# %%
import numpy as np
with open('x_65dims.npy', 'rb') as f:
    X = np.load(f)

# %%
from pyclustertend import vat

# %%
vat(X)

# %%
from pyclustertend import ivat
ivat(X)

# %%
from pyclustertend import hopkins
hopkins(X,30)
# Out:
# np.float64(0.17310401689289495)

# %%
with open('x_298dims.npy', 'rb') as f:
    X = np.load(f)

# %%
vat(X)

# %%
ivat(X)
