# %%
import grewpy
from grewpy import Corpus, CorpusDraft, Request
from collections import Counter
import sys
sys.path.insert(1, "/Users/madalina/Documents/M2TAL/stage/check_coherent_labels/tod")

import tod.corpus
import tod.outliers
import tod.clustering
import tod.plotting
import tod.dimension_reduction_classic

treebank_path = "/Users/madalina/Documents/M2TAL/stage/check_coherent_labels/data/input/Universal_Dependencies/ud-treebanks-v2.15/UD_French-GSD"
# treebank_path = "/Users/madalina/Downloads/bUD_English-GUM"
grew_pattern = "pattern{X[upos<>PUNCT]}"
patterns_text_file = "/Users/madalina/Documents/M2TAL/stage/check_coherent_labels/scripts/3. probability_matrix/patterns_all_nodes.txt"
analysed_category = "all_nodes"

corpus = tod.corpus.Corpus(
    treebank_path=treebank_path,
    grew_pattern=grew_pattern,
    patterns_text_file=patterns_text_file,
    use_sud=False,
    matrix_type="coverage",
    excluded_feature_patterns=[r"CxnElt=", r"Cxn=", r"own", r"Gender"]
        # excluded_feature_patterns=[r"CxnElt=", r"Cxn=", r"XML=", r"PDTB=", r"SplitAnte=", r"MSeg=", r"Entity=", r"Discourse=", r"Bridge=", r"own"]
)

# %% [markdown]
# Find the already annotated polycategorial lexical units (such as divers det,adj or from adp, sconj)

# %%
previous_lemma_pos = list(corpus._idx2lexunit.values())[0]
polycategorial_lexunits = {}
for lemma, pos in list(corpus._idx2lexunit.values())[1:]:
    current_lemma_pos = (lemma, pos)
    if current_lemma_pos[0] == previous_lemma_pos[0]:
        if current_lemma_pos[0] not in polycategorial_lexunits:
            polycategorial_lexunits[current_lemma_pos[0]] = (current_lemma_pos[1], previous_lemma_pos[1])
        else:
            polycategorial_lexunits[current_lemma_pos[0]] += (current_lemma_pos[1],)
    previous_lemma_pos = current_lemma_pos
print(polycategorial_lexunits)
print(len(polycategorial_lexunits))
# Out:
# {'/': ('CCONJ', 'ADP'), '1er': ('NUM', 'ADJ'), 'allemand': ('NOUN', 'ADJ'), 'américain': ('NOUN', 'ADJ'), 'anglais': ('NOUN', 'ADJ'), 'après': ('ADV', 'ADP'), 'arabe': ('NOUN', 'ADJ'), 'aucun': ('PRON', 'DET'), 'autant': ('PRON', 'ADV'), 'autre': ('PRON', 'ADJ'), 'avant': ('ADV', 'ADP', 'NOUN'), 'avoir': ('VERB', 'AUX'), 'beaucoup': ('PRON', 'ADV'), 'bien': ('NOUN', 'ADV'), 'blanc': ('NOUN', 'ADJ'), 'bref': ('INTJ', 'ADJ'), 'britannique': ('NOUN', 'ADJ'), 'caractéristique': ('NOUN', 'ADJ'), 'ce': ('PRON', 'DET'), 'certain': ('DET', 'ADJ', 'PRON'), 'chrétien': ('NOUN', 'ADJ'), 'comme': ('CCONJ', 'ADP', 'SCONJ'), 'conseiller': ('VERB', 'NOUN'), 'courant': ('NOUN', 'ADJ'), 'critique': ('NOUN', 'ADJ'), 'depuis': ('ADV', 'ADP'), 'différent': ('DET', 'ADJ'), 'divers': ('DET', 'ADJ'), 'donc': ('CCONJ', 'ADV'), 'droit': ('NOUN', 'ADJ'), 'en': ('PRON', 'ADP'), 'ensemble': ('NOUN', 'ADV'), 'espagnol': ('NOUN', 'ADJ'), 'essentiel': ('NOUN', 'ADJ'), 'extérieur': ('NOUN', 'ADJ'), 'faire': ('VERB', 'AUX'), 'fort': ('ADV', 'ADJ', 'NOUN'), 'français': ('NOUN', 'ADJ'), 'gauche': ('NOUN', 'ADJ'), 'grec': ('NOUN', 'ADJ'), 'général': ('NOUN', 'ADJ'), 'h': ('NUM', 'NOUN'), 'intérieur': ('NOUN', 'ADJ'), 'italien': ('NOUN', 'ADJ'), 'japonais': ('NOUN', 'ADJ'), 'jeune': ('NOUN', 'ADJ'), 'juif': ('NOUN', 'ADJ'), 'large': ('NOUN', 'ADJ'), 'latin': ('NOUN', 'ADJ'), 'long': ('NOUN', 'ADJ'), 'mal': ('NOUN', 'ADV'), 'militaire': ('NOUN', 'ADJ'), 'moins': ('PRON', 'ADV'), 'mort': ('NOUN', 'ADJ'), 'moyen': ('NOUN', 'ADJ'), 'même': ('ADV', 'ADJ'), 'noir': ('NOUN', 'ADJ'), 'or': ('NOUN', 'CCONJ'), 'personne': ('PRON', 'NOUN'), 'personnel': ('NOUN', 'ADJ'), 'peu': ('PRON', 'ADV'), 'physique': ('NOUN', 'ADJ'), 'plat': ('NOUN', 'ADJ'), 'plus': ('PRON', 'ADV'), 'plusieurs': ('PRON', 'DET'), 'policier': ('NOUN', 'ADJ'), 'politique': ('NOUN', 'ADJ'), 'pouvoir': ('VERB', 'NOUN'), 'professionnel': ('NOUN', 'ADJ'), 'près': ('PRON', 'ADV'), 'public': ('NOUN', 'ADJ'), 'que': ('PRON', 'ADV', 'SCONJ'), 'quel': ('DET', 'ADJ'), 'responsable': ('NOUN', 'ADJ'), 'romain': ('NOUN', 'ADJ'), 'roman': ('NOUN', 'ADJ'), 'savoir': ('VERB', 'NOUN'), 'scientifique': ('NOUN', 'ADJ'), 'second': ('NOUN', 'ADJ'), 'si': ('SCONJ', 'ADV'), 'soit': ('CCONJ', 'ADV'), 'son': ('NOUN', 'DET'), 'suivant': ('ADP', 'ADJ'), 'technique': ('NOUN', 'ADJ'), 'tel': ('DET', 'ADJ'), 'total': ('NOUN', 'ADJ'), 'tout': ('ADV', 'ADJ', 'DET', 'PRON'), 'un': ('NUM', 'DET', 'PRON'), 'vidéo': ('NOUN', 'ADJ'), 'voisin': ('NOUN', 'ADJ'), 'étranger': ('NOUN', 'ADJ'), 'être': ('VERB', 'AUX')}
# 92

# %%
pos_nbelements = {}
for lemma, pos in list(corpus._idx2lexunit.values())[0:]:
    if pos not in pos_nbelements:
        pos_nbelements[pos] = {"total": 0, "polycategorial": 0}
    pos_nbelements[pos]["total"] += 1
    if lemma in polycategorial_lexunits:
        pos_nbelements[pos]["polycategorial"] += 1
print(pos_nbelements)
# Out:
# {'NOUN': {'total': 1400, 'polycategorial': 59}, 'CCONJ': {'total': 14, 'polycategorial': 5}, 'ADP': {'total': 35, 'polycategorial': 7}, 'NUM': {'total': 166, 'polycategorial': 3}, 'ADJ': {'total': 402, 'polycategorial': 59}, 'VERB': {'total': 556, 'polycategorial': 6}, 'PROPN': {'total': 172, 'polycategorial': 0}, 'ADV': {'total': 123, 'polycategorial': 19}, 'DET': {'total': 15, 'polycategorial': 11}, 'PRON': {'total': 40, 'polycategorial': 16}, 'AUX': {'total': 3, 'polycategorial': 3}, 'INTJ': {'total': 2, 'polycategorial': 1}, 'SCONJ': {'total': 6, 'polycategorial': 3}, 'X': {'total': 1, 'polycategorial': 0}}

# %%
corpus.lexunit2idx(('soit', 'ADV'))
# Out:
# 2506

# %% [markdown]
# Measure the distance between the vectors representing the two lexical units (e.g. v1 = anglais, noun and v2 = anglais, adj) and compare the cross-POS distance to the average distance within the category. A split is justified if the distance between (anglais, N) and (anglais, adj) is significantly higher than the typical distance between two nouns.

# %%
def _get_category_stats(target_pos, target_idx, target_vec, metric='cosine'):
        # Indices of all other members of this POS
        cat_indices = [idx for idx, unit in idx_to_unit.items() 
                       if unit[1] == target_pos and idx != target_idx]
        
        if len(cat_indices) < 2:
            return 0.0, 0.0, 0.0 # Not enough data to compute stats
        
        # Distances from our target word to all other words in its POS
        cat_matrix = matrix[cat_indices]
        dists = cdist(target_vec, cat_matrix, metric=metric)[0]
        
        return np.mean(dists), np.std(dists), len(cat_indices)

# %%
import numpy as np
from scipy.spatial.distance import cdist

def check_cross_pos_distance(matrix, idx_to_unit, unit_to_idx, lemma, poses, metric='cosine', k=1.0):
    """
    Checks if dist(lemma_pos1, lemma_pos2) is greater than the intra-category 
    distance for BOTH categories.
    
    Args:
        matrix (np.array): N x M matrix (rows=units, cols=features).
        idx_to_unit (dict): Maps row index -> (lemma, pos).
        unit_to_idx (dict): Maps (lemma, pos) -> row index.
        lemma (str): The lemma to check.
        poses (tuple): A tuple of two POS tags (pos1, pos2).
        metric (str): Distance metric ('cosine', 'euclidean', etc.).
        
    Returns:
        dict: Results containing distances, the comparison boolean, and the farthest element.
    """
    
    target_1 = (lemma, poses[0])
    target_2 = (lemma, poses[1])

    idx1 = unit_to_idx[target_1]
    idx2 = unit_to_idx[target_2]

    vec1 = matrix[idx1].reshape(1, -1) # Reshape for cdist
    vec2 = matrix[idx2].reshape(1, -1)

    # 3. Calculate Cross-POS distance (e.g., dist(dance_N, dance_V))
    # cdist returns a 2D array, we take [0][0]
    cross_dist = cdist(vec1, vec2, metric=metric)[0][0]

    mu1, std1, count1 = _get_category_stats(poses[0], idx1, vec1, metric)
    mu2, std2, count2 = _get_category_stats(poses[1], idx2, vec2, metric)

    # 4. Calculate Z-scores
    # How many standard deviations is the cross_dist away from the category mean?
    z1 = (cross_dist - mu1) / std1 if std1 > 0 else 0
    z2 = (cross_dist - mu2) / std2 if std2 > 0 else 0

    # 5. Final Logic
    # We split if the cross_dist is significantly larger than the average variation in BOTH categories.
    # should_split = (z1 > k) or (z2 > k)
    should_split = cross_dist > mu1 or cross_dist > mu2

    return {
        "lemma": lemma,
        "pos1": poses[0],
        "pos2": poses[1],
        "cross_dist": round(float(cross_dist), 4),
        f"{poses[0]}_stats": {"mean": round(float(mu1), 4), "std": round(float(std1), 4), "z_score": round(float(z1), 2)},
        f"{poses[1]}_stats": {"mean": round(float(mu2), 4), "std": round(float(std2), 4), "z_score": round(float(z2), 2)},
        "should_split": bool(should_split),
        "threshold_k": k
    }

# --- Example Usage ---

# # 1. Create Dummy Data
# # 5 lexical units, 3 features each
matrix = np.array([
    [1.0, 0.9, 0.1],  # 0: (dance, noun)
    [0.1, 0.2, 0.9],  # 1: (dance, verb) - Very different from noun
    [0.9, 0.8, 0.2],  # 2: (table, noun) - Similar to dance_noun
    [0.8, 0.9, 0.1],  # 3: (chair, noun) - Similar to dance_noun
    [0.5, 0.5, 0.5],  # 4: (weird, noun) - The "farthest" noun
])

idx_to_unit = {
    0: ("dance", "noun"),
    1: ("dance", "verb"),
    2: ("table", "noun"),
    3: ("chair", "noun"),
    4: ("weird", "noun")
}

unit_to_idx = {v: k for k, v in idx_to_unit.items()}
# 2. Run the check
result = check_cross_pos_distance(matrix, idx_to_unit, unit_to_idx, "dance", ("noun","verb"), metric='cosine', k=1.0)

# 3. Print Results
print(result)
# print(f"Distance (dance, N) <-> (dance, V): {result['cross_dist']:.4f}")
# print(f"Max Dist (dance, N) <-> Any Noun:   {result['max_intra_cat_dist']:.4f}")
# print(f"Farthest Noun:                      {result['farthest_same_cat_unit']}")
# print("-" * 30)
# print(f"Is Cross Distance Bigger?           {result['is_cross_bigger']}")
# Out:
# {'lemma': 'dance', 'pos1': 'noun', 'pos2': 'verb', 'cross_dist': 0.7043, 'noun_stats': {'mean': 0.0515, 'std': 0.0655, 'z_score': 9.97}, 'verb_stats': {'mean': 0.0, 'std': 0.0, 'z_score': 0.0}, 'should_split': True, 'threshold_k': 1.0}

# %%
True or False
# Out:
# True

# %%
matrix = corpus.feature_matrix
idx_to_unit = corpus._idx2lexunit
unit_to_idx = corpus._lexunit2idx
for lemma, poses in polycategorial_lexunits.items():
    comparison_result = check_cross_pos_distance(matrix, idx_to_unit, unit_to_idx, lemma, poses, metric='cosine', k=1.0)
    # print(f"{comparison_result['lemma']}, {comparison_result['pos1']} vs {comparison_result['pos2']}: should split? {comparison_result['should_split']}")
    print(comparison_result)

    # print(f"{dico['lemma']}, {dico['pos1']} vs {dico['pos2']}: {decision}")
# Out:
# {'lemma': '/', 'pos1': 'CCONJ', 'pos2': 'ADP', 'cross_dist': 0.148, 'CCONJ_stats': {'mean': 0.3161, 'std': 0.1018, 'z_score': -1.65}, 'ADP_stats': {'mean': 0.2917, 'std': 0.0893, 'z_score': -1.61}, 'should_split': False, 'threshold_k': 1.0}
# {'lemma': '1er', 'pos1': 'NUM', 'pos2': 'ADJ', 'cross_dist': 0.3058, 'NUM_stats': {'mean': 0.5565, 'std': 0.2299, 'z_score': -1.09}, 'ADJ_stats': {'mean': 0.4708, 'std': 0.1825, 'z_score': -0.9}, 'should_split': False, 'threshold_k': 1.0}
# {'lemma': 'allemand', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5409, 'NOUN_stats': {'mean': 0.1516, 'std': 0.0748, 'z_score': 5.2}, 'ADJ_stats': {'mean': 0.1874, 'std': 0.2027, 'z_score': 1.74}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'américain', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.7016, 'NOUN_stats': {'mean': 0.2184, 'std': 0.0983, 'z_score': 4.92}, 'ADJ_stats': {'mean': 0.1931, 'std': 0.1979, 'z_score': 2.57}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'anglais', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.4892, 'NOUN_stats': {'mean': 0.2346, 'std': 0.0747, 'z_score': 3.41}, 'ADJ_stats': {'mean': 0.1881, 'std': 0.1948, 'z_score': 1.55}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'après', 'pos1': 'ADV', 'pos2': 'ADP', 'cross_dist': 0.5795, 'ADV_stats': {'mean': 0.4165, 'std': 0.1167, 'z_score': 1.4}, 'ADP_stats': {'mean': 0.1408, 'std': 0.1119, 'z_score': 3.92}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'arabe', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6017, 'NOUN_stats': {'mean': 0.2099, 'std': 0.0764, 'z_score': 5.13}, 'ADJ_stats': {'mean': 0.1927, 'std': 0.2029, 'z_score': 2.02}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'aucun', 'pos1': 'PRON', 'pos2': 'DET', 'cross_dist': 0.6589, 'PRON_stats': {'mean': 0.3591, 'std': 0.0943, 'z_score': 3.18}, 'DET_stats': {'mean': 0.1728, 'std': 0.158, 'z_score': 3.08}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'autant', 'pos1': 'PRON', 'pos2': 'ADV', 'cross_dist': 0.4456, 'PRON_stats': {'mean': 0.5433, 'std': 0.2273, 'z_score': -0.43}, 'ADV_stats': {'mean': 0.3316, 'std': 0.0845, 'z_score': 1.35}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'autre', 'pos1': 'PRON', 'pos2': 'ADJ', 'cross_dist': 0.5531, 'PRON_stats': {'mean': 0.5258, 'std': 0.0914, 'z_score': 0.3}, 'ADJ_stats': {'mean': 0.5528, 'std': 0.1934, 'z_score': 0.0}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'avant', 'pos1': 'NOUN', 'pos2': 'ADV', 'cross_dist': 0.5069, 'NOUN_stats': {'mean': 0.1821, 'std': 0.0781, 'z_score': 4.16}, 'ADV_stats': {'mean': 0.4952, 'std': 0.1172, 'z_score': 0.1}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'avoir', 'pos1': 'VERB', 'pos2': 'AUX', 'cross_dist': 0.7706, 'VERB_stats': {'mean': 0.1552, 'std': 0.071, 'z_score': 8.67}, 'AUX_stats': {'mean': 0.3613, 'std': 0.2073, 'z_score': 1.97}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'beaucoup', 'pos1': 'PRON', 'pos2': 'ADV', 'cross_dist': 0.4593, 'PRON_stats': {'mean': 0.401, 'std': 0.1682, 'z_score': 0.35}, 'ADV_stats': {'mean': 0.2862, 'std': 0.1329, 'z_score': 1.3}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'bien', 'pos1': 'NOUN', 'pos2': 'ADV', 'cross_dist': 0.62, 'NOUN_stats': {'mean': 0.11, 'std': 0.0836, 'z_score': 6.1}, 'ADV_stats': {'mean': 0.2019, 'std': 0.145, 'z_score': 2.88}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'blanc', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.3862, 'NOUN_stats': {'mean': 0.1697, 'std': 0.0725, 'z_score': 2.99}, 'ADJ_stats': {'mean': 0.179, 'std': 0.1903, 'z_score': 1.09}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'bref', 'pos1': 'INTJ', 'pos2': 'ADJ', 'cross_dist': 0.5418, 'INTJ_stats': {'mean': 0.0, 'std': 0.0, 'z_score': 0.0}, 'ADJ_stats': {'mean': 0.3867, 'std': 0.1359, 'z_score': 1.14}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'britannique', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6776, 'NOUN_stats': {'mean': 0.1911, 'std': 0.0973, 'z_score': 5.0}, 'ADJ_stats': {'mean': 0.1841, 'std': 0.2009, 'z_score': 2.46}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'caractéristique', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5713, 'NOUN_stats': {'mean': 0.1936, 'std': 0.0965, 'z_score': 3.92}, 'ADJ_stats': {'mean': 0.288, 'std': 0.1392, 'z_score': 2.04}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'ce', 'pos1': 'PRON', 'pos2': 'DET', 'cross_dist': 0.4524, 'PRON_stats': {'mean': 0.4521, 'std': 0.1623, 'z_score': 0.0}, 'DET_stats': {'mean': 0.1167, 'std': 0.1176, 'z_score': 2.86}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'certain', 'pos1': 'PRON', 'pos2': 'DET', 'cross_dist': 0.5508, 'PRON_stats': {'mean': 0.3229, 'std': 0.1082, 'z_score': 2.11}, 'DET_stats': {'mean': 0.2248, 'std': 0.1498, 'z_score': 2.18}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'chrétien', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5503, 'NOUN_stats': {'mean': 0.1677, 'std': 0.0812, 'z_score': 4.71}, 'ADJ_stats': {'mean': 0.1893, 'std': 0.1824, 'z_score': 1.98}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'comme', 'pos1': 'SCONJ', 'pos2': 'CCONJ', 'cross_dist': 0.2187, 'SCONJ_stats': {'mean': 0.1498, 'std': 0.0238, 'z_score': 2.89}, 'CCONJ_stats': {'mean': 0.2642, 'std': 0.1248, 'z_score': -0.36}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'conseiller', 'pos1': 'VERB', 'pos2': 'NOUN', 'cross_dist': 0.4821, 'VERB_stats': {'mean': 0.2612, 'std': 0.0728, 'z_score': 3.03}, 'NOUN_stats': {'mean': 0.2931, 'std': 0.0718, 'z_score': 2.63}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'courant', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5105, 'NOUN_stats': {'mean': 0.1182, 'std': 0.0935, 'z_score': 4.2}, 'ADJ_stats': {'mean': 0.2188, 'std': 0.1401, 'z_score': 2.08}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'critique', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.4991, 'NOUN_stats': {'mean': 0.1281, 'std': 0.0821, 'z_score': 4.52}, 'ADJ_stats': {'mean': 0.2028, 'std': 0.1834, 'z_score': 1.62}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'depuis', 'pos1': 'ADV', 'pos2': 'ADP', 'cross_dist': 0.5646, 'ADV_stats': {'mean': 0.3131, 'std': 0.1114, 'z_score': 2.26}, 'ADP_stats': {'mean': 0.1344, 'std': 0.0932, 'z_score': 4.61}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'différent', 'pos1': 'DET', 'pos2': 'ADJ', 'cross_dist': 0.3075, 'DET_stats': {'mean': 0.2252, 'std': 0.1505, 'z_score': 0.55}, 'ADJ_stats': {'mean': 0.3354, 'std': 0.0982, 'z_score': -0.28}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'divers', 'pos1': 'DET', 'pos2': 'ADJ', 'cross_dist': 0.2975, 'DET_stats': {'mean': 0.2371, 'std': 0.1551, 'z_score': 0.39}, 'ADJ_stats': {'mean': 0.4229, 'std': 0.1164, 'z_score': -1.08}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'donc', 'pos1': 'CCONJ', 'pos2': 'ADV', 'cross_dist': 0.5037, 'CCONJ_stats': {'mean': 0.2284, 'std': 0.1199, 'z_score': 2.3}, 'ADV_stats': {'mean': 0.2382, 'std': 0.1693, 'z_score': 1.57}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'droit', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5918, 'NOUN_stats': {'mean': 0.1141, 'std': 0.0866, 'z_score': 5.52}, 'ADJ_stats': {'mean': 0.2066, 'std': 0.2013, 'z_score': 1.91}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'en', 'pos1': 'PRON', 'pos2': 'ADP', 'cross_dist': 0.4781, 'PRON_stats': {'mean': 0.3748, 'std': 0.2337, 'z_score': 0.44}, 'ADP_stats': {'mean': 0.2346, 'std': 0.0727, 'z_score': 3.35}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'ensemble', 'pos1': 'NOUN', 'pos2': 'ADV', 'cross_dist': 0.6393, 'NOUN_stats': {'mean': 0.1197, 'std': 0.1046, 'z_score': 4.97}, 'ADV_stats': {'mean': 0.3892, 'std': 0.1366, 'z_score': 1.83}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'espagnol', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.454, 'NOUN_stats': {'mean': 0.1725, 'std': 0.0716, 'z_score': 3.93}, 'ADJ_stats': {'mean': 0.1874, 'std': 0.2004, 'z_score': 1.33}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'essentiel', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5719, 'NOUN_stats': {'mean': 0.1877, 'std': 0.1187, 'z_score': 3.24}, 'ADJ_stats': {'mean': 0.2569, 'std': 0.1516, 'z_score': 2.08}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'extérieur', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5532, 'NOUN_stats': {'mean': 0.1266, 'std': 0.0969, 'z_score': 4.4}, 'ADJ_stats': {'mean': 0.1848, 'std': 0.196, 'z_score': 1.88}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'faire', 'pos1': 'VERB', 'pos2': 'AUX', 'cross_dist': 0.8186, 'VERB_stats': {'mean': 0.1316, 'std': 0.0629, 'z_score': 10.92}, 'AUX_stats': {'mean': 0.5505, 'std': 0.0181, 'z_score': 14.83}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'fort', 'pos1': 'NOUN', 'pos2': 'ADV', 'cross_dist': 0.6498, 'NOUN_stats': {'mean': 0.1874, 'std': 0.1086, 'z_score': 4.26}, 'ADV_stats': {'mean': 0.2829, 'std': 0.1253, 'z_score': 2.93}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'français', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5571, 'NOUN_stats': {'mean': 0.143, 'std': 0.0787, 'z_score': 5.27}, 'ADJ_stats': {'mean': 0.188, 'std': 0.1976, 'z_score': 1.87}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'gauche', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.4785, 'NOUN_stats': {'mean': 0.2589, 'std': 0.0803, 'z_score': 2.74}, 'ADJ_stats': {'mean': 0.2098, 'std': 0.201, 'z_score': 1.34}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'grec', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6342, 'NOUN_stats': {'mean': 0.1684, 'std': 0.0954, 'z_score': 4.88}, 'ADJ_stats': {'mean': 0.1911, 'std': 0.1952, 'z_score': 2.27}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'général', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5868, 'NOUN_stats': {'mean': 0.1677, 'std': 0.105, 'z_score': 3.99}, 'ADJ_stats': {'mean': 0.2025, 'std': 0.2002, 'z_score': 1.92}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'h', 'pos1': 'NUM', 'pos2': 'NOUN', 'cross_dist': 0.0307, 'NUM_stats': {'mean': 0.5507, 'std': 0.1338, 'z_score': -3.89}, 'NOUN_stats': {'mean': 0.5351, 'std': 0.0959, 'z_score': -5.26}, 'should_split': False, 'threshold_k': 1.0}
# {'lemma': 'intérieur', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6441, 'NOUN_stats': {'mean': 0.1398, 'std': 0.1044, 'z_score': 4.83}, 'ADJ_stats': {'mean': 0.1921, 'std': 0.2042, 'z_score': 2.21}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'italien', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5159, 'NOUN_stats': {'mean': 0.1835, 'std': 0.0884, 'z_score': 3.76}, 'ADJ_stats': {'mean': 0.1873, 'std': 0.1962, 'z_score': 1.67}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'japonais', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5763, 'NOUN_stats': {'mean': 0.1612, 'std': 0.0892, 'z_score': 4.65}, 'ADJ_stats': {'mean': 0.1914, 'std': 0.2024, 'z_score': 1.9}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'jeune', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5241, 'NOUN_stats': {'mean': 0.1489, 'std': 0.0867, 'z_score': 4.33}, 'ADJ_stats': {'mean': 0.4421, 'std': 0.1799, 'z_score': 0.46}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'juif', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5787, 'NOUN_stats': {'mean': 0.1997, 'std': 0.0843, 'z_score': 4.5}, 'ADJ_stats': {'mean': 0.1892, 'std': 0.2024, 'z_score': 1.92}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'large', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.543, 'NOUN_stats': {'mean': 0.1637, 'std': 0.0894, 'z_score': 4.24}, 'ADJ_stats': {'mean': 0.3673, 'std': 0.1529, 'z_score': 1.15}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'latin', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5678, 'NOUN_stats': {'mean': 0.1987, 'std': 0.0844, 'z_score': 4.37}, 'ADJ_stats': {'mean': 0.2341, 'std': 0.1885, 'z_score': 1.77}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'long', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6297, 'NOUN_stats': {'mean': 0.5805, 'std': 0.1109, 'z_score': 0.44}, 'ADJ_stats': {'mean': 0.3432, 'std': 0.1324, 'z_score': 2.16}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'mal', 'pos1': 'NOUN', 'pos2': 'ADV', 'cross_dist': 0.6003, 'NOUN_stats': {'mean': 0.1474, 'std': 0.0776, 'z_score': 5.84}, 'ADV_stats': {'mean': 0.2638, 'std': 0.1384, 'z_score': 2.43}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'militaire', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.676, 'NOUN_stats': {'mean': 0.1843, 'std': 0.0902, 'z_score': 5.45}, 'ADJ_stats': {'mean': 0.1891, 'std': 0.2011, 'z_score': 2.42}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'moins', 'pos1': 'PRON', 'pos2': 'ADV', 'cross_dist': 0.6363, 'PRON_stats': {'mean': 0.5222, 'std': 0.2255, 'z_score': 0.51}, 'ADV_stats': {'mean': 0.3312, 'std': 0.1316, 'z_score': 2.32}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'mort', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5421, 'NOUN_stats': {'mean': 0.1226, 'std': 0.0856, 'z_score': 4.9}, 'ADJ_stats': {'mean': 0.2919, 'std': 0.1497, 'z_score': 1.67}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'moyen', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5523, 'NOUN_stats': {'mean': 0.1428, 'std': 0.0862, 'z_score': 4.75}, 'ADJ_stats': {'mean': 0.2245, 'std': 0.1312, 'z_score': 2.5}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'même', 'pos1': 'ADV', 'pos2': 'ADJ', 'cross_dist': 0.5215, 'ADV_stats': {'mean': 0.2468, 'std': 0.1059, 'z_score': 2.59}, 'ADJ_stats': {'mean': 0.5107, 'std': 0.2072, 'z_score': 0.05}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'noir', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.4891, 'NOUN_stats': {'mean': 0.2446, 'std': 0.0687, 'z_score': 3.56}, 'ADJ_stats': {'mean': 0.1811, 'std': 0.1911, 'z_score': 1.61}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'or', 'pos1': 'NOUN', 'pos2': 'CCONJ', 'cross_dist': 0.7712, 'NOUN_stats': {'mean': 0.4075, 'std': 0.1051, 'z_score': 3.46}, 'CCONJ_stats': {'mean': 0.3706, 'std': 0.1473, 'z_score': 2.72}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'personne', 'pos1': 'PRON', 'pos2': 'NOUN', 'cross_dist': 0.6327, 'PRON_stats': {'mean': 0.4247, 'std': 0.1309, 'z_score': 1.59}, 'NOUN_stats': {'mean': 0.1615, 'std': 0.0665, 'z_score': 7.09}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'personnel', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5988, 'NOUN_stats': {'mean': 0.1444, 'std': 0.1119, 'z_score': 4.06}, 'ADJ_stats': {'mean': 0.1821, 'std': 0.195, 'z_score': 2.14}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'peu', 'pos1': 'PRON', 'pos2': 'ADV', 'cross_dist': 0.4503, 'PRON_stats': {'mean': 0.4907, 'std': 0.1666, 'z_score': -0.24}, 'ADV_stats': {'mean': 0.245, 'std': 0.1277, 'z_score': 1.61}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'physique', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.4311, 'NOUN_stats': {'mean': 0.3338, 'std': 0.0931, 'z_score': 1.05}, 'ADJ_stats': {'mean': 0.1913, 'std': 0.2044, 'z_score': 1.17}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'plat', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6433, 'NOUN_stats': {'mean': 0.1816, 'std': 0.0986, 'z_score': 4.68}, 'ADJ_stats': {'mean': 0.1903, 'std': 0.1801, 'z_score': 2.52}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'plus', 'pos1': 'PRON', 'pos2': 'ADV', 'cross_dist': 0.7219, 'PRON_stats': {'mean': 0.4568, 'std': 0.2055, 'z_score': 1.29}, 'ADV_stats': {'mean': 0.4343, 'std': 0.1524, 'z_score': 1.89}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'plusieurs', 'pos1': 'PRON', 'pos2': 'DET', 'cross_dist': 0.7665, 'PRON_stats': {'mean': 0.4725, 'std': 0.143, 'z_score': 2.06}, 'DET_stats': {'mean': 0.2201, 'std': 0.1453, 'z_score': 3.76}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'policier', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.7276, 'NOUN_stats': {'mean': 0.2411, 'std': 0.095, 'z_score': 5.12}, 'ADJ_stats': {'mean': 0.2083, 'std': 0.2076, 'z_score': 2.5}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'politique', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5611, 'NOUN_stats': {'mean': 0.1126, 'std': 0.098, 'z_score': 4.58}, 'ADJ_stats': {'mean': 0.1889, 'std': 0.1995, 'z_score': 1.87}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'pouvoir', 'pos1': 'VERB', 'pos2': 'NOUN', 'cross_dist': 0.6837, 'VERB_stats': {'mean': 0.3614, 'std': 0.0788, 'z_score': 4.09}, 'NOUN_stats': {'mean': 0.0997, 'std': 0.0983, 'z_score': 5.94}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'professionnel', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.4631, 'NOUN_stats': {'mean': 0.1757, 'std': 0.0642, 'z_score': 4.48}, 'ADJ_stats': {'mean': 0.1767, 'std': 0.1862, 'z_score': 1.54}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'près', 'pos1': 'PRON', 'pos2': 'ADV', 'cross_dist': 0.1889, 'PRON_stats': {'mean': 0.4705, 'std': 0.2066, 'z_score': -1.36}, 'ADV_stats': {'mean': 0.4799, 'std': 0.1435, 'z_score': -2.03}, 'should_split': False, 'threshold_k': 1.0}
# {'lemma': 'public', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6132, 'NOUN_stats': {'mean': 0.141, 'std': 0.1059, 'z_score': 4.46}, 'ADJ_stats': {'mean': 0.1858, 'std': 0.2025, 'z_score': 2.11}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'que', 'pos1': 'SCONJ', 'pos2': 'PRON', 'cross_dist': 0.1319, 'SCONJ_stats': {'mean': 0.0793, 'std': 0.0259, 'z_score': 2.03}, 'PRON_stats': {'mean': 0.3808, 'std': 0.1823, 'z_score': -1.37}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'quel', 'pos1': 'DET', 'pos2': 'ADJ', 'cross_dist': 0.8898, 'DET_stats': {'mean': 0.1286, 'std': 0.1234, 'z_score': 6.17}, 'ADJ_stats': {'mean': 0.6906, 'std': 0.1503, 'z_score': 1.33}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'responsable', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.503, 'NOUN_stats': {'mean': 0.1206, 'std': 0.0832, 'z_score': 4.59}, 'ADJ_stats': {'mean': 0.4216, 'std': 0.1471, 'z_score': 0.55}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'romain', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6877, 'NOUN_stats': {'mean': 0.2157, 'std': 0.095, 'z_score': 4.97}, 'ADJ_stats': {'mean': 0.1874, 'std': 0.2013, 'z_score': 2.48}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'roman', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5305, 'NOUN_stats': {'mean': 0.1119, 'std': 0.088, 'z_score': 4.76}, 'ADJ_stats': {'mean': 0.2075, 'std': 0.1923, 'z_score': 1.68}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'savoir', 'pos1': 'VERB', 'pos2': 'NOUN', 'cross_dist': 0.6227, 'VERB_stats': {'mean': 0.2337, 'std': 0.0737, 'z_score': 5.28}, 'NOUN_stats': {'mean': 0.1349, 'std': 0.0978, 'z_score': 4.99}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'scientifique', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5886, 'NOUN_stats': {'mean': 0.2989, 'std': 0.0873, 'z_score': 3.32}, 'ADJ_stats': {'mean': 0.1912, 'std': 0.2063, 'z_score': 1.93}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'second', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.416, 'NOUN_stats': {'mean': 0.1834, 'std': 0.095, 'z_score': 2.45}, 'ADJ_stats': {'mean': 0.5121, 'std': 0.2118, 'z_score': -0.45}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'si', 'pos1': 'SCONJ', 'pos2': 'ADV', 'cross_dist': 0.5406, 'SCONJ_stats': {'mean': 0.0738, 'std': 0.0579, 'z_score': 8.06}, 'ADV_stats': {'mean': 0.4412, 'std': 0.1565, 'z_score': 0.64}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'soit', 'pos1': 'CCONJ', 'pos2': 'ADV', 'cross_dist': 0.1717, 'CCONJ_stats': {'mean': 0.2111, 'std': 0.1068, 'z_score': -0.37}, 'ADV_stats': {'mean': 0.5809, 'std': 0.1257, 'z_score': -3.25}, 'should_split': False, 'threshold_k': 1.0}
# {'lemma': 'son', 'pos1': 'NOUN', 'pos2': 'DET', 'cross_dist': 0.6918, 'NOUN_stats': {'mean': 0.1295, 'std': 0.0839, 'z_score': 6.7}, 'DET_stats': {'mean': 0.0975, 'std': 0.0899, 'z_score': 6.61}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'suivant', 'pos1': 'ADP', 'pos2': 'ADJ', 'cross_dist': 0.5804, 'ADP_stats': {'mean': 0.1467, 'std': 0.1281, 'z_score': 3.39}, 'ADJ_stats': {'mean': 0.2044, 'std': 0.2029, 'z_score': 1.85}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'technique', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5553, 'NOUN_stats': {'mean': 0.1095, 'std': 0.0869, 'z_score': 5.13}, 'ADJ_stats': {'mean': 0.2098, 'std': 0.2005, 'z_score': 1.72}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'tel', 'pos1': 'DET', 'pos2': 'ADJ', 'cross_dist': 0.4483, 'DET_stats': {'mean': 0.2056, 'std': 0.1521, 'z_score': 1.6}, 'ADJ_stats': {'mean': 0.3412, 'std': 0.0724, 'z_score': 1.48}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'total', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.6433, 'NOUN_stats': {'mean': 0.1506, 'std': 0.1008, 'z_score': 4.89}, 'ADJ_stats': {'mean': 0.1933, 'std': 0.1859, 'z_score': 2.42}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'tout', 'pos1': 'PRON', 'pos2': 'DET', 'cross_dist': 0.5429, 'PRON_stats': {'mean': 0.2791, 'std': 0.0878, 'z_score': 3.01}, 'DET_stats': {'mean': 0.1007, 'std': 0.0813, 'z_score': 5.44}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'un', 'pos1': 'PRON', 'pos2': 'NUM', 'cross_dist': 0.7795, 'PRON_stats': {'mean': 0.589, 'std': 0.1859, 'z_score': 1.02}, 'NUM_stats': {'mean': 0.5134, 'std': 0.1091, 'z_score': 2.44}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'vidéo', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.3285, 'NOUN_stats': {'mean': 0.213, 'std': 0.064, 'z_score': 1.81}, 'ADJ_stats': {'mean': 0.2061, 'std': 0.2015, 'z_score': 0.61}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'voisin', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.5658, 'NOUN_stats': {'mean': 0.3051, 'std': 0.0715, 'z_score': 3.65}, 'ADJ_stats': {'mean': 0.2369, 'std': 0.1909, 'z_score': 1.72}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'étranger', 'pos1': 'NOUN', 'pos2': 'ADJ', 'cross_dist': 0.707, 'NOUN_stats': {'mean': 0.1685, 'std': 0.1036, 'z_score': 5.2}, 'ADJ_stats': {'mean': 0.2895, 'std': 0.203, 'z_score': 2.06}, 'should_split': True, 'threshold_k': 1.0}
# {'lemma': 'être', 'pos1': 'VERB', 'pos2': 'AUX', 'cross_dist': 0.7297, 'VERB_stats': {'mean': 0.2007, 'std': 0.0669, 'z_score': 7.91}, 'AUX_stats': {'mean': 0.3432, 'std': 0.1892, 'z_score': 2.04}, 'should_split': True, 'threshold_k': 1.0}

# %%
import numpy as np

def get_discriminating_features(matrix, unit_to_idx, idx_to_feature, lemma, poses, top_n=10):
    """
    Identifies which features (columns) have the largest difference between two senses.
    """
    pos1, pos2 = poses
    target_1, target_2 = (lemma, pos1), (lemma, pos2)

    # 1. Extract the vectors
    idx1 = unit_to_idx[target_1]
    idx2 = unit_to_idx[target_2]
    
    vec1 = matrix[idx1]
    vec2 = matrix[idx2]

    # 2. Calculate absolute difference per feature: |v1 - v2|
    # Formula: $\Delta f = |v_{1,f} - v_{2,f}|$
    diffs = np.abs(vec1 - vec2)

    # 3. Get indices of the largest differences
    # argsort sorts ascending, so we take the end of the array and reverse it
    top_indices = np.argsort(diffs)[-top_n:][::-1]

    results = []
    for i in top_indices:
        feature_name = idx_to_feature[i]
        results.append({
            "feature": feature_name,
            f"val_{pos1}": round(float(vec1[i]), 4),
            f"val_{pos2}": round(float(vec2[i]), 4),
            "abs_diff": round(float(diffs[i]), 4)
        })

    return results

# %%
top_diffs = get_discriminating_features(matrix, unit_to_idx, corpus._idx2feature, "of", ("SCONJ", "ADP"))

for d in top_diffs:
    print(d)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 top_diffs = get_discriminating_features(matrix, unit_to_idx, corpus._idx2feature, "of", ("SCONJ", "ADP"))
#       3 for d in top_diffs:
#       4     print(d)
#
# Cell In[89], line 11, in get_discriminating_features(matrix, unit_to_idx, idx_to_feature, lemma, poses, top_n)
#       8 target_1, target_2 = (lemma, pos1), (lemma, pos2)
#      10 # 1. Extract the vectors
# ---> 11 idx1 = unit_to_idx[target_1]
#      12 idx2 = unit_to_idx[target_2]
#      14 vec1 = matrix[idx1]
#
# KeyError: ('of', 'SCONJ')

# %%
from itertools import combinations
import numpy as np
from scipy.spatial.distance import cdist

def check_robust_split(matrix, idx_to_unit, unit_to_idx, lemma, poses, k_neighbors=20, metric='cosine'):
    # Generate all unique pairs of poses
    # e.g., if poses=['NOUN', 'VERB', 'ADJ'], pairs are (N, V), (N, A), (V, A)
    pose_pairs = list(combinations(poses, 2))
    results = []

    def get_local_density(target_pos, target_idx, target_vec):
        all_cat_indices = [idx for idx, u in idx_to_unit.items() if u[1] == target_pos and idx != target_idx]
        
        if not all_cat_indices:
            return 0.0
            
        if len(all_cat_indices) < k_neighbors:
            compare_indices = all_cat_indices
        else:
            all_dists = cdist(target_vec, matrix[all_cat_indices], metric=metric)[0]
            closest_k_relative_indices = np.argsort(all_dists)[:k_neighbors]
            compare_indices = [all_cat_indices[i] for i in closest_k_relative_indices]
        
        local_dists = cdist(target_vec, matrix[compare_indices], metric=metric)[0]
        return np.median(local_dists)

    # Iterate through each pair and calculate the split strength
    for pos1, pos2 in pose_pairs:
        t1, t2 = (lemma, pos1), (lemma, pos2)
        
        # Skip this pair if one of the senses isn't in our mapping
        if t1 not in unit_to_idx or t2 not in unit_to_idx:
            continue

        v1 = matrix[unit_to_idx[t1]].reshape(1, -1)
        v2 = matrix[unit_to_idx[t2]].reshape(1, -1)
        cross_dist = cdist(v1, v2, metric=metric)[0][0]

        local_size1 = get_local_density(pos1, unit_to_idx[t1], v1)
        local_size2 = get_local_density(pos2, unit_to_idx[t2], v2)

        robust_ratio1 = cross_dist / local_size1 if local_size1 > 0 else 0
        robust_ratio2 = cross_dist / local_size2 if local_size2 > 0 else 0
        split_strength = min(robust_ratio1, robust_ratio2)

        min_ratio = min(robust_ratio1, robust_ratio2)
        difference = abs(robust_ratio1 - robust_ratio2)
        split_quality_score = min_ratio / (1 + difference )

        results.append({
            "lemma": lemma,
            "poses_compared": (pos1, pos2), # Added for clarity in multi-pose output
            "split_strength": round(split_strength, 3),
            "interpretation": "High = Clear Split | Low = Merged/Noisy",
            "ratios": {pos1: round(robust_ratio1, 2), pos2: round(robust_ratio2, 2)},
            "local_densities": {pos1: round(local_size1, 3), pos2: round(local_size2, 3)},
            "cross_dist": round(cross_dist, 3),
            "min_ratio": round(min_ratio, 3),
            "difference" : round(difference, 3),
            "split_quality_score": round(split_quality_score, 3)
        })

    # Return the list of results (or None if no valid pairs were found)
    return results if results else None

# %%
for lemma, poses in polycategorial_lexunits.items():
    result = check_robust_split(matrix, idx_to_unit, unit_to_idx, lemma, poses, k_neighbors=20, metric='cosine')
    for dico in result:
        print(dico)
# Out:
# {'lemma': '/', 'poses_compared': ('CCONJ', 'ADP'), 'split_strength': 0.489, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'CCONJ': 0.49, 'ADP': 0.58}, 'local_densities': {'CCONJ': 0.303, 'ADP': 0.255}, 'cross_dist': 0.148, 'min_ratio': 0.489, 'difference': 0.092, 'split_quality_score': 0.448}
# {'lemma': '1er', 'poses_compared': ('NUM', 'ADJ'), 'split_strength': 6.156, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NUM': 6.16, 'ADJ': 6.7}, 'local_densities': {'NUM': 0.05, 'ADJ': 0.046}, 'cross_dist': 0.306, 'min_ratio': 6.156, 'difference': 0.549, 'split_quality_score': 3.974}
# {'lemma': 'allemand', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 8.209, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 8.21, 'ADJ': 49.03}, 'local_densities': {'NOUN': 0.066, 'ADJ': 0.011}, 'cross_dist': 0.541, 'min_ratio': 8.209, 'difference': 40.818, 'split_quality_score': 0.196}
# {'lemma': 'américain', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 8.558, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 8.56, 'ADJ': 57.61}, 'local_densities': {'NOUN': 0.082, 'ADJ': 0.012}, 'cross_dist': 0.702, 'min_ratio': 8.558, 'difference': 49.056, 'split_quality_score': 0.171}
# {'lemma': 'anglais', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 5.969, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 5.97, 'ADJ': 28.9}, 'local_densities': {'NOUN': 0.082, 'ADJ': 0.017}, 'cross_dist': 0.489, 'min_ratio': 5.969, 'difference': 22.933, 'split_quality_score': 0.249}
# {'lemma': 'après', 'poses_compared': ('ADV', 'ADP'), 'split_strength': 2.301, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 2.3, 'ADP': 7.82}, 'local_densities': {'ADV': 0.252, 'ADP': 0.074}, 'cross_dist': 0.58, 'min_ratio': 2.301, 'difference': 5.521, 'split_quality_score': 0.353}
# {'lemma': 'arabe', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 6.164, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 6.16, 'ADJ': 38.21}, 'local_densities': {'NOUN': 0.098, 'ADJ': 0.016}, 'cross_dist': 0.602, 'min_ratio': 6.164, 'difference': 32.049, 'split_quality_score': 0.187}
# {'lemma': 'aucun', 'poses_compared': ('PRON', 'DET'), 'split_strength': 2.14, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 2.14, 'DET': 8.38}, 'local_densities': {'PRON': 0.308, 'DET': 0.079}, 'cross_dist': 0.659, 'min_ratio': 2.14, 'difference': 6.238, 'split_quality_score': 0.296}
# {'lemma': 'autant', 'poses_compared': ('PRON', 'ADV'), 'split_strength': 1.179, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 1.18, 'ADV': 1.88}, 'local_densities': {'PRON': 0.378, 'ADV': 0.236}, 'cross_dist': 0.446, 'min_ratio': 1.179, 'difference': 0.706, 'split_quality_score': 0.691}
# {'lemma': 'autre', 'poses_compared': ('PRON', 'ADJ'), 'split_strength': 1.133, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 1.13, 'ADJ': 5.49}, 'local_densities': {'PRON': 0.488, 'ADJ': 0.101}, 'cross_dist': 0.553, 'min_ratio': 1.133, 'difference': 4.362, 'split_quality_score': 0.211}
# {'lemma': 'avant', 'poses_compared': ('ADV', 'ADP'), 'split_strength': 1.951, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 1.95, 'ADP': 11.7}, 'local_densities': {'ADV': 0.359, 'ADP': 0.06}, 'cross_dist': 0.7, 'min_ratio': 1.951, 'difference': 9.752, 'split_quality_score': 0.181}
# {'lemma': 'avant', 'poses_compared': ('ADV', 'NOUN'), 'split_strength': 1.413, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 1.41, 'NOUN': 7.67}, 'local_densities': {'ADV': 0.359, 'NOUN': 0.066}, 'cross_dist': 0.507, 'min_ratio': 1.413, 'difference': 6.262, 'split_quality_score': 0.195}
# {'lemma': 'avant', 'poses_compared': ('ADP', 'NOUN'), 'split_strength': 12.039, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADP': 13.3, 'NOUN': 12.04}, 'local_densities': {'ADP': 0.06, 'NOUN': 0.066}, 'cross_dist': 0.795, 'min_ratio': 12.039, 'difference': 1.256, 'split_quality_score': 5.336}
# {'lemma': 'avoir', 'poses_compared': ('VERB', 'AUX'), 'split_strength': 2.133, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'VERB': 14.62, 'AUX': 2.13}, 'local_densities': {'VERB': 0.053, 'AUX': 0.361}, 'cross_dist': 0.771, 'min_ratio': 2.133, 'difference': 12.484, 'split_quality_score': 0.158}
# {'lemma': 'beaucoup', 'poses_compared': ('PRON', 'ADV'), 'split_strength': 1.552, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 1.55, 'ADV': 2.8}, 'local_densities': {'PRON': 0.296, 'ADV': 0.164}, 'cross_dist': 0.459, 'min_ratio': 1.552, 'difference': 1.252, 'split_quality_score': 0.689}
# {'lemma': 'bien', 'poses_compared': ('NOUN', 'ADV'), 'split_strength': 9.953, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 19.93, 'ADV': 9.95}, 'local_densities': {'NOUN': 0.031, 'ADV': 0.062}, 'cross_dist': 0.62, 'min_ratio': 9.953, 'difference': 9.978, 'split_quality_score': 0.907}
# {'lemma': 'blanc', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 4.996, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 5.0, 'ADJ': 18.6}, 'local_densities': {'NOUN': 0.077, 'ADJ': 0.021}, 'cross_dist': 0.386, 'min_ratio': 4.996, 'difference': 13.603, 'split_quality_score': 0.342}
# {'lemma': 'bref', 'poses_compared': ('INTJ', 'ADJ'), 'split_strength': 0.806, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'INTJ': 0.81, 'ADJ': 6.26}, 'local_densities': {'INTJ': 0.672, 'ADJ': 0.087}, 'cross_dist': 0.542, 'min_ratio': 0.806, 'difference': 5.452, 'split_quality_score': 0.125}
# {'lemma': 'britannique', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 9.432, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 9.43, 'ADJ': 63.59}, 'local_densities': {'NOUN': 0.072, 'ADJ': 0.011}, 'cross_dist': 0.678, 'min_ratio': 9.432, 'difference': 54.16, 'split_quality_score': 0.171}
# {'lemma': 'caractéristique', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 4.697, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 9.83, 'ADJ': 4.7}, 'local_densities': {'NOUN': 0.058, 'ADJ': 0.122}, 'cross_dist': 0.571, 'min_ratio': 4.697, 'difference': 5.136, 'split_quality_score': 0.765}
# {'lemma': 'ce', 'poses_compared': ('PRON', 'DET'), 'split_strength': 1.455, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 1.46, 'DET': 7.92}, 'local_densities': {'PRON': 0.311, 'DET': 0.057}, 'cross_dist': 0.452, 'min_ratio': 1.455, 'difference': 6.466, 'split_quality_score': 0.195}
# {'lemma': 'certain', 'poses_compared': ('DET', 'ADJ'), 'split_strength': 2.003, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'DET': 2.0, 'ADJ': 7.71}, 'local_densities': {'DET': 0.262, 'ADJ': 0.068}, 'cross_dist': 0.524, 'min_ratio': 2.003, 'difference': 5.711, 'split_quality_score': 0.298}
# {'lemma': 'certain', 'poses_compared': ('DET', 'PRON'), 'split_strength': 2.105, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'DET': 2.1, 'PRON': 2.34}, 'local_densities': {'DET': 0.262, 'PRON': 0.236}, 'cross_dist': 0.551, 'min_ratio': 2.105, 'difference': 0.233, 'split_quality_score': 1.708}
# {'lemma': 'certain', 'poses_compared': ('ADJ', 'PRON'), 'split_strength': 3.194, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADJ': 11.08, 'PRON': 3.19}, 'local_densities': {'ADJ': 0.068, 'PRON': 0.236}, 'cross_dist': 0.753, 'min_ratio': 3.194, 'difference': 7.886, 'split_quality_score': 0.359}
# {'lemma': 'chrétien', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 9.039, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 9.04, 'ADJ': 15.42}, 'local_densities': {'NOUN': 0.061, 'ADJ': 0.036}, 'cross_dist': 0.55, 'min_ratio': 9.039, 'difference': 6.383, 'split_quality_score': 1.224}
# {'lemma': 'comme', 'poses_compared': ('CCONJ', 'ADP'), 'split_strength': 1.045, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'CCONJ': 1.05, 'ADP': 3.59}, 'local_densities': {'CCONJ': 0.22, 'ADP': 0.064}, 'cross_dist': 0.23, 'min_ratio': 1.045, 'difference': 2.547, 'split_quality_score': 0.295}
# {'lemma': 'comme', 'poses_compared': ('CCONJ', 'SCONJ'), 'split_strength': 0.994, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'CCONJ': 0.99, 'SCONJ': 1.43}, 'local_densities': {'CCONJ': 0.22, 'SCONJ': 0.153}, 'cross_dist': 0.219, 'min_ratio': 0.994, 'difference': 0.435, 'split_quality_score': 0.692}
# {'lemma': 'comme', 'poses_compared': ('ADP', 'SCONJ'), 'split_strength': 1.509, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADP': 3.61, 'SCONJ': 1.51}, 'local_densities': {'ADP': 0.064, 'SCONJ': 0.153}, 'cross_dist': 0.231, 'min_ratio': 1.509, 'difference': 2.098, 'split_quality_score': 0.487}
# {'lemma': 'conseiller', 'poses_compared': ('VERB', 'NOUN'), 'split_strength': 3.636, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'VERB': 3.64, 'NOUN': 3.68}, 'local_densities': {'VERB': 0.133, 'NOUN': 0.131}, 'cross_dist': 0.482, 'min_ratio': 3.636, 'difference': 0.045, 'split_quality_score': 3.479}
# {'lemma': 'courant', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 6.832, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 14.68, 'ADJ': 6.83}, 'local_densities': {'NOUN': 0.035, 'ADJ': 0.075}, 'cross_dist': 0.511, 'min_ratio': 6.832, 'difference': 7.845, 'split_quality_score': 0.772}
# {'lemma': 'critique', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 13.48, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 13.48, 'ADJ': 15.16}, 'local_densities': {'NOUN': 0.037, 'ADJ': 0.033}, 'cross_dist': 0.499, 'min_ratio': 13.48, 'difference': 1.677, 'split_quality_score': 5.036}
# {'lemma': 'depuis', 'poses_compared': ('ADV', 'ADP'), 'split_strength': 3.117, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 3.12, 'ADP': 5.7}, 'local_densities': {'ADV': 0.181, 'ADP': 0.099}, 'cross_dist': 0.565, 'min_ratio': 3.117, 'difference': 2.584, 'split_quality_score': 0.87}
# {'lemma': 'différent', 'poses_compared': ('DET', 'ADJ'), 'split_strength': 1.199, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'DET': 1.2, 'ADJ': 1.84}, 'local_densities': {'DET': 0.256, 'ADJ': 0.167}, 'cross_dist': 0.307, 'min_ratio': 1.199, 'difference': 0.642, 'split_quality_score': 0.73}
# {'lemma': 'divers', 'poses_compared': ('DET', 'ADJ'), 'split_strength': 1.112, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'DET': 1.11, 'ADJ': 1.49}, 'local_densities': {'DET': 0.268, 'ADJ': 0.2}, 'cross_dist': 0.297, 'min_ratio': 1.112, 'difference': 0.374, 'split_quality_score': 0.809}
# {'lemma': 'donc', 'poses_compared': ('CCONJ', 'ADV'), 'split_strength': 2.68, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'CCONJ': 2.68, 'ADV': 12.94}, 'local_densities': {'CCONJ': 0.188, 'ADV': 0.039}, 'cross_dist': 0.504, 'min_ratio': 2.68, 'difference': 10.265, 'split_quality_score': 0.238}
# {'lemma': 'droit', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 18.52, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 18.52, 'ADJ': 43.27}, 'local_densities': {'NOUN': 0.032, 'ADJ': 0.014}, 'cross_dist': 0.592, 'min_ratio': 18.52, 'difference': 24.755, 'split_quality_score': 0.719}
# {'lemma': 'en', 'poses_compared': ('PRON', 'ADP'), 'split_strength': 2.459, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 2.96, 'ADP': 2.46}, 'local_densities': {'PRON': 0.162, 'ADP': 0.194}, 'cross_dist': 0.478, 'min_ratio': 2.459, 'difference': 0.499, 'split_quality_score': 1.641}
# {'lemma': 'ensemble', 'poses_compared': ('NOUN', 'ADV'), 'split_strength': 2.986, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 27.54, 'ADV': 2.99}, 'local_densities': {'NOUN': 0.023, 'ADV': 0.214}, 'cross_dist': 0.639, 'min_ratio': 2.986, 'difference': 24.551, 'split_quality_score': 0.117}
# {'lemma': 'espagnol', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 5.813, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 5.81, 'ADJ': 30.91}, 'local_densities': {'NOUN': 0.078, 'ADJ': 0.015}, 'cross_dist': 0.454, 'min_ratio': 5.813, 'difference': 25.097, 'split_quality_score': 0.223}
# {'lemma': 'essentiel', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 6.614, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 10.02, 'ADJ': 6.61}, 'local_densities': {'NOUN': 0.057, 'ADJ': 0.086}, 'cross_dist': 0.572, 'min_ratio': 6.614, 'difference': 3.408, 'split_quality_score': 1.5}
# {'lemma': 'extérieur', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 21.08, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 21.08, 'ADJ': 31.62}, 'local_densities': {'NOUN': 0.026, 'ADJ': 0.017}, 'cross_dist': 0.553, 'min_ratio': 21.08, 'difference': 10.536, 'split_quality_score': 1.827}
# {'lemma': 'faire', 'poses_compared': ('VERB', 'AUX'), 'split_strength': 1.487, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'VERB': 17.64, 'AUX': 1.49}, 'local_densities': {'VERB': 0.046, 'AUX': 0.55}, 'cross_dist': 0.819, 'min_ratio': 1.487, 'difference': 16.15, 'split_quality_score': 0.087}
# {'lemma': 'fort', 'poses_compared': ('ADV', 'ADJ'), 'split_strength': 3.349, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 3.35, 'ADJ': 6.82}, 'local_densities': {'ADV': 0.133, 'ADJ': 0.065}, 'cross_dist': 0.445, 'min_ratio': 3.349, 'difference': 3.468, 'split_quality_score': 0.75}
# {'lemma': 'fort', 'poses_compared': ('ADV', 'NOUN'), 'split_strength': 4.895, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 4.9, 'NOUN': 9.33}, 'local_densities': {'ADV': 0.133, 'NOUN': 0.07}, 'cross_dist': 0.65, 'min_ratio': 4.895, 'difference': 4.434, 'split_quality_score': 0.901}
# {'lemma': 'fort', 'poses_compared': ('ADJ', 'NOUN'), 'split_strength': 6.666, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADJ': 7.12, 'NOUN': 6.67}, 'local_densities': {'ADJ': 0.065, 'NOUN': 0.07}, 'cross_dist': 0.464, 'min_ratio': 6.666, 'difference': 0.453, 'split_quality_score': 4.587}
# {'lemma': 'français', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 9.63, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 9.63, 'ADJ': 56.91}, 'local_densities': {'NOUN': 0.058, 'ADJ': 0.01}, 'cross_dist': 0.557, 'min_ratio': 9.63, 'difference': 47.277, 'split_quality_score': 0.199}
# {'lemma': 'gauche', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 6.76, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 6.76, 'ADJ': 36.23}, 'local_densities': {'NOUN': 0.071, 'ADJ': 0.013}, 'cross_dist': 0.479, 'min_ratio': 6.76, 'difference': 29.473, 'split_quality_score': 0.222}
# {'lemma': 'grec', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 10.367, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 10.37, 'ADJ': 44.15}, 'local_densities': {'NOUN': 0.061, 'ADJ': 0.014}, 'cross_dist': 0.634, 'min_ratio': 10.367, 'difference': 33.778, 'split_quality_score': 0.298}
# {'lemma': 'général', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 14.657, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 14.66, 'ADJ': 43.64}, 'local_densities': {'NOUN': 0.04, 'ADJ': 0.013}, 'cross_dist': 0.587, 'min_ratio': 14.657, 'difference': 28.986, 'split_quality_score': 0.489}
# {'lemma': 'h', 'poses_compared': ('NUM', 'NOUN'), 'split_strength': 0.077, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NUM': 0.08, 'NOUN': 0.34}, 'local_densities': {'NUM': 0.398, 'NOUN': 0.091}, 'cross_dist': 0.031, 'min_ratio': 0.077, 'difference': 0.26, 'split_quality_score': 0.061}
# {'lemma': 'intérieur', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 26.239, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 26.24, 'ADJ': 55.26}, 'local_densities': {'NOUN': 0.025, 'ADJ': 0.012}, 'cross_dist': 0.644, 'min_ratio': 26.239, 'difference': 29.023, 'split_quality_score': 0.874}
# {'lemma': 'italien', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 7.255, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 7.26, 'ADJ': 50.16}, 'local_densities': {'NOUN': 0.071, 'ADJ': 0.01}, 'cross_dist': 0.516, 'min_ratio': 7.255, 'difference': 42.906, 'split_quality_score': 0.165}
# {'lemma': 'japonais', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 9.369, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 9.37, 'ADJ': 34.27}, 'local_densities': {'NOUN': 0.062, 'ADJ': 0.017}, 'cross_dist': 0.576, 'min_ratio': 9.369, 'difference': 24.902, 'split_quality_score': 0.362}
# {'lemma': 'jeune', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 13.355, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 13.55, 'ADJ': 13.35}, 'local_densities': {'NOUN': 0.039, 'ADJ': 0.039}, 'cross_dist': 0.524, 'min_ratio': 13.355, 'difference': 0.198, 'split_quality_score': 11.149}
# {'lemma': 'juif', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 9.789, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 9.79, 'ADJ': 41.04}, 'local_densities': {'NOUN': 0.059, 'ADJ': 0.014}, 'cross_dist': 0.579, 'min_ratio': 9.789, 'difference': 31.25, 'split_quality_score': 0.304}
# {'lemma': 'large', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 13.091, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 13.15, 'ADJ': 13.09}, 'local_densities': {'NOUN': 0.041, 'ADJ': 0.041}, 'cross_dist': 0.543, 'min_ratio': 13.091, 'difference': 0.055, 'split_quality_score': 12.403}
# {'lemma': 'latin', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 6.235, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 6.24, 'ADJ': 11.7}, 'local_densities': {'NOUN': 0.091, 'ADJ': 0.049}, 'cross_dist': 0.568, 'min_ratio': 6.235, 'difference': 5.466, 'split_quality_score': 0.964}
# {'lemma': 'long', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 2.824, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 2.82, 'ADJ': 11.51}, 'local_densities': {'NOUN': 0.223, 'ADJ': 0.055}, 'cross_dist': 0.63, 'min_ratio': 2.824, 'difference': 8.683, 'split_quality_score': 0.292}
# {'lemma': 'mal', 'poses_compared': ('NOUN', 'ADV'), 'split_strength': 6.695, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 9.82, 'ADV': 6.7}, 'local_densities': {'NOUN': 0.061, 'ADV': 0.09}, 'cross_dist': 0.6, 'min_ratio': 6.695, 'difference': 3.127, 'split_quality_score': 1.622}
# {'lemma': 'militaire', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 8.944, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 8.94, 'ADJ': 61.42}, 'local_densities': {'NOUN': 0.076, 'ADJ': 0.011}, 'cross_dist': 0.676, 'min_ratio': 8.944, 'difference': 52.478, 'split_quality_score': 0.167}
# {'lemma': 'moins', 'poses_compared': ('PRON', 'ADV'), 'split_strength': 1.8, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 1.8, 'ADV': 4.4}, 'local_densities': {'PRON': 0.354, 'ADV': 0.145}, 'cross_dist': 0.636, 'min_ratio': 1.8, 'difference': 2.6, 'split_quality_score': 0.5}
# {'lemma': 'mort', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 4.469, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 16.97, 'ADJ': 4.47}, 'local_densities': {'NOUN': 0.032, 'ADJ': 0.121}, 'cross_dist': 0.542, 'min_ratio': 4.469, 'difference': 12.501, 'split_quality_score': 0.331}
# {'lemma': 'moyen', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 6.356, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 12.7, 'ADJ': 6.36}, 'local_densities': {'NOUN': 0.043, 'ADJ': 0.087}, 'cross_dist': 0.552, 'min_ratio': 6.356, 'difference': 6.343, 'split_quality_score': 0.866}
# {'lemma': 'même', 'poses_compared': ('ADV', 'ADJ'), 'split_strength': 3.834, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 3.83, 'ADJ': 29.29}, 'local_densities': {'ADV': 0.136, 'ADJ': 0.018}, 'cross_dist': 0.521, 'min_ratio': 3.834, 'difference': 25.456, 'split_quality_score': 0.145}
# {'lemma': 'noir', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 3.996, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 4.0, 'ADJ': 23.51}, 'local_densities': {'NOUN': 0.122, 'ADJ': 0.021}, 'cross_dist': 0.489, 'min_ratio': 3.996, 'difference': 19.517, 'split_quality_score': 0.195}
# {'lemma': 'or', 'poses_compared': ('NOUN', 'CCONJ'), 'split_strength': 1.875, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 12.46, 'CCONJ': 1.88}, 'local_densities': {'NOUN': 0.062, 'CCONJ': 0.411}, 'cross_dist': 0.771, 'min_ratio': 1.875, 'difference': 10.58, 'split_quality_score': 0.162}
# {'lemma': 'personne', 'poses_compared': ('PRON', 'NOUN'), 'split_strength': 1.932, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 1.93, 'NOUN': 11.02}, 'local_densities': {'PRON': 0.328, 'NOUN': 0.057}, 'cross_dist': 0.633, 'min_ratio': 1.932, 'difference': 9.089, 'split_quality_score': 0.191}
# {'lemma': 'personnel', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 19.055, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 19.06, 'ADJ': 39.01}, 'local_densities': {'NOUN': 0.031, 'ADJ': 0.015}, 'cross_dist': 0.599, 'min_ratio': 19.055, 'difference': 19.951, 'split_quality_score': 0.91}
# {'lemma': 'peu', 'poses_compared': ('PRON', 'ADV'), 'split_strength': 1.172, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 1.17, 'ADV': 3.9}, 'local_densities': {'PRON': 0.384, 'ADV': 0.115}, 'cross_dist': 0.45, 'min_ratio': 1.172, 'difference': 2.727, 'split_quality_score': 0.314}
# {'lemma': 'physique', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 5.606, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 5.61, 'ADJ': 27.91}, 'local_densities': {'NOUN': 0.077, 'ADJ': 0.015}, 'cross_dist': 0.431, 'min_ratio': 5.606, 'difference': 22.308, 'split_quality_score': 0.241}
# {'lemma': 'plat', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 12.507, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 12.51, 'ADJ': 17.5}, 'local_densities': {'NOUN': 0.051, 'ADJ': 0.037}, 'cross_dist': 0.643, 'min_ratio': 12.507, 'difference': 4.992, 'split_quality_score': 2.087}
# {'lemma': 'plus', 'poses_compared': ('PRON', 'ADV'), 'split_strength': 2.167, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 2.17, 'ADV': 4.37}, 'local_densities': {'PRON': 0.333, 'ADV': 0.165}, 'cross_dist': 0.722, 'min_ratio': 2.167, 'difference': 2.204, 'split_quality_score': 0.676}
# {'lemma': 'plusieurs', 'poses_compared': ('PRON', 'DET'), 'split_strength': 2.194, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 2.19, 'DET': 3.02}, 'local_densities': {'PRON': 0.349, 'DET': 0.254}, 'cross_dist': 0.767, 'min_ratio': 2.194, 'difference': 0.83, 'split_quality_score': 1.199}
# {'lemma': 'policier', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 7.753, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 7.75, 'ADJ': 30.15}, 'local_densities': {'NOUN': 0.094, 'ADJ': 0.024}, 'cross_dist': 0.728, 'min_ratio': 7.753, 'difference': 22.393, 'split_quality_score': 0.331}
# {'lemma': 'politique', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 29.517, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 29.52, 'ADJ': 50.39}, 'local_densities': {'NOUN': 0.019, 'ADJ': 0.011}, 'cross_dist': 0.561, 'min_ratio': 29.517, 'difference': 20.872, 'split_quality_score': 1.35}
# {'lemma': 'pouvoir', 'poses_compared': ('VERB', 'NOUN'), 'split_strength': 5.098, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'VERB': 5.1, 'NOUN': 41.02}, 'local_densities': {'VERB': 0.134, 'NOUN': 0.017}, 'cross_dist': 0.684, 'min_ratio': 5.098, 'difference': 35.92, 'split_quality_score': 0.138}
# {'lemma': 'professionnel', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 6.043, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 6.04, 'ADJ': 23.32}, 'local_densities': {'NOUN': 0.077, 'ADJ': 0.02}, 'cross_dist': 0.463, 'min_ratio': 6.043, 'difference': 17.277, 'split_quality_score': 0.331}
# {'lemma': 'près', 'poses_compared': ('PRON', 'ADV'), 'split_strength': 0.52, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 0.52, 'ADV': 0.67}, 'local_densities': {'PRON': 0.363, 'ADV': 0.281}, 'cross_dist': 0.189, 'min_ratio': 0.52, 'difference': 0.152, 'split_quality_score': 0.451}
# {'lemma': 'public', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 17.283, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 17.28, 'ADJ': 54.12}, 'local_densities': {'NOUN': 0.035, 'ADJ': 0.011}, 'cross_dist': 0.613, 'min_ratio': 17.283, 'difference': 36.839, 'split_quality_score': 0.457}
# {'lemma': 'que', 'poses_compared': ('PRON', 'ADV'), 'split_strength': 2.105, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 2.11, 'ADV': 2.49}, 'local_densities': {'PRON': 0.247, 'ADV': 0.209}, 'cross_dist': 0.521, 'min_ratio': 2.105, 'difference': 0.386, 'split_quality_score': 1.519}
# {'lemma': 'que', 'poses_compared': ('PRON', 'SCONJ'), 'split_strength': 0.533, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'PRON': 0.53, 'SCONJ': 1.63}, 'local_densities': {'PRON': 0.247, 'SCONJ': 0.081}, 'cross_dist': 0.132, 'min_ratio': 0.533, 'difference': 1.096, 'split_quality_score': 0.254}
# {'lemma': 'que', 'poses_compared': ('ADV', 'SCONJ'), 'split_strength': 1.201, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 1.2, 'SCONJ': 3.1}, 'local_densities': {'ADV': 0.209, 'SCONJ': 0.081}, 'cross_dist': 0.251, 'min_ratio': 1.201, 'difference': 1.902, 'split_quality_score': 0.414}
# {'lemma': 'quel', 'poses_compared': ('DET', 'ADJ'), 'split_strength': 2.797, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'DET': 13.25, 'ADJ': 2.8}, 'local_densities': {'DET': 0.067, 'ADJ': 0.318}, 'cross_dist': 0.89, 'min_ratio': 2.797, 'difference': 10.453, 'split_quality_score': 0.244}
# {'lemma': 'responsable', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 4.008, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 12.57, 'ADJ': 4.01}, 'local_densities': {'NOUN': 0.04, 'ADJ': 0.125}, 'cross_dist': 0.503, 'min_ratio': 4.008, 'difference': 8.561, 'split_quality_score': 0.419}
# {'lemma': 'romain', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 10.997, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 11.0, 'ADJ': 56.87}, 'local_densities': {'NOUN': 0.063, 'ADJ': 0.012}, 'cross_dist': 0.688, 'min_ratio': 10.997, 'difference': 45.877, 'split_quality_score': 0.235}
# {'lemma': 'roman', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 17.38, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 17.38, 'ADJ': 19.54}, 'local_densities': {'NOUN': 0.031, 'ADJ': 0.027}, 'cross_dist': 0.531, 'min_ratio': 17.38, 'difference': 2.165, 'split_quality_score': 5.491}
# {'lemma': 'savoir', 'poses_compared': ('VERB', 'NOUN'), 'split_strength': 6.94, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'VERB': 6.94, 'NOUN': 15.76}, 'local_densities': {'VERB': 0.09, 'NOUN': 0.04}, 'cross_dist': 0.623, 'min_ratio': 6.94, 'difference': 8.824, 'split_quality_score': 0.706}
# {'lemma': 'scientifique', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 4.726, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 4.73, 'ADJ': 48.04}, 'local_densities': {'NOUN': 0.125, 'ADJ': 0.012}, 'cross_dist': 0.589, 'min_ratio': 4.726, 'difference': 43.318, 'split_quality_score': 0.107}
# {'lemma': 'second', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 5.872, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 5.87, 'ADJ': 23.49}, 'local_densities': {'NOUN': 0.071, 'ADJ': 0.018}, 'cross_dist': 0.416, 'min_ratio': 5.872, 'difference': 17.613, 'split_quality_score': 0.315}
# {'lemma': 'si', 'poses_compared': ('SCONJ', 'ADV'), 'split_strength': 3.002, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'SCONJ': 11.57, 'ADV': 3.0}, 'local_densities': {'SCONJ': 0.047, 'ADV': 0.18}, 'cross_dist': 0.541, 'min_ratio': 3.002, 'difference': 8.569, 'split_quality_score': 0.314}
# {'lemma': 'soit', 'poses_compared': ('CCONJ', 'ADV'), 'split_strength': 0.434, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'CCONJ': 1.17, 'ADV': 0.43}, 'local_densities': {'CCONJ': 0.147, 'ADV': 0.396}, 'cross_dist': 0.172, 'min_ratio': 0.434, 'difference': 0.738, 'split_quality_score': 0.25}
# {'lemma': 'son', 'poses_compared': ('NOUN', 'DET'), 'split_strength': 12.931, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 16.65, 'DET': 12.93}, 'local_densities': {'NOUN': 0.042, 'DET': 0.053}, 'cross_dist': 0.692, 'min_ratio': 12.931, 'difference': 3.721, 'split_quality_score': 2.739}
# {'lemma': 'suivant', 'poses_compared': ('ADP', 'ADJ'), 'split_strength': 7.737, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADP': 7.74, 'ADJ': 23.98}, 'local_densities': {'ADP': 0.075, 'ADJ': 0.024}, 'cross_dist': 0.58, 'min_ratio': 7.737, 'difference': 16.241, 'split_quality_score': 0.449}
# {'lemma': 'technique', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 18.69, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 18.69, 'ADJ': 21.78}, 'local_densities': {'NOUN': 0.03, 'ADJ': 0.025}, 'cross_dist': 0.555, 'min_ratio': 18.69, 'difference': 3.092, 'split_quality_score': 4.568}
# {'lemma': 'tel', 'poses_compared': ('DET', 'ADJ'), 'split_strength': 2.085, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'DET': 4.34, 'ADJ': 2.09}, 'local_densities': {'DET': 0.103, 'ADJ': 0.215}, 'cross_dist': 0.448, 'min_ratio': 2.085, 'difference': 2.255, 'split_quality_score': 0.641}
# {'lemma': 'total', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 15.869, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 15.87, 'ADJ': 48.83}, 'local_densities': {'NOUN': 0.041, 'ADJ': 0.013}, 'cross_dist': 0.643, 'min_ratio': 15.869, 'difference': 32.96, 'split_quality_score': 0.467}
# {'lemma': 'tout', 'poses_compared': ('ADV', 'ADJ'), 'split_strength': 1.19, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 2.5, 'ADJ': 1.19}, 'local_densities': {'ADV': 0.217, 'ADJ': 0.457}, 'cross_dist': 0.543, 'min_ratio': 1.19, 'difference': 1.311, 'split_quality_score': 0.515}
# {'lemma': 'tout', 'poses_compared': ('ADV', 'DET'), 'split_strength': 2.349, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 2.35, 'DET': 5.99}, 'local_densities': {'ADV': 0.217, 'DET': 0.085}, 'cross_dist': 0.51, 'min_ratio': 2.349, 'difference': 3.643, 'split_quality_score': 0.506}
# {'lemma': 'tout', 'poses_compared': ('ADV', 'PRON'), 'split_strength': 1.664, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADV': 1.67, 'PRON': 1.66}, 'local_densities': {'ADV': 0.217, 'PRON': 0.218}, 'cross_dist': 0.362, 'min_ratio': 1.664, 'difference': 0.005, 'split_quality_score': 1.655}
# {'lemma': 'tout', 'poses_compared': ('ADJ', 'DET'), 'split_strength': 0.798, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADJ': 0.8, 'DET': 4.28}, 'local_densities': {'ADJ': 0.457, 'DET': 0.085}, 'cross_dist': 0.364, 'min_ratio': 0.798, 'difference': 3.48, 'split_quality_score': 0.178}
# {'lemma': 'tout', 'poses_compared': ('ADJ', 'PRON'), 'split_strength': 1.265, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'ADJ': 1.26, 'PRON': 2.65}, 'local_densities': {'ADJ': 0.457, 'PRON': 0.218}, 'cross_dist': 0.577, 'min_ratio': 1.265, 'difference': 1.386, 'split_quality_score': 0.53}
# {'lemma': 'tout', 'poses_compared': ('DET', 'PRON'), 'split_strength': 2.492, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'DET': 6.38, 'PRON': 2.49}, 'local_densities': {'DET': 0.085, 'PRON': 0.218}, 'cross_dist': 0.543, 'min_ratio': 2.492, 'difference': 3.884, 'split_quality_score': 0.51}
# {'lemma': 'un', 'poses_compared': ('NUM', 'DET'), 'split_strength': 0.145, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NUM': 0.14, 'DET': 1.13}, 'local_densities': {'NUM': 0.36, 'DET': 0.046}, 'cross_dist': 0.052, 'min_ratio': 0.145, 'difference': 0.981, 'split_quality_score': 0.073}
# {'lemma': 'un', 'poses_compared': ('NUM', 'PRON'), 'split_strength': 1.988, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NUM': 2.17, 'PRON': 1.99}, 'local_densities': {'NUM': 0.36, 'PRON': 0.392}, 'cross_dist': 0.779, 'min_ratio': 1.988, 'difference': 0.18, 'split_quality_score': 1.685}
# {'lemma': 'un', 'poses_compared': ('DET', 'PRON'), 'split_strength': 2.055, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'DET': 17.4, 'PRON': 2.05}, 'local_densities': {'DET': 0.046, 'PRON': 0.392}, 'cross_dist': 0.806, 'min_ratio': 2.055, 'difference': 15.347, 'split_quality_score': 0.126}
# {'lemma': 'vidéo', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 2.858, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 2.86, 'ADJ': 12.66}, 'local_densities': {'NOUN': 0.115, 'ADJ': 0.026}, 'cross_dist': 0.329, 'min_ratio': 2.858, 'difference': 9.801, 'split_quality_score': 0.265}
# {'lemma': 'voisin', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 4.441, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 4.44, 'ADJ': 13.13}, 'local_densities': {'NOUN': 0.127, 'ADJ': 0.043}, 'cross_dist': 0.566, 'min_ratio': 4.441, 'difference': 8.69, 'split_quality_score': 0.458}
# {'lemma': 'étranger', 'poses_compared': ('NOUN', 'ADJ'), 'split_strength': 14.395, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'NOUN': 14.39, 'ADJ': 15.09}, 'local_densities': {'NOUN': 0.049, 'ADJ': 0.047}, 'cross_dist': 0.707, 'min_ratio': 14.395, 'difference': 0.695, 'split_quality_score': 8.494}
# {'lemma': 'être', 'poses_compared': ('VERB', 'AUX'), 'split_strength': 2.126, 'interpretation': 'High = Clear Split | Low = Merged/Noisy', 'ratios': {'VERB': 11.99, 'AUX': 2.13}, 'local_densities': {'VERB': 0.061, 'AUX': 0.343}, 'cross_dist': 0.73, 'min_ratio': 2.126, 'difference': 9.863, 'split_quality_score': 0.196}

# %%
results = []
for lemma, poses in polycategorial_lexunits.items():
    result = check_robust_split(matrix, idx_to_unit, unit_to_idx, lemma, poses, k_neighbors=20, metric='cosine')
    for dico in result:
        results.extend(result)

# %%
results
# Out:
# [{'lemma': '/',
#   'poses_compared': ('CCONJ', 'ADP'),
#   'split_strength': 0.489,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 0.49, 'ADP': 0.58},
#   'local_densities': {'CCONJ': 0.303, 'ADP': 0.255},
#   'cross_dist': 0.148,
#   'min_ratio': 0.489,
#   'difference': 0.092,
#   'split_quality_score': 0.448},
#  {'lemma': '1er',
#   'poses_compared': ('NUM', 'ADJ'),
#   'split_strength': 6.156,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NUM': 6.16, 'ADJ': 6.7},
#   'local_densities': {'NUM': 0.05, 'ADJ': 0.046},
#   'cross_dist': 0.306,
#   'min_ratio': 6.156,
#   'difference': 0.549,
#   'split_quality_score': 3.974},
#  {'lemma': 'allemand',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 8.209,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 8.21, 'ADJ': 49.03},
#   'local_densities': {'NOUN': 0.066, 'ADJ': 0.011},
#   'cross_dist': 0.541,
#   'min_ratio': 8.209,
#   'difference': 40.818,
#   'split_quality_score': 0.196},
#  {'lemma': 'américain',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 8.558,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 8.56, 'ADJ': 57.61},
#   'local_densities': {'NOUN': 0.082, 'ADJ': 0.012},
#   'cross_dist': 0.702,
#   'min_ratio': 8.558,
#   'difference': 49.056,
#   'split_quality_score': 0.171},
#  {'lemma': 'anglais',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 5.969,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 5.97, 'ADJ': 28.9},
#   'local_densities': {'NOUN': 0.082, 'ADJ': 0.017},
#   'cross_dist': 0.489,
#   'min_ratio': 5.969,
#   'difference': 22.933,
#   'split_quality_score': 0.249},
#  {'lemma': 'après',
#   'poses_compared': ('ADV', 'ADP'),
#   'split_strength': 2.301,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.3, 'ADP': 7.82},
#   'local_densities': {'ADV': 0.252, 'ADP': 0.074},
#   'cross_dist': 0.58,
#   'min_ratio': 2.301,
#   'difference': 5.521,
#   'split_quality_score': 0.353},
#  {'lemma': 'arabe',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 6.164,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 6.16, 'ADJ': 38.21},
#   'local_densities': {'NOUN': 0.098, 'ADJ': 0.016},
#   'cross_dist': 0.602,
#   'min_ratio': 6.164,
#   'difference': 32.049,
#   'split_quality_score': 0.187},
#  {'lemma': 'aucun',
#   'poses_compared': ('PRON', 'DET'),
#   'split_strength': 2.14,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 2.14, 'DET': 8.38},
#   'local_densities': {'PRON': 0.308, 'DET': 0.079},
#   'cross_dist': 0.659,
#   'min_ratio': 2.14,
#   'difference': 6.238,
#   'split_quality_score': 0.296},
#  {'lemma': 'autant',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 1.179,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 1.18, 'ADV': 1.88},
#   'local_densities': {'PRON': 0.378, 'ADV': 0.236},
#   'cross_dist': 0.446,
#   'min_ratio': 1.179,
#   'difference': 0.706,
#   'split_quality_score': 0.691},
#  {'lemma': 'autre',
#   'poses_compared': ('PRON', 'ADJ'),
#   'split_strength': 1.133,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 1.13, 'ADJ': 5.49},
#   'local_densities': {'PRON': 0.488, 'ADJ': 0.101},
#   'cross_dist': 0.553,
#   'min_ratio': 1.133,
#   'difference': 4.362,
#   'split_quality_score': 0.211},
#  {'lemma': 'avant',
#   'poses_compared': ('ADV', 'ADP'),
#   'split_strength': 1.951,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.95, 'ADP': 11.7},
#   'local_densities': {'ADV': 0.359, 'ADP': 0.06},
#   'cross_dist': 0.7,
#   'min_ratio': 1.951,
#   'difference': 9.752,
#   'split_quality_score': 0.181},
#  {'lemma': 'avant',
#   'poses_compared': ('ADV', 'NOUN'),
#   'split_strength': 1.413,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.41, 'NOUN': 7.67},
#   'local_densities': {'ADV': 0.359, 'NOUN': 0.066},
#   'cross_dist': 0.507,
#   'min_ratio': 1.413,
#   'difference': 6.262,
#   'split_quality_score': 0.195},
#  {'lemma': 'avant',
#   'poses_compared': ('ADP', 'NOUN'),
#   'split_strength': 12.039,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADP': 13.3, 'NOUN': 12.04},
#   'local_densities': {'ADP': 0.06, 'NOUN': 0.066},
#   'cross_dist': 0.795,
#   'min_ratio': 12.039,
#   'difference': 1.256,
#   'split_quality_score': 5.336},
#  {'lemma': 'avant',
#   'poses_compared': ('ADV', 'ADP'),
#   'split_strength': 1.951,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.95, 'ADP': 11.7},
#   'local_densities': {'ADV': 0.359, 'ADP': 0.06},
#   'cross_dist': 0.7,
#   'min_ratio': 1.951,
#   'difference': 9.752,
#   'split_quality_score': 0.181},
#  {'lemma': 'avant',
#   'poses_compared': ('ADV', 'NOUN'),
#   'split_strength': 1.413,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.41, 'NOUN': 7.67},
#   'local_densities': {'ADV': 0.359, 'NOUN': 0.066},
#   'cross_dist': 0.507,
#   'min_ratio': 1.413,
#   'difference': 6.262,
#   'split_quality_score': 0.195},
#  {'lemma': 'avant',
#   'poses_compared': ('ADP', 'NOUN'),
#   'split_strength': 12.039,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADP': 13.3, 'NOUN': 12.04},
#   'local_densities': {'ADP': 0.06, 'NOUN': 0.066},
#   'cross_dist': 0.795,
#   'min_ratio': 12.039,
#   'difference': 1.256,
#   'split_quality_score': 5.336},
#  {'lemma': 'avant',
#   'poses_compared': ('ADV', 'ADP'),
#   'split_strength': 1.951,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.95, 'ADP': 11.7},
#   'local_densities': {'ADV': 0.359, 'ADP': 0.06},
#   'cross_dist': 0.7,
#   'min_ratio': 1.951,
#   'difference': 9.752,
#   'split_quality_score': 0.181},
#  {'lemma': 'avant',
#   'poses_compared': ('ADV', 'NOUN'),
#   'split_strength': 1.413,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.41, 'NOUN': 7.67},
#   'local_densities': {'ADV': 0.359, 'NOUN': 0.066},
#   'cross_dist': 0.507,
#   'min_ratio': 1.413,
#   'difference': 6.262,
#   'split_quality_score': 0.195},
#  {'lemma': 'avant',
#   'poses_compared': ('ADP', 'NOUN'),
#   'split_strength': 12.039,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADP': 13.3, 'NOUN': 12.04},
#   'local_densities': {'ADP': 0.06, 'NOUN': 0.066},
#   'cross_dist': 0.795,
#   'min_ratio': 12.039,
#   'difference': 1.256,
#   'split_quality_score': 5.336},
#  {'lemma': 'avoir',
#   'poses_compared': ('VERB', 'AUX'),
#   'split_strength': 2.133,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'VERB': 14.62, 'AUX': 2.13},
#   'local_densities': {'VERB': 0.053, 'AUX': 0.361},
#   'cross_dist': 0.771,
#   'min_ratio': 2.133,
#   'difference': 12.484,
#   'split_quality_score': 0.158},
#  {'lemma': 'beaucoup',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 1.552,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 1.55, 'ADV': 2.8},
#   'local_densities': {'PRON': 0.296, 'ADV': 0.164},
#   'cross_dist': 0.459,
#   'min_ratio': 1.552,
#   'difference': 1.252,
#   'split_quality_score': 0.689},
#  {'lemma': 'bien',
#   'poses_compared': ('NOUN', 'ADV'),
#   'split_strength': 9.953,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 19.93, 'ADV': 9.95},
#   'local_densities': {'NOUN': 0.031, 'ADV': 0.062},
#   'cross_dist': 0.62,
#   'min_ratio': 9.953,
#   'difference': 9.978,
#   'split_quality_score': 0.907},
#  {'lemma': 'blanc',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 4.996,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 5.0, 'ADJ': 18.6},
#   'local_densities': {'NOUN': 0.077, 'ADJ': 0.021},
#   'cross_dist': 0.386,
#   'min_ratio': 4.996,
#   'difference': 13.603,
#   'split_quality_score': 0.342},
#  {'lemma': 'bref',
#   'poses_compared': ('INTJ', 'ADJ'),
#   'split_strength': 0.806,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'INTJ': 0.81, 'ADJ': 6.26},
#   'local_densities': {'INTJ': 0.672, 'ADJ': 0.087},
#   'cross_dist': 0.542,
#   'min_ratio': 0.806,
#   'difference': 5.452,
#   'split_quality_score': 0.125},
#  {'lemma': 'britannique',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 9.432,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 9.43, 'ADJ': 63.59},
#   'local_densities': {'NOUN': 0.072, 'ADJ': 0.011},
#   'cross_dist': 0.678,
#   'min_ratio': 9.432,
#   'difference': 54.16,
#   'split_quality_score': 0.171},
#  {'lemma': 'caractéristique',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 4.697,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 9.83, 'ADJ': 4.7},
#   'local_densities': {'NOUN': 0.058, 'ADJ': 0.122},
#   'cross_dist': 0.571,
#   'min_ratio': 4.697,
#   'difference': 5.136,
#   'split_quality_score': 0.765},
#  {'lemma': 'ce',
#   'poses_compared': ('PRON', 'DET'),
#   'split_strength': 1.455,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 1.46, 'DET': 7.92},
#   'local_densities': {'PRON': 0.311, 'DET': 0.057},
#   'cross_dist': 0.452,
#   'min_ratio': 1.455,
#   'difference': 6.466,
#   'split_quality_score': 0.195},
#  {'lemma': 'certain',
#   'poses_compared': ('DET', 'ADJ'),
#   'split_strength': 2.003,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 2.0, 'ADJ': 7.71},
#   'local_densities': {'DET': 0.262, 'ADJ': 0.068},
#   'cross_dist': 0.524,
#   'min_ratio': 2.003,
#   'difference': 5.711,
#   'split_quality_score': 0.298},
#  {'lemma': 'certain',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.105,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 2.1, 'PRON': 2.34},
#   'local_densities': {'DET': 0.262, 'PRON': 0.236},
#   'cross_dist': 0.551,
#   'min_ratio': 2.105,
#   'difference': 0.233,
#   'split_quality_score': 1.708},
#  {'lemma': 'certain',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 3.194,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 11.08, 'PRON': 3.19},
#   'local_densities': {'ADJ': 0.068, 'PRON': 0.236},
#   'cross_dist': 0.753,
#   'min_ratio': 3.194,
#   'difference': 7.886,
#   'split_quality_score': 0.359},
#  {'lemma': 'certain',
#   'poses_compared': ('DET', 'ADJ'),
#   'split_strength': 2.003,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 2.0, 'ADJ': 7.71},
#   'local_densities': {'DET': 0.262, 'ADJ': 0.068},
#   'cross_dist': 0.524,
#   'min_ratio': 2.003,
#   'difference': 5.711,
#   'split_quality_score': 0.298},
#  {'lemma': 'certain',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.105,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 2.1, 'PRON': 2.34},
#   'local_densities': {'DET': 0.262, 'PRON': 0.236},
#   'cross_dist': 0.551,
#   'min_ratio': 2.105,
#   'difference': 0.233,
#   'split_quality_score': 1.708},
#  {'lemma': 'certain',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 3.194,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 11.08, 'PRON': 3.19},
#   'local_densities': {'ADJ': 0.068, 'PRON': 0.236},
#   'cross_dist': 0.753,
#   'min_ratio': 3.194,
#   'difference': 7.886,
#   'split_quality_score': 0.359},
#  {'lemma': 'certain',
#   'poses_compared': ('DET', 'ADJ'),
#   'split_strength': 2.003,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 2.0, 'ADJ': 7.71},
#   'local_densities': {'DET': 0.262, 'ADJ': 0.068},
#   'cross_dist': 0.524,
#   'min_ratio': 2.003,
#   'difference': 5.711,
#   'split_quality_score': 0.298},
#  {'lemma': 'certain',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.105,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 2.1, 'PRON': 2.34},
#   'local_densities': {'DET': 0.262, 'PRON': 0.236},
#   'cross_dist': 0.551,
#   'min_ratio': 2.105,
#   'difference': 0.233,
#   'split_quality_score': 1.708},
#  {'lemma': 'certain',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 3.194,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 11.08, 'PRON': 3.19},
#   'local_densities': {'ADJ': 0.068, 'PRON': 0.236},
#   'cross_dist': 0.753,
#   'min_ratio': 3.194,
#   'difference': 7.886,
#   'split_quality_score': 0.359},
#  {'lemma': 'chrétien',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 9.039,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 9.04, 'ADJ': 15.42},
#   'local_densities': {'NOUN': 0.061, 'ADJ': 0.036},
#   'cross_dist': 0.55,
#   'min_ratio': 9.039,
#   'difference': 6.383,
#   'split_quality_score': 1.224},
#  {'lemma': 'comme',
#   'poses_compared': ('CCONJ', 'ADP'),
#   'split_strength': 1.045,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 1.05, 'ADP': 3.59},
#   'local_densities': {'CCONJ': 0.22, 'ADP': 0.064},
#   'cross_dist': 0.23,
#   'min_ratio': 1.045,
#   'difference': 2.547,
#   'split_quality_score': 0.295},
#  {'lemma': 'comme',
#   'poses_compared': ('CCONJ', 'SCONJ'),
#   'split_strength': 0.994,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 0.99, 'SCONJ': 1.43},
#   'local_densities': {'CCONJ': 0.22, 'SCONJ': 0.153},
#   'cross_dist': 0.219,
#   'min_ratio': 0.994,
#   'difference': 0.435,
#   'split_quality_score': 0.692},
#  {'lemma': 'comme',
#   'poses_compared': ('ADP', 'SCONJ'),
#   'split_strength': 1.509,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADP': 3.61, 'SCONJ': 1.51},
#   'local_densities': {'ADP': 0.064, 'SCONJ': 0.153},
#   'cross_dist': 0.231,
#   'min_ratio': 1.509,
#   'difference': 2.098,
#   'split_quality_score': 0.487},
#  {'lemma': 'comme',
#   'poses_compared': ('CCONJ', 'ADP'),
#   'split_strength': 1.045,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 1.05, 'ADP': 3.59},
#   'local_densities': {'CCONJ': 0.22, 'ADP': 0.064},
#   'cross_dist': 0.23,
#   'min_ratio': 1.045,
#   'difference': 2.547,
#   'split_quality_score': 0.295},
#  {'lemma': 'comme',
#   'poses_compared': ('CCONJ', 'SCONJ'),
#   'split_strength': 0.994,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 0.99, 'SCONJ': 1.43},
#   'local_densities': {'CCONJ': 0.22, 'SCONJ': 0.153},
#   'cross_dist': 0.219,
#   'min_ratio': 0.994,
#   'difference': 0.435,
#   'split_quality_score': 0.692},
#  {'lemma': 'comme',
#   'poses_compared': ('ADP', 'SCONJ'),
#   'split_strength': 1.509,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADP': 3.61, 'SCONJ': 1.51},
#   'local_densities': {'ADP': 0.064, 'SCONJ': 0.153},
#   'cross_dist': 0.231,
#   'min_ratio': 1.509,
#   'difference': 2.098,
#   'split_quality_score': 0.487},
#  {'lemma': 'comme',
#   'poses_compared': ('CCONJ', 'ADP'),
#   'split_strength': 1.045,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 1.05, 'ADP': 3.59},
#   'local_densities': {'CCONJ': 0.22, 'ADP': 0.064},
#   'cross_dist': 0.23,
#   'min_ratio': 1.045,
#   'difference': 2.547,
#   'split_quality_score': 0.295},
#  {'lemma': 'comme',
#   'poses_compared': ('CCONJ', 'SCONJ'),
#   'split_strength': 0.994,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 0.99, 'SCONJ': 1.43},
#   'local_densities': {'CCONJ': 0.22, 'SCONJ': 0.153},
#   'cross_dist': 0.219,
#   'min_ratio': 0.994,
#   'difference': 0.435,
#   'split_quality_score': 0.692},
#  {'lemma': 'comme',
#   'poses_compared': ('ADP', 'SCONJ'),
#   'split_strength': 1.509,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADP': 3.61, 'SCONJ': 1.51},
#   'local_densities': {'ADP': 0.064, 'SCONJ': 0.153},
#   'cross_dist': 0.231,
#   'min_ratio': 1.509,
#   'difference': 2.098,
#   'split_quality_score': 0.487},
#  {'lemma': 'conseiller',
#   'poses_compared': ('VERB', 'NOUN'),
#   'split_strength': 3.636,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'VERB': 3.64, 'NOUN': 3.68},
#   'local_densities': {'VERB': 0.133, 'NOUN': 0.131},
#   'cross_dist': 0.482,
#   'min_ratio': 3.636,
#   'difference': 0.045,
#   'split_quality_score': 3.479},
#  {'lemma': 'courant',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 6.832,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 14.68, 'ADJ': 6.83},
#   'local_densities': {'NOUN': 0.035, 'ADJ': 0.075},
#   'cross_dist': 0.511,
#   'min_ratio': 6.832,
#   'difference': 7.845,
#   'split_quality_score': 0.772},
#  {'lemma': 'critique',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 13.48,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 13.48, 'ADJ': 15.16},
#   'local_densities': {'NOUN': 0.037, 'ADJ': 0.033},
#   'cross_dist': 0.499,
#   'min_ratio': 13.48,
#   'difference': 1.677,
#   'split_quality_score': 5.036},
#  {'lemma': 'depuis',
#   'poses_compared': ('ADV', 'ADP'),
#   'split_strength': 3.117,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 3.12, 'ADP': 5.7},
#   'local_densities': {'ADV': 0.181, 'ADP': 0.099},
#   'cross_dist': 0.565,
#   'min_ratio': 3.117,
#   'difference': 2.584,
#   'split_quality_score': 0.87},
#  {'lemma': 'différent',
#   'poses_compared': ('DET', 'ADJ'),
#   'split_strength': 1.199,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 1.2, 'ADJ': 1.84},
#   'local_densities': {'DET': 0.256, 'ADJ': 0.167},
#   'cross_dist': 0.307,
#   'min_ratio': 1.199,
#   'difference': 0.642,
#   'split_quality_score': 0.73},
#  {'lemma': 'divers',
#   'poses_compared': ('DET', 'ADJ'),
#   'split_strength': 1.112,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 1.11, 'ADJ': 1.49},
#   'local_densities': {'DET': 0.268, 'ADJ': 0.2},
#   'cross_dist': 0.297,
#   'min_ratio': 1.112,
#   'difference': 0.374,
#   'split_quality_score': 0.809},
#  {'lemma': 'donc',
#   'poses_compared': ('CCONJ', 'ADV'),
#   'split_strength': 2.68,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 2.68, 'ADV': 12.94},
#   'local_densities': {'CCONJ': 0.188, 'ADV': 0.039},
#   'cross_dist': 0.504,
#   'min_ratio': 2.68,
#   'difference': 10.265,
#   'split_quality_score': 0.238},
#  {'lemma': 'droit',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 18.52,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 18.52, 'ADJ': 43.27},
#   'local_densities': {'NOUN': 0.032, 'ADJ': 0.014},
#   'cross_dist': 0.592,
#   'min_ratio': 18.52,
#   'difference': 24.755,
#   'split_quality_score': 0.719},
#  {'lemma': 'en',
#   'poses_compared': ('PRON', 'ADP'),
#   'split_strength': 2.459,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 2.96, 'ADP': 2.46},
#   'local_densities': {'PRON': 0.162, 'ADP': 0.194},
#   'cross_dist': 0.478,
#   'min_ratio': 2.459,
#   'difference': 0.499,
#   'split_quality_score': 1.641},
#  {'lemma': 'ensemble',
#   'poses_compared': ('NOUN', 'ADV'),
#   'split_strength': 2.986,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 27.54, 'ADV': 2.99},
#   'local_densities': {'NOUN': 0.023, 'ADV': 0.214},
#   'cross_dist': 0.639,
#   'min_ratio': 2.986,
#   'difference': 24.551,
#   'split_quality_score': 0.117},
#  {'lemma': 'espagnol',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 5.813,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 5.81, 'ADJ': 30.91},
#   'local_densities': {'NOUN': 0.078, 'ADJ': 0.015},
#   'cross_dist': 0.454,
#   'min_ratio': 5.813,
#   'difference': 25.097,
#   'split_quality_score': 0.223},
#  {'lemma': 'essentiel',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 6.614,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 10.02, 'ADJ': 6.61},
#   'local_densities': {'NOUN': 0.057, 'ADJ': 0.086},
#   'cross_dist': 0.572,
#   'min_ratio': 6.614,
#   'difference': 3.408,
#   'split_quality_score': 1.5},
#  {'lemma': 'extérieur',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 21.08,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 21.08, 'ADJ': 31.62},
#   'local_densities': {'NOUN': 0.026, 'ADJ': 0.017},
#   'cross_dist': 0.553,
#   'min_ratio': 21.08,
#   'difference': 10.536,
#   'split_quality_score': 1.827},
#  {'lemma': 'faire',
#   'poses_compared': ('VERB', 'AUX'),
#   'split_strength': 1.487,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'VERB': 17.64, 'AUX': 1.49},
#   'local_densities': {'VERB': 0.046, 'AUX': 0.55},
#   'cross_dist': 0.819,
#   'min_ratio': 1.487,
#   'difference': 16.15,
#   'split_quality_score': 0.087},
#  {'lemma': 'fort',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 3.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 3.35, 'ADJ': 6.82},
#   'local_densities': {'ADV': 0.133, 'ADJ': 0.065},
#   'cross_dist': 0.445,
#   'min_ratio': 3.349,
#   'difference': 3.468,
#   'split_quality_score': 0.75},
#  {'lemma': 'fort',
#   'poses_compared': ('ADV', 'NOUN'),
#   'split_strength': 4.895,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 4.9, 'NOUN': 9.33},
#   'local_densities': {'ADV': 0.133, 'NOUN': 0.07},
#   'cross_dist': 0.65,
#   'min_ratio': 4.895,
#   'difference': 4.434,
#   'split_quality_score': 0.901},
#  {'lemma': 'fort',
#   'poses_compared': ('ADJ', 'NOUN'),
#   'split_strength': 6.666,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 7.12, 'NOUN': 6.67},
#   'local_densities': {'ADJ': 0.065, 'NOUN': 0.07},
#   'cross_dist': 0.464,
#   'min_ratio': 6.666,
#   'difference': 0.453,
#   'split_quality_score': 4.587},
#  {'lemma': 'fort',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 3.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 3.35, 'ADJ': 6.82},
#   'local_densities': {'ADV': 0.133, 'ADJ': 0.065},
#   'cross_dist': 0.445,
#   'min_ratio': 3.349,
#   'difference': 3.468,
#   'split_quality_score': 0.75},
#  {'lemma': 'fort',
#   'poses_compared': ('ADV', 'NOUN'),
#   'split_strength': 4.895,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 4.9, 'NOUN': 9.33},
#   'local_densities': {'ADV': 0.133, 'NOUN': 0.07},
#   'cross_dist': 0.65,
#   'min_ratio': 4.895,
#   'difference': 4.434,
#   'split_quality_score': 0.901},
#  {'lemma': 'fort',
#   'poses_compared': ('ADJ', 'NOUN'),
#   'split_strength': 6.666,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 7.12, 'NOUN': 6.67},
#   'local_densities': {'ADJ': 0.065, 'NOUN': 0.07},
#   'cross_dist': 0.464,
#   'min_ratio': 6.666,
#   'difference': 0.453,
#   'split_quality_score': 4.587},
#  {'lemma': 'fort',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 3.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 3.35, 'ADJ': 6.82},
#   'local_densities': {'ADV': 0.133, 'ADJ': 0.065},
#   'cross_dist': 0.445,
#   'min_ratio': 3.349,
#   'difference': 3.468,
#   'split_quality_score': 0.75},
#  {'lemma': 'fort',
#   'poses_compared': ('ADV', 'NOUN'),
#   'split_strength': 4.895,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 4.9, 'NOUN': 9.33},
#   'local_densities': {'ADV': 0.133, 'NOUN': 0.07},
#   'cross_dist': 0.65,
#   'min_ratio': 4.895,
#   'difference': 4.434,
#   'split_quality_score': 0.901},
#  {'lemma': 'fort',
#   'poses_compared': ('ADJ', 'NOUN'),
#   'split_strength': 6.666,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 7.12, 'NOUN': 6.67},
#   'local_densities': {'ADJ': 0.065, 'NOUN': 0.07},
#   'cross_dist': 0.464,
#   'min_ratio': 6.666,
#   'difference': 0.453,
#   'split_quality_score': 4.587},
#  {'lemma': 'français',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 9.63,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 9.63, 'ADJ': 56.91},
#   'local_densities': {'NOUN': 0.058, 'ADJ': 0.01},
#   'cross_dist': 0.557,
#   'min_ratio': 9.63,
#   'difference': 47.277,
#   'split_quality_score': 0.199},
#  {'lemma': 'gauche',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 6.76,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 6.76, 'ADJ': 36.23},
#   'local_densities': {'NOUN': 0.071, 'ADJ': 0.013},
#   'cross_dist': 0.479,
#   'min_ratio': 6.76,
#   'difference': 29.473,
#   'split_quality_score': 0.222},
#  {'lemma': 'grec',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 10.367,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 10.37, 'ADJ': 44.15},
#   'local_densities': {'NOUN': 0.061, 'ADJ': 0.014},
#   'cross_dist': 0.634,
#   'min_ratio': 10.367,
#   'difference': 33.778,
#   'split_quality_score': 0.298},
#  {'lemma': 'général',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 14.657,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 14.66, 'ADJ': 43.64},
#   'local_densities': {'NOUN': 0.04, 'ADJ': 0.013},
#   'cross_dist': 0.587,
#   'min_ratio': 14.657,
#   'difference': 28.986,
#   'split_quality_score': 0.489},
#  {'lemma': 'h',
#   'poses_compared': ('NUM', 'NOUN'),
#   'split_strength': 0.077,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NUM': 0.08, 'NOUN': 0.34},
#   'local_densities': {'NUM': 0.398, 'NOUN': 0.091},
#   'cross_dist': 0.031,
#   'min_ratio': 0.077,
#   'difference': 0.26,
#   'split_quality_score': 0.061},
#  {'lemma': 'intérieur',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 26.239,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 26.24, 'ADJ': 55.26},
#   'local_densities': {'NOUN': 0.025, 'ADJ': 0.012},
#   'cross_dist': 0.644,
#   'min_ratio': 26.239,
#   'difference': 29.023,
#   'split_quality_score': 0.874},
#  {'lemma': 'italien',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 7.255,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 7.26, 'ADJ': 50.16},
#   'local_densities': {'NOUN': 0.071, 'ADJ': 0.01},
#   'cross_dist': 0.516,
#   'min_ratio': 7.255,
#   'difference': 42.906,
#   'split_quality_score': 0.165},
#  {'lemma': 'japonais',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 9.369,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 9.37, 'ADJ': 34.27},
#   'local_densities': {'NOUN': 0.062, 'ADJ': 0.017},
#   'cross_dist': 0.576,
#   'min_ratio': 9.369,
#   'difference': 24.902,
#   'split_quality_score': 0.362},
#  {'lemma': 'jeune',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 13.355,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 13.55, 'ADJ': 13.35},
#   'local_densities': {'NOUN': 0.039, 'ADJ': 0.039},
#   'cross_dist': 0.524,
#   'min_ratio': 13.355,
#   'difference': 0.198,
#   'split_quality_score': 11.149},
#  {'lemma': 'juif',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 9.789,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 9.79, 'ADJ': 41.04},
#   'local_densities': {'NOUN': 0.059, 'ADJ': 0.014},
#   'cross_dist': 0.579,
#   'min_ratio': 9.789,
#   'difference': 31.25,
#   'split_quality_score': 0.304},
#  {'lemma': 'large',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 13.091,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 13.15, 'ADJ': 13.09},
#   'local_densities': {'NOUN': 0.041, 'ADJ': 0.041},
#   'cross_dist': 0.543,
#   'min_ratio': 13.091,
#   'difference': 0.055,
#   'split_quality_score': 12.403},
#  {'lemma': 'latin',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 6.235,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 6.24, 'ADJ': 11.7},
#   'local_densities': {'NOUN': 0.091, 'ADJ': 0.049},
#   'cross_dist': 0.568,
#   'min_ratio': 6.235,
#   'difference': 5.466,
#   'split_quality_score': 0.964},
#  {'lemma': 'long',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 2.824,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 2.82, 'ADJ': 11.51},
#   'local_densities': {'NOUN': 0.223, 'ADJ': 0.055},
#   'cross_dist': 0.63,
#   'min_ratio': 2.824,
#   'difference': 8.683,
#   'split_quality_score': 0.292},
#  {'lemma': 'mal',
#   'poses_compared': ('NOUN', 'ADV'),
#   'split_strength': 6.695,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 9.82, 'ADV': 6.7},
#   'local_densities': {'NOUN': 0.061, 'ADV': 0.09},
#   'cross_dist': 0.6,
#   'min_ratio': 6.695,
#   'difference': 3.127,
#   'split_quality_score': 1.622},
#  {'lemma': 'militaire',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 8.944,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 8.94, 'ADJ': 61.42},
#   'local_densities': {'NOUN': 0.076, 'ADJ': 0.011},
#   'cross_dist': 0.676,
#   'min_ratio': 8.944,
#   'difference': 52.478,
#   'split_quality_score': 0.167},
#  {'lemma': 'moins',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 1.8,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 1.8, 'ADV': 4.4},
#   'local_densities': {'PRON': 0.354, 'ADV': 0.145},
#   'cross_dist': 0.636,
#   'min_ratio': 1.8,
#   'difference': 2.6,
#   'split_quality_score': 0.5},
#  {'lemma': 'mort',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 4.469,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 16.97, 'ADJ': 4.47},
#   'local_densities': {'NOUN': 0.032, 'ADJ': 0.121},
#   'cross_dist': 0.542,
#   'min_ratio': 4.469,
#   'difference': 12.501,
#   'split_quality_score': 0.331},
#  {'lemma': 'moyen',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 6.356,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 12.7, 'ADJ': 6.36},
#   'local_densities': {'NOUN': 0.043, 'ADJ': 0.087},
#   'cross_dist': 0.552,
#   'min_ratio': 6.356,
#   'difference': 6.343,
#   'split_quality_score': 0.866},
#  {'lemma': 'même',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 3.834,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 3.83, 'ADJ': 29.29},
#   'local_densities': {'ADV': 0.136, 'ADJ': 0.018},
#   'cross_dist': 0.521,
#   'min_ratio': 3.834,
#   'difference': 25.456,
#   'split_quality_score': 0.145},
#  {'lemma': 'noir',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 3.996,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 4.0, 'ADJ': 23.51},
#   'local_densities': {'NOUN': 0.122, 'ADJ': 0.021},
#   'cross_dist': 0.489,
#   'min_ratio': 3.996,
#   'difference': 19.517,
#   'split_quality_score': 0.195},
#  {'lemma': 'or',
#   'poses_compared': ('NOUN', 'CCONJ'),
#   'split_strength': 1.875,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 12.46, 'CCONJ': 1.88},
#   'local_densities': {'NOUN': 0.062, 'CCONJ': 0.411},
#   'cross_dist': 0.771,
#   'min_ratio': 1.875,
#   'difference': 10.58,
#   'split_quality_score': 0.162},
#  {'lemma': 'personne',
#   'poses_compared': ('PRON', 'NOUN'),
#   'split_strength': 1.932,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 1.93, 'NOUN': 11.02},
#   'local_densities': {'PRON': 0.328, 'NOUN': 0.057},
#   'cross_dist': 0.633,
#   'min_ratio': 1.932,
#   'difference': 9.089,
#   'split_quality_score': 0.191},
#  {'lemma': 'personnel',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 19.055,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 19.06, 'ADJ': 39.01},
#   'local_densities': {'NOUN': 0.031, 'ADJ': 0.015},
#   'cross_dist': 0.599,
#   'min_ratio': 19.055,
#   'difference': 19.951,
#   'split_quality_score': 0.91},
#  {'lemma': 'peu',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 1.172,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 1.17, 'ADV': 3.9},
#   'local_densities': {'PRON': 0.384, 'ADV': 0.115},
#   'cross_dist': 0.45,
#   'min_ratio': 1.172,
#   'difference': 2.727,
#   'split_quality_score': 0.314},
#  {'lemma': 'physique',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 5.606,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 5.61, 'ADJ': 27.91},
#   'local_densities': {'NOUN': 0.077, 'ADJ': 0.015},
#   'cross_dist': 0.431,
#   'min_ratio': 5.606,
#   'difference': 22.308,
#   'split_quality_score': 0.241},
#  {'lemma': 'plat',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 12.507,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 12.51, 'ADJ': 17.5},
#   'local_densities': {'NOUN': 0.051, 'ADJ': 0.037},
#   'cross_dist': 0.643,
#   'min_ratio': 12.507,
#   'difference': 4.992,
#   'split_quality_score': 2.087},
#  {'lemma': 'plus',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 2.167,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 2.17, 'ADV': 4.37},
#   'local_densities': {'PRON': 0.333, 'ADV': 0.165},
#   'cross_dist': 0.722,
#   'min_ratio': 2.167,
#   'difference': 2.204,
#   'split_quality_score': 0.676},
#  {'lemma': 'plusieurs',
#   'poses_compared': ('PRON', 'DET'),
#   'split_strength': 2.194,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 2.19, 'DET': 3.02},
#   'local_densities': {'PRON': 0.349, 'DET': 0.254},
#   'cross_dist': 0.767,
#   'min_ratio': 2.194,
#   'difference': 0.83,
#   'split_quality_score': 1.199},
#  {'lemma': 'policier',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 7.753,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 7.75, 'ADJ': 30.15},
#   'local_densities': {'NOUN': 0.094, 'ADJ': 0.024},
#   'cross_dist': 0.728,
#   'min_ratio': 7.753,
#   'difference': 22.393,
#   'split_quality_score': 0.331},
#  {'lemma': 'politique',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 29.517,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 29.52, 'ADJ': 50.39},
#   'local_densities': {'NOUN': 0.019, 'ADJ': 0.011},
#   'cross_dist': 0.561,
#   'min_ratio': 29.517,
#   'difference': 20.872,
#   'split_quality_score': 1.35},
#  {'lemma': 'pouvoir',
#   'poses_compared': ('VERB', 'NOUN'),
#   'split_strength': 5.098,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'VERB': 5.1, 'NOUN': 41.02},
#   'local_densities': {'VERB': 0.134, 'NOUN': 0.017},
#   'cross_dist': 0.684,
#   'min_ratio': 5.098,
#   'difference': 35.92,
#   'split_quality_score': 0.138},
#  {'lemma': 'professionnel',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 6.043,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 6.04, 'ADJ': 23.32},
#   'local_densities': {'NOUN': 0.077, 'ADJ': 0.02},
#   'cross_dist': 0.463,
#   'min_ratio': 6.043,
#   'difference': 17.277,
#   'split_quality_score': 0.331},
#  {'lemma': 'près',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 0.52,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 0.52, 'ADV': 0.67},
#   'local_densities': {'PRON': 0.363, 'ADV': 0.281},
#   'cross_dist': 0.189,
#   'min_ratio': 0.52,
#   'difference': 0.152,
#   'split_quality_score': 0.451},
#  {'lemma': 'public',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 17.283,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 17.28, 'ADJ': 54.12},
#   'local_densities': {'NOUN': 0.035, 'ADJ': 0.011},
#   'cross_dist': 0.613,
#   'min_ratio': 17.283,
#   'difference': 36.839,
#   'split_quality_score': 0.457},
#  {'lemma': 'que',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 2.105,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 2.11, 'ADV': 2.49},
#   'local_densities': {'PRON': 0.247, 'ADV': 0.209},
#   'cross_dist': 0.521,
#   'min_ratio': 2.105,
#   'difference': 0.386,
#   'split_quality_score': 1.519},
#  {'lemma': 'que',
#   'poses_compared': ('PRON', 'SCONJ'),
#   'split_strength': 0.533,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 0.53, 'SCONJ': 1.63},
#   'local_densities': {'PRON': 0.247, 'SCONJ': 0.081},
#   'cross_dist': 0.132,
#   'min_ratio': 0.533,
#   'difference': 1.096,
#   'split_quality_score': 0.254},
#  {'lemma': 'que',
#   'poses_compared': ('ADV', 'SCONJ'),
#   'split_strength': 1.201,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.2, 'SCONJ': 3.1},
#   'local_densities': {'ADV': 0.209, 'SCONJ': 0.081},
#   'cross_dist': 0.251,
#   'min_ratio': 1.201,
#   'difference': 1.902,
#   'split_quality_score': 0.414},
#  {'lemma': 'que',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 2.105,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 2.11, 'ADV': 2.49},
#   'local_densities': {'PRON': 0.247, 'ADV': 0.209},
#   'cross_dist': 0.521,
#   'min_ratio': 2.105,
#   'difference': 0.386,
#   'split_quality_score': 1.519},
#  {'lemma': 'que',
#   'poses_compared': ('PRON', 'SCONJ'),
#   'split_strength': 0.533,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 0.53, 'SCONJ': 1.63},
#   'local_densities': {'PRON': 0.247, 'SCONJ': 0.081},
#   'cross_dist': 0.132,
#   'min_ratio': 0.533,
#   'difference': 1.096,
#   'split_quality_score': 0.254},
#  {'lemma': 'que',
#   'poses_compared': ('ADV', 'SCONJ'),
#   'split_strength': 1.201,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.2, 'SCONJ': 3.1},
#   'local_densities': {'ADV': 0.209, 'SCONJ': 0.081},
#   'cross_dist': 0.251,
#   'min_ratio': 1.201,
#   'difference': 1.902,
#   'split_quality_score': 0.414},
#  {'lemma': 'que',
#   'poses_compared': ('PRON', 'ADV'),
#   'split_strength': 2.105,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 2.11, 'ADV': 2.49},
#   'local_densities': {'PRON': 0.247, 'ADV': 0.209},
#   'cross_dist': 0.521,
#   'min_ratio': 2.105,
#   'difference': 0.386,
#   'split_quality_score': 1.519},
#  {'lemma': 'que',
#   'poses_compared': ('PRON', 'SCONJ'),
#   'split_strength': 0.533,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'PRON': 0.53, 'SCONJ': 1.63},
#   'local_densities': {'PRON': 0.247, 'SCONJ': 0.081},
#   'cross_dist': 0.132,
#   'min_ratio': 0.533,
#   'difference': 1.096,
#   'split_quality_score': 0.254},
#  {'lemma': 'que',
#   'poses_compared': ('ADV', 'SCONJ'),
#   'split_strength': 1.201,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.2, 'SCONJ': 3.1},
#   'local_densities': {'ADV': 0.209, 'SCONJ': 0.081},
#   'cross_dist': 0.251,
#   'min_ratio': 1.201,
#   'difference': 1.902,
#   'split_quality_score': 0.414},
#  {'lemma': 'quel',
#   'poses_compared': ('DET', 'ADJ'),
#   'split_strength': 2.797,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 13.25, 'ADJ': 2.8},
#   'local_densities': {'DET': 0.067, 'ADJ': 0.318},
#   'cross_dist': 0.89,
#   'min_ratio': 2.797,
#   'difference': 10.453,
#   'split_quality_score': 0.244},
#  {'lemma': 'responsable',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 4.008,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 12.57, 'ADJ': 4.01},
#   'local_densities': {'NOUN': 0.04, 'ADJ': 0.125},
#   'cross_dist': 0.503,
#   'min_ratio': 4.008,
#   'difference': 8.561,
#   'split_quality_score': 0.419},
#  {'lemma': 'romain',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 10.997,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 11.0, 'ADJ': 56.87},
#   'local_densities': {'NOUN': 0.063, 'ADJ': 0.012},
#   'cross_dist': 0.688,
#   'min_ratio': 10.997,
#   'difference': 45.877,
#   'split_quality_score': 0.235},
#  {'lemma': 'roman',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 17.38,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 17.38, 'ADJ': 19.54},
#   'local_densities': {'NOUN': 0.031, 'ADJ': 0.027},
#   'cross_dist': 0.531,
#   'min_ratio': 17.38,
#   'difference': 2.165,
#   'split_quality_score': 5.491},
#  {'lemma': 'savoir',
#   'poses_compared': ('VERB', 'NOUN'),
#   'split_strength': 6.94,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'VERB': 6.94, 'NOUN': 15.76},
#   'local_densities': {'VERB': 0.09, 'NOUN': 0.04},
#   'cross_dist': 0.623,
#   'min_ratio': 6.94,
#   'difference': 8.824,
#   'split_quality_score': 0.706},
#  {'lemma': 'scientifique',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 4.726,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 4.73, 'ADJ': 48.04},
#   'local_densities': {'NOUN': 0.125, 'ADJ': 0.012},
#   'cross_dist': 0.589,
#   'min_ratio': 4.726,
#   'difference': 43.318,
#   'split_quality_score': 0.107},
#  {'lemma': 'second',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 5.872,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 5.87, 'ADJ': 23.49},
#   'local_densities': {'NOUN': 0.071, 'ADJ': 0.018},
#   'cross_dist': 0.416,
#   'min_ratio': 5.872,
#   'difference': 17.613,
#   'split_quality_score': 0.315},
#  {'lemma': 'si',
#   'poses_compared': ('SCONJ', 'ADV'),
#   'split_strength': 3.002,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'SCONJ': 11.57, 'ADV': 3.0},
#   'local_densities': {'SCONJ': 0.047, 'ADV': 0.18},
#   'cross_dist': 0.541,
#   'min_ratio': 3.002,
#   'difference': 8.569,
#   'split_quality_score': 0.314},
#  {'lemma': 'soit',
#   'poses_compared': ('CCONJ', 'ADV'),
#   'split_strength': 0.434,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'CCONJ': 1.17, 'ADV': 0.43},
#   'local_densities': {'CCONJ': 0.147, 'ADV': 0.396},
#   'cross_dist': 0.172,
#   'min_ratio': 0.434,
#   'difference': 0.738,
#   'split_quality_score': 0.25},
#  {'lemma': 'son',
#   'poses_compared': ('NOUN', 'DET'),
#   'split_strength': 12.931,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 16.65, 'DET': 12.93},
#   'local_densities': {'NOUN': 0.042, 'DET': 0.053},
#   'cross_dist': 0.692,
#   'min_ratio': 12.931,
#   'difference': 3.721,
#   'split_quality_score': 2.739},
#  {'lemma': 'suivant',
#   'poses_compared': ('ADP', 'ADJ'),
#   'split_strength': 7.737,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADP': 7.74, 'ADJ': 23.98},
#   'local_densities': {'ADP': 0.075, 'ADJ': 0.024},
#   'cross_dist': 0.58,
#   'min_ratio': 7.737,
#   'difference': 16.241,
#   'split_quality_score': 0.449},
#  {'lemma': 'technique',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 18.69,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 18.69, 'ADJ': 21.78},
#   'local_densities': {'NOUN': 0.03, 'ADJ': 0.025},
#   'cross_dist': 0.555,
#   'min_ratio': 18.69,
#   'difference': 3.092,
#   'split_quality_score': 4.568},
#  {'lemma': 'tel',
#   'poses_compared': ('DET', 'ADJ'),
#   'split_strength': 2.085,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 4.34, 'ADJ': 2.09},
#   'local_densities': {'DET': 0.103, 'ADJ': 0.215},
#   'cross_dist': 0.448,
#   'min_ratio': 2.085,
#   'difference': 2.255,
#   'split_quality_score': 0.641},
#  {'lemma': 'total',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 15.869,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 15.87, 'ADJ': 48.83},
#   'local_densities': {'NOUN': 0.041, 'ADJ': 0.013},
#   'cross_dist': 0.643,
#   'min_ratio': 15.869,
#   'difference': 32.96,
#   'split_quality_score': 0.467},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 1.19,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.5, 'ADJ': 1.19},
#   'local_densities': {'ADV': 0.217, 'ADJ': 0.457},
#   'cross_dist': 0.543,
#   'min_ratio': 1.19,
#   'difference': 1.311,
#   'split_quality_score': 0.515},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'DET'),
#   'split_strength': 2.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.35, 'DET': 5.99},
#   'local_densities': {'ADV': 0.217, 'DET': 0.085},
#   'cross_dist': 0.51,
#   'min_ratio': 2.349,
#   'difference': 3.643,
#   'split_quality_score': 0.506},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'PRON'),
#   'split_strength': 1.664,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.67, 'PRON': 1.66},
#   'local_densities': {'ADV': 0.217, 'PRON': 0.218},
#   'cross_dist': 0.362,
#   'min_ratio': 1.664,
#   'difference': 0.005,
#   'split_quality_score': 1.655},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'DET'),
#   'split_strength': 0.798,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 0.8, 'DET': 4.28},
#   'local_densities': {'ADJ': 0.457, 'DET': 0.085},
#   'cross_dist': 0.364,
#   'min_ratio': 0.798,
#   'difference': 3.48,
#   'split_quality_score': 0.178},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 1.265,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 1.26, 'PRON': 2.65},
#   'local_densities': {'ADJ': 0.457, 'PRON': 0.218},
#   'cross_dist': 0.577,
#   'min_ratio': 1.265,
#   'difference': 1.386,
#   'split_quality_score': 0.53},
#  {'lemma': 'tout',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.492,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 6.38, 'PRON': 2.49},
#   'local_densities': {'DET': 0.085, 'PRON': 0.218},
#   'cross_dist': 0.543,
#   'min_ratio': 2.492,
#   'difference': 3.884,
#   'split_quality_score': 0.51},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 1.19,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.5, 'ADJ': 1.19},
#   'local_densities': {'ADV': 0.217, 'ADJ': 0.457},
#   'cross_dist': 0.543,
#   'min_ratio': 1.19,
#   'difference': 1.311,
#   'split_quality_score': 0.515},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'DET'),
#   'split_strength': 2.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.35, 'DET': 5.99},
#   'local_densities': {'ADV': 0.217, 'DET': 0.085},
#   'cross_dist': 0.51,
#   'min_ratio': 2.349,
#   'difference': 3.643,
#   'split_quality_score': 0.506},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'PRON'),
#   'split_strength': 1.664,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.67, 'PRON': 1.66},
#   'local_densities': {'ADV': 0.217, 'PRON': 0.218},
#   'cross_dist': 0.362,
#   'min_ratio': 1.664,
#   'difference': 0.005,
#   'split_quality_score': 1.655},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'DET'),
#   'split_strength': 0.798,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 0.8, 'DET': 4.28},
#   'local_densities': {'ADJ': 0.457, 'DET': 0.085},
#   'cross_dist': 0.364,
#   'min_ratio': 0.798,
#   'difference': 3.48,
#   'split_quality_score': 0.178},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 1.265,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 1.26, 'PRON': 2.65},
#   'local_densities': {'ADJ': 0.457, 'PRON': 0.218},
#   'cross_dist': 0.577,
#   'min_ratio': 1.265,
#   'difference': 1.386,
#   'split_quality_score': 0.53},
#  {'lemma': 'tout',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.492,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 6.38, 'PRON': 2.49},
#   'local_densities': {'DET': 0.085, 'PRON': 0.218},
#   'cross_dist': 0.543,
#   'min_ratio': 2.492,
#   'difference': 3.884,
#   'split_quality_score': 0.51},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 1.19,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.5, 'ADJ': 1.19},
#   'local_densities': {'ADV': 0.217, 'ADJ': 0.457},
#   'cross_dist': 0.543,
#   'min_ratio': 1.19,
#   'difference': 1.311,
#   'split_quality_score': 0.515},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'DET'),
#   'split_strength': 2.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.35, 'DET': 5.99},
#   'local_densities': {'ADV': 0.217, 'DET': 0.085},
#   'cross_dist': 0.51,
#   'min_ratio': 2.349,
#   'difference': 3.643,
#   'split_quality_score': 0.506},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'PRON'),
#   'split_strength': 1.664,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.67, 'PRON': 1.66},
#   'local_densities': {'ADV': 0.217, 'PRON': 0.218},
#   'cross_dist': 0.362,
#   'min_ratio': 1.664,
#   'difference': 0.005,
#   'split_quality_score': 1.655},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'DET'),
#   'split_strength': 0.798,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 0.8, 'DET': 4.28},
#   'local_densities': {'ADJ': 0.457, 'DET': 0.085},
#   'cross_dist': 0.364,
#   'min_ratio': 0.798,
#   'difference': 3.48,
#   'split_quality_score': 0.178},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 1.265,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 1.26, 'PRON': 2.65},
#   'local_densities': {'ADJ': 0.457, 'PRON': 0.218},
#   'cross_dist': 0.577,
#   'min_ratio': 1.265,
#   'difference': 1.386,
#   'split_quality_score': 0.53},
#  {'lemma': 'tout',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.492,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 6.38, 'PRON': 2.49},
#   'local_densities': {'DET': 0.085, 'PRON': 0.218},
#   'cross_dist': 0.543,
#   'min_ratio': 2.492,
#   'difference': 3.884,
#   'split_quality_score': 0.51},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 1.19,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.5, 'ADJ': 1.19},
#   'local_densities': {'ADV': 0.217, 'ADJ': 0.457},
#   'cross_dist': 0.543,
#   'min_ratio': 1.19,
#   'difference': 1.311,
#   'split_quality_score': 0.515},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'DET'),
#   'split_strength': 2.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.35, 'DET': 5.99},
#   'local_densities': {'ADV': 0.217, 'DET': 0.085},
#   'cross_dist': 0.51,
#   'min_ratio': 2.349,
#   'difference': 3.643,
#   'split_quality_score': 0.506},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'PRON'),
#   'split_strength': 1.664,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.67, 'PRON': 1.66},
#   'local_densities': {'ADV': 0.217, 'PRON': 0.218},
#   'cross_dist': 0.362,
#   'min_ratio': 1.664,
#   'difference': 0.005,
#   'split_quality_score': 1.655},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'DET'),
#   'split_strength': 0.798,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 0.8, 'DET': 4.28},
#   'local_densities': {'ADJ': 0.457, 'DET': 0.085},
#   'cross_dist': 0.364,
#   'min_ratio': 0.798,
#   'difference': 3.48,
#   'split_quality_score': 0.178},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 1.265,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 1.26, 'PRON': 2.65},
#   'local_densities': {'ADJ': 0.457, 'PRON': 0.218},
#   'cross_dist': 0.577,
#   'min_ratio': 1.265,
#   'difference': 1.386,
#   'split_quality_score': 0.53},
#  {'lemma': 'tout',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.492,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 6.38, 'PRON': 2.49},
#   'local_densities': {'DET': 0.085, 'PRON': 0.218},
#   'cross_dist': 0.543,
#   'min_ratio': 2.492,
#   'difference': 3.884,
#   'split_quality_score': 0.51},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 1.19,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.5, 'ADJ': 1.19},
#   'local_densities': {'ADV': 0.217, 'ADJ': 0.457},
#   'cross_dist': 0.543,
#   'min_ratio': 1.19,
#   'difference': 1.311,
#   'split_quality_score': 0.515},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'DET'),
#   'split_strength': 2.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.35, 'DET': 5.99},
#   'local_densities': {'ADV': 0.217, 'DET': 0.085},
#   'cross_dist': 0.51,
#   'min_ratio': 2.349,
#   'difference': 3.643,
#   'split_quality_score': 0.506},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'PRON'),
#   'split_strength': 1.664,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.67, 'PRON': 1.66},
#   'local_densities': {'ADV': 0.217, 'PRON': 0.218},
#   'cross_dist': 0.362,
#   'min_ratio': 1.664,
#   'difference': 0.005,
#   'split_quality_score': 1.655},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'DET'),
#   'split_strength': 0.798,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 0.8, 'DET': 4.28},
#   'local_densities': {'ADJ': 0.457, 'DET': 0.085},
#   'cross_dist': 0.364,
#   'min_ratio': 0.798,
#   'difference': 3.48,
#   'split_quality_score': 0.178},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 1.265,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 1.26, 'PRON': 2.65},
#   'local_densities': {'ADJ': 0.457, 'PRON': 0.218},
#   'cross_dist': 0.577,
#   'min_ratio': 1.265,
#   'difference': 1.386,
#   'split_quality_score': 0.53},
#  {'lemma': 'tout',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.492,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 6.38, 'PRON': 2.49},
#   'local_densities': {'DET': 0.085, 'PRON': 0.218},
#   'cross_dist': 0.543,
#   'min_ratio': 2.492,
#   'difference': 3.884,
#   'split_quality_score': 0.51},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'ADJ'),
#   'split_strength': 1.19,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.5, 'ADJ': 1.19},
#   'local_densities': {'ADV': 0.217, 'ADJ': 0.457},
#   'cross_dist': 0.543,
#   'min_ratio': 1.19,
#   'difference': 1.311,
#   'split_quality_score': 0.515},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'DET'),
#   'split_strength': 2.349,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 2.35, 'DET': 5.99},
#   'local_densities': {'ADV': 0.217, 'DET': 0.085},
#   'cross_dist': 0.51,
#   'min_ratio': 2.349,
#   'difference': 3.643,
#   'split_quality_score': 0.506},
#  {'lemma': 'tout',
#   'poses_compared': ('ADV', 'PRON'),
#   'split_strength': 1.664,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADV': 1.67, 'PRON': 1.66},
#   'local_densities': {'ADV': 0.217, 'PRON': 0.218},
#   'cross_dist': 0.362,
#   'min_ratio': 1.664,
#   'difference': 0.005,
#   'split_quality_score': 1.655},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'DET'),
#   'split_strength': 0.798,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 0.8, 'DET': 4.28},
#   'local_densities': {'ADJ': 0.457, 'DET': 0.085},
#   'cross_dist': 0.364,
#   'min_ratio': 0.798,
#   'difference': 3.48,
#   'split_quality_score': 0.178},
#  {'lemma': 'tout',
#   'poses_compared': ('ADJ', 'PRON'),
#   'split_strength': 1.265,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'ADJ': 1.26, 'PRON': 2.65},
#   'local_densities': {'ADJ': 0.457, 'PRON': 0.218},
#   'cross_dist': 0.577,
#   'min_ratio': 1.265,
#   'difference': 1.386,
#   'split_quality_score': 0.53},
#  {'lemma': 'tout',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.492,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 6.38, 'PRON': 2.49},
#   'local_densities': {'DET': 0.085, 'PRON': 0.218},
#   'cross_dist': 0.543,
#   'min_ratio': 2.492,
#   'difference': 3.884,
#   'split_quality_score': 0.51},
#  {'lemma': 'un',
#   'poses_compared': ('NUM', 'DET'),
#   'split_strength': 0.145,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NUM': 0.14, 'DET': 1.13},
#   'local_densities': {'NUM': 0.36, 'DET': 0.046},
#   'cross_dist': 0.052,
#   'min_ratio': 0.145,
#   'difference': 0.981,
#   'split_quality_score': 0.073},
#  {'lemma': 'un',
#   'poses_compared': ('NUM', 'PRON'),
#   'split_strength': 1.988,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NUM': 2.17, 'PRON': 1.99},
#   'local_densities': {'NUM': 0.36, 'PRON': 0.392},
#   'cross_dist': 0.779,
#   'min_ratio': 1.988,
#   'difference': 0.18,
#   'split_quality_score': 1.685},
#  {'lemma': 'un',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.055,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 17.4, 'PRON': 2.05},
#   'local_densities': {'DET': 0.046, 'PRON': 0.392},
#   'cross_dist': 0.806,
#   'min_ratio': 2.055,
#   'difference': 15.347,
#   'split_quality_score': 0.126},
#  {'lemma': 'un',
#   'poses_compared': ('NUM', 'DET'),
#   'split_strength': 0.145,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NUM': 0.14, 'DET': 1.13},
#   'local_densities': {'NUM': 0.36, 'DET': 0.046},
#   'cross_dist': 0.052,
#   'min_ratio': 0.145,
#   'difference': 0.981,
#   'split_quality_score': 0.073},
#  {'lemma': 'un',
#   'poses_compared': ('NUM', 'PRON'),
#   'split_strength': 1.988,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NUM': 2.17, 'PRON': 1.99},
#   'local_densities': {'NUM': 0.36, 'PRON': 0.392},
#   'cross_dist': 0.779,
#   'min_ratio': 1.988,
#   'difference': 0.18,
#   'split_quality_score': 1.685},
#  {'lemma': 'un',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.055,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 17.4, 'PRON': 2.05},
#   'local_densities': {'DET': 0.046, 'PRON': 0.392},
#   'cross_dist': 0.806,
#   'min_ratio': 2.055,
#   'difference': 15.347,
#   'split_quality_score': 0.126},
#  {'lemma': 'un',
#   'poses_compared': ('NUM', 'DET'),
#   'split_strength': 0.145,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NUM': 0.14, 'DET': 1.13},
#   'local_densities': {'NUM': 0.36, 'DET': 0.046},
#   'cross_dist': 0.052,
#   'min_ratio': 0.145,
#   'difference': 0.981,
#   'split_quality_score': 0.073},
#  {'lemma': 'un',
#   'poses_compared': ('NUM', 'PRON'),
#   'split_strength': 1.988,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NUM': 2.17, 'PRON': 1.99},
#   'local_densities': {'NUM': 0.36, 'PRON': 0.392},
#   'cross_dist': 0.779,
#   'min_ratio': 1.988,
#   'difference': 0.18,
#   'split_quality_score': 1.685},
#  {'lemma': 'un',
#   'poses_compared': ('DET', 'PRON'),
#   'split_strength': 2.055,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'DET': 17.4, 'PRON': 2.05},
#   'local_densities': {'DET': 0.046, 'PRON': 0.392},
#   'cross_dist': 0.806,
#   'min_ratio': 2.055,
#   'difference': 15.347,
#   'split_quality_score': 0.126},
#  {'lemma': 'vidéo',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 2.858,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 2.86, 'ADJ': 12.66},
#   'local_densities': {'NOUN': 0.115, 'ADJ': 0.026},
#   'cross_dist': 0.329,
#   'min_ratio': 2.858,
#   'difference': 9.801,
#   'split_quality_score': 0.265},
#  {'lemma': 'voisin',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 4.441,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 4.44, 'ADJ': 13.13},
#   'local_densities': {'NOUN': 0.127, 'ADJ': 0.043},
#   'cross_dist': 0.566,
#   'min_ratio': 4.441,
#   'difference': 8.69,
#   'split_quality_score': 0.458},
#  {'lemma': 'étranger',
#   'poses_compared': ('NOUN', 'ADJ'),
#   'split_strength': 14.395,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'NOUN': 14.39, 'ADJ': 15.09},
#   'local_densities': {'NOUN': 0.049, 'ADJ': 0.047},
#   'cross_dist': 0.707,
#   'min_ratio': 14.395,
#   'difference': 0.695,
#   'split_quality_score': 8.494},
#  {'lemma': 'être',
#   'poses_compared': ('VERB', 'AUX'),
#   'split_strength': 2.126,
#   'interpretation': 'High = Clear Split | Low = Merged/Noisy',
#   'ratios': {'VERB': 11.99, 'AUX': 2.13},
#   'local_densities': {'VERB': 0.061, 'AUX': 0.343},
#   'cross_dist': 0.73,
#   'min_ratio': 2.126,
#   'difference': 9.863,
#   'split_quality_score': 0.196}]

# %%
import pandas as pd
import plotly.express as px


# Convert to DataFrame
df = pd.DataFrame(results)

# Create a readable string for the hover info
df['poses_str'] = df['poses_compared'].apply(lambda x: f"{x[0]} vs {x[1]}")
df['ratios_str'] = df['ratios'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))
df['densities_str'] = df['local_densities'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))

# Create the plot
fig = px.scatter(
    df, 
    x="cross_dist", 
    y="split_strength",
    text="lemma",  # This annotates the points
    hover_name="lemma",
    hover_data={
        "cross_dist": True,
        "split_strength": True,
        "poses_str": True,
        "ratios_str": True,
        "densities_str": True,
        "lemma": False # Hide it from the list since it's the title
    },
    labels={
        "cross_dist": "Cross Distance Score",
        "split_strength": "Split Strength Score",
        "poses_str": "POS Compared",
        "ratios_str": "Ratios",
        "densities_str": "Local Densities"
    },
    title="Lexical Split Analysis: Cross Distance vs Split Strength"
)

# Improve text positioning and appearance
fig.update_traces(textposition='top center')
fig.update_layout(
    height=700,
    template="plotly_white",
    hoverlabel=dict(bgcolor="white", font_size=12)
)

fig.show()
# Out:
# /opt/homebrew/lib/python3.11/site-packages/kaleido/__init__.py:14: UserWarning:
#
#
#
# Warning: You have Plotly version 5.22.0, which is not compatible with this version of Kaleido (1.0.0).
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.

# %%
fig.write_html("fr_gsd_splitstrength_vs_crossdistance.html")

# %%
import pandas as pd
import plotly.express as px


# Convert to DataFrame
df = pd.DataFrame(results)

# Create a readable string for the hover info
df['poses_str'] = df['poses_compared'].apply(lambda x: f"{x[0]} vs {x[1]}")
df['ratios_str'] = df['ratios'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))
df['densities_str'] = df['local_densities'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))

# Create the plot
fig = px.scatter(
    df, 
    x="split_strength", 
    y="cross_dist",
    text="lemma",  # This annotates the points
    hover_name="lemma",
    hover_data={
        "cross_dist": True,
        "split_strength": True,
        "poses_str": True,
        "ratios_str": True,
        "densities_str": True,
        "split_quality_score": True,
        "lemma": False # Hide it from the list since it's the title
    },
    labels={
        "cross_dist": "Cross Distance Score",
        "split_strength": "Split Strength Score",
        "poses_str": "POS Compared",
        "ratios_str": "Ratios",
        "densities_str": "Local Densities",
        "split_quality_score": "Min ratio/difference"
    },
    title="Lexical Split Analysis: Split strength vs cross_dist (ss = min(r1, r2) where r_x = cross_dist / median dist between x and 20 closest neighbours)"
)

# Improve text positioning and appearance
fig.update_traces(textposition='top center')
fig.update_layout(
    height=700,
    template="plotly_white",
    hoverlabel=dict(bgcolor="white", font_size=12)
)

fig.show()

# %%
fig.write_html("fr_cross_dist_vs_split_strength.html")

# %%
import pandas as pd
import plotly.express as px


# Convert to DataFrame
df = pd.DataFrame(results)

# Create a readable string for the hover info
df['poses_str'] = df['poses_compared'].apply(lambda x: f"{x[0]} vs {x[1]}")
df['ratios_str'] = df['ratios'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))
df['densities_str'] = df['local_densities'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))

# Create the plot
fig = px.scatter(
    df, 
    x="split_strength", 
    y="cross_dist",
    text="lemma",  # This annotates the points
    hover_name="lemma",
    hover_data={
        "cross_dist": True,
        "split_strength": True,
        "poses_str": True,
        "ratios_str": True,
        "densities_str": True,
        "split_quality_score": True,
        "lemma": False # Hide it from the list since it's the title
    },
    labels={
        "cross_dist": "Cross Distance Score",
        "split_strength": "Split Strength Score",
        "poses_str": "POS Compared",
        "ratios_str": "Ratios",
        "densities_str": "Local Densities",
        "split_quality_score": "Min ratio/difference"
    },
    title="Lexical Split Analysis: Split strength vs cross_dist (ss = min(r1, r2) where r_x = cross_dist / median dist between x and 20 closest neighbours)"
)

# Improve text positioning and appearance
fig.update_traces(textposition='top center')
fig.update_layout(
    height=700,
    template="plotly_white",
    hoverlabel=dict(bgcolor="white", font_size=12)
)

fig.show()

# %%
import pandas as pd
import plotly.express as px


# Convert to DataFrame
df = pd.DataFrame(results)

# Create a readable string for the hover info
df['poses_str'] = df['poses_compared'].apply(lambda x: f"{x[0]} vs {x[1]}")
df['ratios_str'] = df['ratios'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))
df['densities_str'] = df['local_densities'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))
x_series = df['ratios'].apply(lambda x: list(x.values())[0])
y_series = df['ratios'].apply(lambda x: list(x.values())[1])
# Create the plot
fig = px.scatter(
    df, 
    x= df['ratios'].apply(lambda x: list(x.values())[0]), 
    y=df['ratios'].apply(lambda x: list(x.values())[1]), 
    text="lemma",  # This annotates the points
    hover_name="lemma",
    hover_data={
        "cross_dist": True,
        "split_strength": True,
        "poses_str": True,
        "ratios_str": True,
        "densities_str": True,
        "split_quality_score": True,
        "lemma": False # Hide it from the list since it's the title
    },
    labels={
        "cross_dist": "Cross Distance Score",
        "split_strength": "Split Strength Score",
        "poses_str": "POS Compared",
        "ratios_str": "Ratios",
        "densities_str": "Local Densities",
        "split_quality_score": "Min ratio/difference"
    },
    title="Lexical Split Analysis: Split quality score (min ratio/difference) vs. Split strength "
)

# Improve text positioning and appearance
fig.update_traces(textposition='top center')
fig.update_layout(
    height=700,
    template="plotly_white",
    hoverlabel=dict(bgcolor="white", font_size=12)
)
min_val = float(min(x_series.min(), y_series.min()))
max_val = float(max(x_series.max(), y_series.max()))
fig.add_shape(type="line", x0=min_val, y0=min_val, x1=max_val, y1=max_val, xref="x", yref="y", line=dict(color="gray", dash="dash"))

fig.show()

# %%
def get_split_quality(matrix, idx_to_unit, unit_to_idx, lemma, poses, k_neighbors=20):
    # ... (Use the existing logic to get ratios) ...
    res = check_robust_split(matrix, idx_to_unit, unit_to_idx, lemma, poses, k_neighbors)
    
    r1 = res['ratios'][poses[0]]
    r2 = res['ratios'][poses[1]]
    
    # 1. Separation (How far are they?)
    separation = min(r1, r2)
    
    # 2. Asymmetry (How unbalanced is the split?)
    asymmetry = abs(r1 - r2)
    
    # 3. Final Quality Score
    # We penalize high asymmetry
    quality_score = separation / (1 + asymmetry)
    
    return {
        "lemma": lemma,
        "split_quality": round(quality_score, 3),
        "separation": round(separation, 3),
        "asymmetry": round(asymmetry, 3),
        "verdict": "Clean Split" if quality_score > 1.5 else "Messy/Asymmetric" if quality_score > 0.5 else "Merge"
    }

# %%
for lemma, poses in polycategorial_lexunits.items():
    result = check_robust_split(matrix, idx_to_unit, unit_to_idx, lemma, poses, k_neighbors=20, metric='cosine')
    for dico in result:
        current_poses = list(dico['ratios'].keys())
        r1 = dico['ratios'][current_poses[0]]
        r2 = dico['ratios'][current_poses[1]]

        min_ratio = min(r1, r2)
        difference = abs(r1 - r2)
        split_quality_score = min_ratio / (1 + difference ) # logic: if min ratio is high and both ratios are kind of similar then the two functions are far apart, so split. if the difference is high, so the min ratio is a lot smaller than the other one then the point
        # clearly belongs to one of the category more than the other, so the split is poor. if the ratios are low but they're both low it's a grey area, and there should probably be a third category there. 

        split_quality_output = {
        "lemma": lemma,
        "split_quality": round(split_quality_score, 3),
        "separation": round(min_ratio, 3),
        "asymmetry": round(difference, 3),
        "verdict": "Clean Split" if split_quality_score > 1.5 else "Messy/Asymmetric" if split_quality_score > 0.5 else "Merge"
    }
        print(split_quality_output)
# Out:
# {'lemma': '/', 'split_quality': 0.45, 'separation': 0.49, 'asymmetry': 0.09, 'verdict': 'Merge'}
# {'lemma': '1er', 'split_quality': 4.0, 'separation': 6.16, 'asymmetry': 0.54, 'verdict': 'Clean Split'}
# {'lemma': 'allemand', 'split_quality': 0.196, 'separation': 8.21, 'asymmetry': 40.82, 'verdict': 'Merge'}
# {'lemma': 'américain', 'split_quality': 0.171, 'separation': 8.56, 'asymmetry': 49.05, 'verdict': 'Merge'}
# {'lemma': 'anglais', 'split_quality': 0.249, 'separation': 5.97, 'asymmetry': 22.93, 'verdict': 'Merge'}
# {'lemma': 'après', 'split_quality': 0.353, 'separation': 2.3, 'asymmetry': 5.52, 'verdict': 'Merge'}
# {'lemma': 'arabe', 'split_quality': 0.186, 'separation': 6.16, 'asymmetry': 32.05, 'verdict': 'Merge'}
# {'lemma': 'aucun', 'split_quality': 0.296, 'separation': 2.14, 'asymmetry': 6.24, 'verdict': 'Merge'}
# {'lemma': 'autant', 'split_quality': 0.694, 'separation': 1.18, 'asymmetry': 0.7, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'autre', 'split_quality': 0.211, 'separation': 1.13, 'asymmetry': 4.36, 'verdict': 'Merge'}
# {'lemma': 'avant', 'split_quality': 0.181, 'separation': 1.95, 'asymmetry': 9.75, 'verdict': 'Merge'}
# {'lemma': 'avant', 'split_quality': 0.194, 'separation': 1.41, 'asymmetry': 6.26, 'verdict': 'Merge'}
# {'lemma': 'avant', 'split_quality': 5.327, 'separation': 12.04, 'asymmetry': 1.26, 'verdict': 'Clean Split'}
# {'lemma': 'avoir', 'split_quality': 0.158, 'separation': 2.13, 'asymmetry': 12.49, 'verdict': 'Merge'}
# {'lemma': 'beaucoup', 'split_quality': 0.689, 'separation': 1.55, 'asymmetry': 1.25, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'bien', 'split_quality': 0.906, 'separation': 9.95, 'asymmetry': 9.98, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'blanc', 'split_quality': 0.342, 'separation': 5.0, 'asymmetry': 13.6, 'verdict': 'Merge'}
# {'lemma': 'bref', 'split_quality': 0.126, 'separation': 0.81, 'asymmetry': 5.45, 'verdict': 'Merge'}
# {'lemma': 'britannique', 'split_quality': 0.171, 'separation': 9.43, 'asymmetry': 54.16, 'verdict': 'Merge'}
# {'lemma': 'caractéristique', 'split_quality': 0.767, 'separation': 4.7, 'asymmetry': 5.13, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'ce', 'split_quality': 0.196, 'separation': 1.46, 'asymmetry': 6.46, 'verdict': 'Merge'}
# {'lemma': 'certain', 'split_quality': 0.298, 'separation': 2.0, 'asymmetry': 5.71, 'verdict': 'Merge'}
# {'lemma': 'certain', 'split_quality': 1.694, 'separation': 2.1, 'asymmetry': 0.24, 'verdict': 'Clean Split'}
# {'lemma': 'certain', 'split_quality': 0.359, 'separation': 3.19, 'asymmetry': 7.89, 'verdict': 'Merge'}
# {'lemma': 'chrétien', 'split_quality': 1.225, 'separation': 9.04, 'asymmetry': 6.38, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'comme', 'split_quality': 0.297, 'separation': 1.05, 'asymmetry': 2.54, 'verdict': 'Merge'}
# {'lemma': 'comme', 'split_quality': 0.688, 'separation': 0.99, 'asymmetry': 0.44, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'comme', 'split_quality': 0.487, 'separation': 1.51, 'asymmetry': 2.1, 'verdict': 'Merge'}
# {'lemma': 'conseiller', 'split_quality': 3.5, 'separation': 3.64, 'asymmetry': 0.04, 'verdict': 'Clean Split'}
# {'lemma': 'courant', 'split_quality': 0.772, 'separation': 6.83, 'asymmetry': 7.85, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'critique', 'split_quality': 5.03, 'separation': 13.48, 'asymmetry': 1.68, 'verdict': 'Clean Split'}
# {'lemma': 'depuis', 'split_quality': 0.872, 'separation': 3.12, 'asymmetry': 2.58, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'différent', 'split_quality': 0.732, 'separation': 1.2, 'asymmetry': 0.64, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'divers', 'split_quality': 0.804, 'separation': 1.11, 'asymmetry': 0.38, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'donc', 'split_quality': 0.238, 'separation': 2.68, 'asymmetry': 10.26, 'verdict': 'Merge'}
# {'lemma': 'droit', 'split_quality': 0.719, 'separation': 18.52, 'asymmetry': 24.75, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'en', 'split_quality': 1.64, 'separation': 2.46, 'asymmetry': 0.5, 'verdict': 'Clean Split'}
# {'lemma': 'ensemble', 'split_quality': 0.117, 'separation': 2.99, 'asymmetry': 24.55, 'verdict': 'Merge'}
# {'lemma': 'espagnol', 'split_quality': 0.223, 'separation': 5.81, 'asymmetry': 25.1, 'verdict': 'Merge'}
# {'lemma': 'essentiel', 'split_quality': 1.499, 'separation': 6.61, 'asymmetry': 3.41, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'extérieur', 'split_quality': 1.827, 'separation': 21.08, 'asymmetry': 10.54, 'verdict': 'Clean Split'}
# {'lemma': 'faire', 'split_quality': 0.087, 'separation': 1.49, 'asymmetry': 16.15, 'verdict': 'Merge'}
# {'lemma': 'fort', 'split_quality': 0.749, 'separation': 3.35, 'asymmetry': 3.47, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'fort', 'split_quality': 0.902, 'separation': 4.9, 'asymmetry': 4.43, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'fort', 'split_quality': 4.6, 'separation': 6.67, 'asymmetry': 0.45, 'verdict': 'Clean Split'}
# {'lemma': 'français', 'split_quality': 0.199, 'separation': 9.63, 'asymmetry': 47.28, 'verdict': 'Merge'}
# {'lemma': 'gauche', 'split_quality': 0.222, 'separation': 6.76, 'asymmetry': 29.47, 'verdict': 'Merge'}
# {'lemma': 'grec', 'split_quality': 0.298, 'separation': 10.37, 'asymmetry': 33.78, 'verdict': 'Merge'}
# {'lemma': 'général', 'split_quality': 0.489, 'separation': 14.66, 'asymmetry': 28.98, 'verdict': 'Merge'}
# {'lemma': 'h', 'split_quality': 0.063, 'separation': 0.08, 'asymmetry': 0.26, 'verdict': 'Merge'}
# {'lemma': 'intérieur', 'split_quality': 0.874, 'separation': 26.24, 'asymmetry': 29.02, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'italien', 'split_quality': 0.165, 'separation': 7.26, 'asymmetry': 42.9, 'verdict': 'Merge'}
# {'lemma': 'japonais', 'split_quality': 0.362, 'separation': 9.37, 'asymmetry': 24.9, 'verdict': 'Merge'}
# {'lemma': 'jeune', 'split_quality': 11.125, 'separation': 13.35, 'asymmetry': 0.2, 'verdict': 'Clean Split'}
# {'lemma': 'juif', 'split_quality': 0.304, 'separation': 9.79, 'asymmetry': 31.25, 'verdict': 'Merge'}
# {'lemma': 'large', 'split_quality': 12.349, 'separation': 13.09, 'asymmetry': 0.06, 'verdict': 'Clean Split'}
# {'lemma': 'latin', 'split_quality': 0.966, 'separation': 6.24, 'asymmetry': 5.46, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'long', 'split_quality': 0.291, 'separation': 2.82, 'asymmetry': 8.69, 'verdict': 'Merge'}
# {'lemma': 'mal', 'split_quality': 1.626, 'separation': 6.7, 'asymmetry': 3.12, 'verdict': 'Clean Split'}
# {'lemma': 'militaire', 'split_quality': 0.167, 'separation': 8.94, 'asymmetry': 52.48, 'verdict': 'Merge'}
# {'lemma': 'moins', 'split_quality': 0.5, 'separation': 1.8, 'asymmetry': 2.6, 'verdict': 'Merge'}
# {'lemma': 'mort', 'split_quality': 0.331, 'separation': 4.47, 'asymmetry': 12.5, 'verdict': 'Merge'}
# {'lemma': 'moyen', 'split_quality': 0.866, 'separation': 6.36, 'asymmetry': 6.34, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'même', 'split_quality': 0.145, 'separation': 3.83, 'asymmetry': 25.46, 'verdict': 'Merge'}
# {'lemma': 'noir', 'split_quality': 0.195, 'separation': 4.0, 'asymmetry': 19.51, 'verdict': 'Merge'}
# {'lemma': 'or', 'split_quality': 0.162, 'separation': 1.88, 'asymmetry': 10.58, 'verdict': 'Merge'}
# {'lemma': 'personne', 'split_quality': 0.191, 'separation': 1.93, 'asymmetry': 9.09, 'verdict': 'Merge'}
# {'lemma': 'personnel', 'split_quality': 0.91, 'separation': 19.06, 'asymmetry': 19.95, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'peu', 'split_quality': 0.314, 'separation': 1.17, 'asymmetry': 2.73, 'verdict': 'Merge'}
# {'lemma': 'physique', 'split_quality': 0.241, 'separation': 5.61, 'asymmetry': 22.3, 'verdict': 'Merge'}
# {'lemma': 'plat', 'split_quality': 2.088, 'separation': 12.51, 'asymmetry': 4.99, 'verdict': 'Clean Split'}
# {'lemma': 'plus', 'split_quality': 0.678, 'separation': 2.17, 'asymmetry': 2.2, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'plusieurs', 'split_quality': 1.197, 'separation': 2.19, 'asymmetry': 0.83, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'policier', 'split_quality': 0.331, 'separation': 7.75, 'asymmetry': 22.4, 'verdict': 'Merge'}
# {'lemma': 'politique', 'split_quality': 1.35, 'separation': 29.52, 'asymmetry': 20.87, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'pouvoir', 'split_quality': 0.138, 'separation': 5.1, 'asymmetry': 35.92, 'verdict': 'Merge'}
# {'lemma': 'professionnel', 'split_quality': 0.33, 'separation': 6.04, 'asymmetry': 17.28, 'verdict': 'Merge'}
# {'lemma': 'près', 'split_quality': 0.452, 'separation': 0.52, 'asymmetry': 0.15, 'verdict': 'Merge'}
# {'lemma': 'public', 'split_quality': 0.457, 'separation': 17.28, 'asymmetry': 36.84, 'verdict': 'Merge'}
# {'lemma': 'que', 'split_quality': 1.529, 'separation': 2.11, 'asymmetry': 0.38, 'verdict': 'Clean Split'}
# {'lemma': 'que', 'split_quality': 0.252, 'separation': 0.53, 'asymmetry': 1.1, 'verdict': 'Merge'}
# {'lemma': 'que', 'split_quality': 0.414, 'separation': 1.2, 'asymmetry': 1.9, 'verdict': 'Merge'}
# {'lemma': 'quel', 'split_quality': 0.245, 'separation': 2.8, 'asymmetry': 10.45, 'verdict': 'Merge'}
# {'lemma': 'responsable', 'split_quality': 0.419, 'separation': 4.01, 'asymmetry': 8.56, 'verdict': 'Merge'}
# {'lemma': 'romain', 'split_quality': 0.235, 'separation': 11.0, 'asymmetry': 45.87, 'verdict': 'Merge'}
# {'lemma': 'roman', 'split_quality': 5.5, 'separation': 17.38, 'asymmetry': 2.16, 'verdict': 'Clean Split'}
# {'lemma': 'savoir', 'split_quality': 0.707, 'separation': 6.94, 'asymmetry': 8.82, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'scientifique', 'split_quality': 0.107, 'separation': 4.73, 'asymmetry': 43.31, 'verdict': 'Merge'}
# {'lemma': 'second', 'split_quality': 0.315, 'separation': 5.87, 'asymmetry': 17.62, 'verdict': 'Merge'}
# {'lemma': 'si', 'split_quality': 0.313, 'separation': 3.0, 'asymmetry': 8.57, 'verdict': 'Merge'}
# {'lemma': 'soit', 'split_quality': 0.247, 'separation': 0.43, 'asymmetry': 0.74, 'verdict': 'Merge'}
# {'lemma': 'son', 'split_quality': 2.739, 'separation': 12.93, 'asymmetry': 3.72, 'verdict': 'Clean Split'}
# {'lemma': 'suivant', 'split_quality': 0.449, 'separation': 7.74, 'asymmetry': 16.24, 'verdict': 'Merge'}
# {'lemma': 'technique', 'split_quality': 4.57, 'separation': 18.69, 'asymmetry': 3.09, 'verdict': 'Clean Split'}
# {'lemma': 'tel', 'split_quality': 0.643, 'separation': 2.09, 'asymmetry': 2.25, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'total', 'split_quality': 0.467, 'separation': 15.87, 'asymmetry': 32.96, 'verdict': 'Merge'}
# {'lemma': 'tout', 'split_quality': 0.515, 'separation': 1.19, 'asymmetry': 1.31, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'tout', 'split_quality': 0.506, 'separation': 2.35, 'asymmetry': 3.64, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'tout', 'split_quality': 1.644, 'separation': 1.66, 'asymmetry': 0.01, 'verdict': 'Clean Split'}
# {'lemma': 'tout', 'split_quality': 0.179, 'separation': 0.8, 'asymmetry': 3.48, 'verdict': 'Merge'}
# {'lemma': 'tout', 'split_quality': 0.527, 'separation': 1.26, 'asymmetry': 1.39, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'tout', 'split_quality': 0.509, 'separation': 2.49, 'asymmetry': 3.89, 'verdict': 'Messy/Asymmetric'}
# {'lemma': 'un', 'split_quality': 0.07, 'separation': 0.14, 'asymmetry': 0.99, 'verdict': 'Merge'}
# {'lemma': 'un', 'split_quality': 1.686, 'separation': 1.99, 'asymmetry': 0.18, 'verdict': 'Clean Split'}
# {'lemma': 'un', 'split_quality': 0.125, 'separation': 2.05, 'asymmetry': 15.35, 'verdict': 'Merge'}
# {'lemma': 'vidéo', 'split_quality': 0.265, 'separation': 2.86, 'asymmetry': 9.8, 'verdict': 'Merge'}
# {'lemma': 'voisin', 'split_quality': 0.458, 'separation': 4.44, 'asymmetry': 8.69, 'verdict': 'Merge'}
# {'lemma': 'étranger', 'split_quality': 8.465, 'separation': 14.39, 'asymmetry': 0.7, 'verdict': 'Clean Split'}
# {'lemma': 'être', 'split_quality': 0.196, 'separation': 2.13, 'asymmetry': 9.86, 'verdict': 'Merge'}

# %%
import pandas as pd
import plotly.express as px

# 1. Define your thresholds
# 1.0 is the theoretical threshold for Split Strength
ss_thresh = df['split_strength'].median()
# We use the median for Cross Distance to make it relative to your data distribution
cd_thresh = df['cross_dist'].median() 

# 2. Categorize the lemmas into the four quadrants
def categorize(row):
    if row['split_strength'] >= ss_thresh:
        return "Robust Split" if row['cross_dist'] >= cd_thresh else "Mini-Cluster"
    else:
        return "Sparse/Noisy" if row['cross_dist'] >= cd_thresh else "Merged/Syncretic"

df['quadrant'] = df.apply(categorize, axis=1)

# 3. Create the plot
fig = px.scatter(
    df, 
    x="split_strength", 
    y="cross_dist",
    color="quadrant", # This automatically handles the colors
    text="lemma",
    hover_name="lemma",
    color_discrete_map={
        "Robust Split": "#2ca02c",    # Green
        "Mini-Cluster": "#1f77b4",    # Blue
        "Sparse/Noisy": "#ff0efb",    # Orange
        "Merged/Syncretic": "#d62728" # Red
    },
    hover_data={
        "cross_dist": ":.3f",
        "split_strength": ":.3f",
        "poses_str": True,
        "split_quality_score": ":.3f",
        "quadrant": True,
        "lemma": False 
    },
    labels={
        "cross_dist": "Cross Distance (CD)",
        "split_strength": "Split Strength (SS)",
        "quadrant": "Interpretation"
    },
    title="Lexical Split Analysis: Quadrant Mapping"
)

# 4. Add the quadrant divider lines
fig.add_vline(x=ss_thresh, line_dash="dash", line_color="gray", opacity=0.5)
fig.add_hline(y=cd_thresh, line_dash="dash", line_color="gray", opacity=0.5)

# 5. Add explanatory labels in the corners
fig.add_annotation(x=df['split_strength'].max(), y=df['cross_dist'].max(),
                text="<b>TRUE HETEROSEMY</b><br>Far apart & well-anchored", showarrow=False, font=dict(color="green"))
fig.add_annotation(x=0, y=df['cross_dist'].max(),
                text="<b>SPARSE OUTLIERS</b><br>Far but categories are loose", showarrow=False, font=dict(color="orange"), xanchor="left")
fig.add_annotation(x=df['split_strength'].max(), y=df['cross_dist'].min(),
                text="<b>SUBTLE DISTINCTION</b><br>Close but very tight clusters", showarrow=False, font=dict(color="blue"))
fig.add_annotation(x=0, y=df['cross_dist'].min(),
                text="<b>MERGED</b><br>No functional difference", showarrow=False, font=dict(color="red"), xanchor="left")

# Final Styling
fig.update_traces(textposition='top center')
fig.update_layout(
    height=800,
    template="plotly_white",
    legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
)

fig.show()

# %%
fig.write_html("fr_cross_dist_vs_split_strength_annotated.html")

# %%
import pandas as pd
import plotly.express as px


# Convert to DataFrame
df = pd.DataFrame(results)
ss_thresh = df['split_strength'].median()
# We use the median for Cross Distance to make it relative to your data distribution
d_thresh = df['difference'].median() 
# Create a readable string for the hover info
df['poses_str'] = df['poses_compared'].apply(lambda x: f"{x[0]} vs {x[1]}")
df['ratios_str'] = df['ratios'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))
df['densities_str'] = df['local_densities'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))

# Create the plot
fig = px.scatter(
    df, 
    x="difference", 
    y="split_strength",
    text="lemma",  # This annotates the points
    hover_name="lemma",
    hover_data={
        "cross_dist": True,
        "split_strength": True,
        "poses_str": True,
        "ratios_str": True,
        "densities_str": True,
        "split_quality_score": True,
        "lemma": False # Hide it from the list since it's the title
    },
    labels={
        "cross_dist": "Cross Distance Score",
        "split_strength": "Split Strength Score",
        "poses_str": "POS Compared",
        "ratios_str": "Ratios",
        "densities_str": "Local Densities",
        "split_quality_score": "Min ratio/difference"
    },
    title="Lexical Split Analysis: Split strength vs Asymmetry"
)

fig.add_vline(x=ss_thresh, line_dash="dash", line_color="gray", opacity=0.5)
fig.add_hline(y=d_thresh, line_dash="dash", line_color="gray", opacity=0.5)

# Improve text positioning and appearance
fig.update_traces(textposition='top center')
fig.update_layout(
    height=700,
    template="plotly_white",
    hoverlabel=dict(bgcolor="white", font_size=12)
)

fig.show()

# %%
fig.write_html("fr_split_strength_vs_difference.html")

# %%
import pandas as pd
import plotly.express as px


# Convert to DataFrame
df = pd.DataFrame(results)
sq_thresh = df['split_quality_score'].median()
# We use the median for Cross Distance to make it relative to your data distribution
cd_thresh = df['cross_dist'].median() 
# Create a readable string for the hover info
df['poses_str'] = df['poses_compared'].apply(lambda x: f"{x[0]} vs {x[1]}")
df['ratios_str'] = df['ratios'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))
df['densities_str'] = df['local_densities'].apply(lambda x: ", ".join([f"{k}: {v}" for k, v in x.items()]))

# Create the plot
fig = px.scatter(
    df, 
    x="cross_dist", 
    y="split_quality_score",
    text="lemma",  # This annotates the points
    hover_name="lemma",
    hover_data={
        "cross_dist": True,
        "split_strength": True,
        "poses_str": True,
        "ratios_str": True,
        "densities_str": True,
        "split_quality_score": True,
        "lemma": False # Hide it from the list since it's the title
    },
    labels={
        "cross_dist": "Cross Distance Score",
        "split_strength": "Split Strength Score",
        "poses_str": "POS Compared",
        "ratios_str": "Ratios",
        "densities_str": "Local Densities",
        "split_quality_score": "Split Quality Score"
    },
    title="Lexical Split Analysis: Split Quality vs Cross Distance"
)

fig.add_vline(x=sq_thresh, line_dash="dash", line_color="gray", opacity=0.5)
fig.add_hline(y=cd_thresh, line_dash="dash", line_color="gray", opacity=0.5)

# Improve text positioning and appearance
fig.update_traces(textposition='top center')
fig.update_layout(
    height=700,
    template="plotly_white",
    hoverlabel=dict(bgcolor="white", font_size=12)
)

fig.show()

# %%
fig.write_html("fr_splitquality_vs_crossdistance.html")

# %%
# 2. Create the POS Pair label for the X-axis
# This turns ('NOUN', 'ADJ') into "NOUN - ADJ"
df = pd.DataFrame(results)
df['pos_pair'] = df['poses_compared'].apply(lambda x: " - ".join(sorted(list(x))))
sq_thresh = df['split_quality_score'].median()
# 3. Generate the Category Health Box Plot
fig = px.box(
    df, 
    x="pos_pair", 
    y="split_quality_score", 
    points="all",           # Shows individual lemma dots
    hover_name="lemma",     # Lets you see which word is which dot
    color="pos_pair",
    title="Category Health Check: Distribution of Split Quality by POS Pair",
    labels={"pos_pair": "POS Relationship", "split_quality_score": "Split Quality"}
)

# Optional: Add a reference line at Quality = 1.0 (The "Ambiguity Line")
fig.add_hline(y=sq_thresh, line_dash="dot", line_color="red", annotation_text="Quality Median Value")
ordered_indices = df.groupby("pos_pair")["split_quality_score"].median().sort_values().index
fig.update_xaxes(categoryorder='array', categoryarray=ordered_indices)
fig.show()

# %%
import pandas as pd
import plotly.express as px

# 1. Prepare and Deduplicate Data
expanded_results = []
for entry in results:
    pos_a, pos_b = entry['poses_compared']
    
    # Instance for POS A
    row_a = entry.copy()
    row_a['focus_pos'] = pos_a
    row_a['comp_pos'] = pos_b
    expanded_results.append(row_a)
    
    # Instance for POS B
    row_b = entry.copy()
    row_b['focus_pos'] = pos_b
    row_b['comp_pos'] = pos_a
    expanded_results.append(row_b)

df_expanded = pd.DataFrame(expanded_results)

# Remove exact duplicates if they exist in your source list
df_expanded = df_expanded.drop_duplicates(subset=['lemma', 'focus_pos', 'comp_pos', 'split_quality_score'])

# 2. Generate the Plot
fig = px.box(
    df_expanded, 
    x="comp_pos",
    y="split_quality_score", 
    facet_col="focus_pos",
    facet_col_wrap=3,
    color="comp_pos",
    points="all",           # This shows the points
    hover_name="lemma",
    title="Category Health: Points Cleaned & De-duplicated",
)

# 3. Adjust "Jitter" and Point Positioning
# This spreads the points out so they don't overlap vertically/horizontally
fig.update_traces(pointpos=0, jitter=0.3) 

# 4. Axes and Layout Fixes
fig.update_yaxes(matches=None, showticklabels=True)
fig.update_xaxes(matches=None)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
sq_thresh = df['split_quality_score'].median()
fig.add_hline(y=sq_thresh, line_dash="dot", line_color="red", annotation_text="Median")
fig.update_layout(
    height=1700,
    # template="plotly_white",
    # hoverlabel=dict(bgcolor="white", font_size=12)
)
fig.show()
