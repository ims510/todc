# %% [markdown]
# Adverbs without removing the idioms, but with removing those under 10 occurrences

# %%
import grewpy
import yaml
import sys
import numpy as np

sys.path.insert(1, '/Users/madalina/Documents/M2TAL/stage/grex/grex2')
import pyximport
pyximport.install()
import grex.data
import grex.utils
import grex.features
# Out:
# connected to port: 55057

# %%
path = "/Users/madalina/Documents/M1TAL/stage-SK/Treebanks/UD_French-GSD-master"
grewpy.set_config('ud')
corpus = grewpy.Corpus(path)
draft = grewpy.CorpusDraft(corpus)

# %%
all_matches = corpus.search(grewpy.Request("pattern{X[upos=ADV]}"), clustering_parameter=['X.lemma'])

# %%
matches = {}
for key, value in all_matches.items():
    # remove those that have less than 10 occurrences
    if len(value) > 10:
        matches[key] = value

# %%
with open("../3. probability_matrix/patterns_adv.txt") as instream:
    config = yaml.load(instream, Loader=yaml.Loader)

templates = grex.utils.FeaturePredicate.from_config(config["templates"])
feature_predicate = grex.utils.FeaturePredicate.from_config(config["features"], templates=templates)

# %%
data = { k : list() for k in matches }
for adv, mts in matches.items():
    for match in mts:
        features = grex.data.extract_features(draft, match, feature_predicate)
        formatted_features = [
            f"{':'.join(k)}={v}" if not isinstance(v, set) else
            f"{':'.join(k)}={val}" for k, v in features.items() for val in (v if isinstance(v, set) else [v])
        ]
        data[adv].append(formatted_features)

# %%
unique_adv = sorted(set([k for k in data]))
unique_features = sorted(set([feat for _, matches in data.items() for m in matches for feat in m]))

idx2feature = {i : feat for i, feat in enumerate(unique_features) }
feature2idx = {feat : i for i, feat in idx2feature.items()}
idx2adv = {i : feat for i, feat in enumerate(unique_adv) }
adv2idx = {feat : i for i, feat in idx2adv.items()}

# %%
# Examples of features that we'd have in the matrix
for i in range(10):
    print(idx2feature[i])
# Out:
# node:X:child:Definite=Def
# node:X:child:Definite=Ind
# node:X:child:Emph=No
# node:X:child:Emph=Yes
# node:X:child:ExtPos=ADP
# node:X:child:ExtPos=ADV
# node:X:child:ExtPos=CCONJ
# node:X:child:ExtPos=NOUN
# node:X:child:ExtPos=PRON
# node:X:child:ExtPos=PROPN

# %%
X = np.zeros((len(data.keys()), len(unique_features)))
for adv, samples in data.items():
    n_samples = len(matches)
    for m in samples:
        for feature in m:
            X[adv2idx[adv], feature2idx[feature]] += 1
    X[adv2idx[adv]] = X[adv2idx[adv]] / n_samples
print(f"{X.shape=}")
# Out:
# X.shape=(127, 209)

# %%
# Assuming X is your data matrix and cov is the covariance matrix
cov = np.cov(X, rowvar=False)

# Add a small value to the diagonal elements of the covariance matrix
epsilon = 1e-10
cov += np.eye(cov.shape[0]) * epsilon

# Compute the inverse of the regularized covariance matrix
cov_inv = np.linalg.inv(cov)

# %%
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, dendrogram, to_tree
import matplotlib.pyplot as plt

# Hamming or jacard for categorical data, cosine for sparse matrices (normally used in NLP)
# I compute the distance for each pair of lines, each POS
distance_matrix = pdist(X, 'mahalanobis', VI=cov_inv)
# Complete -> we cluster 
linked = linkage(distance_matrix, method="complete", optimal_ordering=True)

plt.figure(figsize=(30, 14))

dn = dendrogram(linked,
                orientation='top',
                labels=[name for name in unique_adv],
                distance_sort='descending',
                show_leaf_counts=True,
                get_leaves=True)

plt.title('Dendrogram', fontsize=12)  # Increase title font size
plt.xlabel('Sample index', fontsize=12)  # Increase x-axis label font size
plt.ylabel('Distance', fontsize=12)  # Increase y-axis label font size
plt.xticks(fontsize=12)  # Increase x-tick labels font size
plt.yticks(fontsize=12)  # Increase y-tick labels font size
plt.show()

# %%
import numpy as np
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics import silhouette_score

def find_optimal_clusters(X, max_clusters=20, metric='cosine', method='complete'):
    distance_matrix = pdist(X, 'mahalanobis', VI=cov_inv)
    linked = linkage(distance_matrix, method=method, optimal_ordering=True)
    
    silhouette_scores = []
    for num_clusters in range(2, max_clusters + 1):
        labels = fcluster(linked, num_clusters, criterion='maxclust')
        if len(np.unique(labels)) > 1:  # Ensure there is more than one cluster
            score = silhouette_score(X, labels, metric='mahalanobis', VI=cov_inv)
            silhouette_scores.append(score)
            print(f'Number of clusters: {num_clusters}, Silhouette Score: {score}')
        else:
            silhouette_scores.append(-1)  # Append a low score if only one cluster
    
    optimal_clusters = np.argmax(silhouette_scores) + 2  # +2 because range starts from 2
    return optimal_clusters, silhouette_scores

# Find the optimal number of clusters
optimal_clusters, silhouette_scores = find_optimal_clusters(X, max_clusters=50)
print(f'Optimal number of clusters: {optimal_clusters}')
print(X.shape)
# Out:
# Number of clusters: 2, Silhouette Score: 0.021990230566706834
# Number of clusters: 3, Silhouette Score: 0.021997753717358716
# Number of clusters: 4, Silhouette Score: 0.021664820318036782
# Number of clusters: 5, Silhouette Score: 0.022013453738182896
# Number of clusters: 6, Silhouette Score: 0.02218793602865386
# Number of clusters: 7, Silhouette Score: 0.02219811251858476
# Number of clusters: 8, Silhouette Score: 0.022208227626477294
# Number of clusters: 9, Silhouette Score: 0.02221801744906124
# Number of clusters: 10, Silhouette Score: 0.02187360734125069
# Number of clusters: 11, Silhouette Score: 0.021518239189350204
# Number of clusters: 12, Silhouette Score: 0.021884584859695404
# Number of clusters: 13, Silhouette Score: 0.021337621275663483
# Number of clusters: 14, Silhouette Score: 0.021339707557725202
# Number of clusters: 15, Silhouette Score: 0.021530870087937942
# Number of clusters: 16, Silhouette Score: 0.021915134872682887
# Number of clusters: 17, Silhouette Score: 0.02229978632123704
# Number of clusters: 18, Silhouette Score: 0.022492213566455494
# Number of clusters: 19, Silhouette Score: 0.022506376980152586
# Number of clusters: 20, Silhouette Score: 0.022513815281368487
# Number of clusters: 21, Silhouette Score: 0.02252751785639942
# Number of clusters: 22, Silhouette Score: 0.021567095671825666
# Number of clusters: 23, Silhouette Score: 0.021771145758910083
# Number of clusters: 24, Silhouette Score: 0.01879526446079373
# Number of clusters: 25, Silhouette Score: 0.019271909189428022
# Number of clusters: 26, Silhouette Score: 0.019509257486215573
# Number of clusters: 27, Silhouette Score: 0.01974724732234735
# Number of clusters: 28, Silhouette Score: 0.01998473613573482
# Number of clusters: 29, Silhouette Score: 0.01998434417623269
# Number of clusters: 30, Silhouette Score: 0.019967911868073028
# Number of clusters: 31, Silhouette Score: 0.02020901117879161
# Number of clusters: 32, Silhouette Score: 0.020199775934541156
# Number of clusters: 33, Silhouette Score: 0.02044202907508837
# Number of clusters: 34, Silhouette Score: 0.020442011625861924
# Number of clusters: 35, Silhouette Score: 0.020441332448616407
# Number of clusters: 36, Silhouette Score: 0.020928027678833467
# Number of clusters: 37, Silhouette Score: 0.02042828742594696
# Number of clusters: 38, Silhouette Score: 0.020378095611542104
# Number of clusters: 39, Silhouette Score: 0.020629947038645777
# Number of clusters: 40, Silhouette Score: 0.02113068395261802
# Number of clusters: 41, Silhouette Score: 0.020619625887406214
# Number of clusters: 42, Silhouette Score: 0.020876738757369045
# Number of clusters: 43, Silhouette Score: 0.02139373224282091
# Number of clusters: 44, Silhouette Score: 0.02191017748174755
# Number of clusters: 45, Silhouette Score: 0.019726728789640876
# Number of clusters: 46, Silhouette Score: 0.019710111400434733
# Number of clusters: 47, Silhouette Score: 0.019708747869473287
# Number of clusters: 48, Silhouette Score: 0.020287228646165206
# Number of clusters: 49, Silhouette Score: 0.02086852942054645
# Number of clusters: 50, Silhouette Score: 0.02115825618175724
# Optimal number of clusters: 21
# (127, 209)

# %%
from sklearn.metrics import calinski_harabasz_score

for i in range(2, 50):
    labels = fcluster(linked, i, criterion='maxclust')
    score = calinski_harabasz_score(X, labels)
    print(f'Number of clusters: {i}, Calinski-Harabasz Index: {score}')
# Out:
# Number of clusters: 2, Calinski-Harabasz Index: 0.5331920494532796
# Number of clusters: 3, Calinski-Harabasz Index: 1.2229948058730244
# Number of clusters: 4, Calinski-Harabasz Index: 1.0811739540742153
# Number of clusters: 5, Calinski-Harabasz Index: 3.9878692901860653
# Number of clusters: 6, Calinski-Harabasz Index: 3.321067838439773
# Number of clusters: 7, Calinski-Harabasz Index: 2.8741131779620925
# Number of clusters: 8, Calinski-Harabasz Index: 2.4523029744132443
# Number of clusters: 9, Calinski-Harabasz Index: 2.1977913886323455
# Number of clusters: 10, Calinski-Harabasz Index: 1.949144236955338
# Number of clusters: 11, Calinski-Harabasz Index: 6.105945478486489
# Number of clusters: 12, Calinski-Harabasz Index: 5.6827395765461235
# Number of clusters: 13, Calinski-Harabasz Index: 5.1749425930603445
# Number of clusters: 14, Calinski-Harabasz Index: 5.140163161266396
# Number of clusters: 15, Calinski-Harabasz Index: 4.736807157399744
# Number of clusters: 16, Calinski-Harabasz Index: 4.392289442787768
# Number of clusters: 17, Calinski-Harabasz Index: 4.094430100295948
# Number of clusters: 18, Calinski-Harabasz Index: 3.974327380877084
# Number of clusters: 19, Calinski-Harabasz Index: 3.930286321016867
# Number of clusters: 20, Calinski-Harabasz Index: 3.692005630971333
# Number of clusters: 21, Calinski-Harabasz Index: 3.47789790956378
# Number of clusters: 22, Calinski-Harabasz Index: 3.294241362897365
# Number of clusters: 23, Calinski-Harabasz Index: 5.564004822509506
# Number of clusters: 24, Calinski-Harabasz Index: 5.278693681987392
# Number of clusters: 25, Calinski-Harabasz Index: 5.066576959054079
# Number of clusters: 26, Calinski-Harabasz Index: 4.828748453479574
# Number of clusters: 27, Calinski-Harabasz Index: 4.914007419111806
# Number of clusters: 28, Calinski-Harabasz Index: 4.696116387262551
# Number of clusters: 29, Calinski-Harabasz Index: 4.483606053538765
# Number of clusters: 30, Calinski-Harabasz Index: 4.29682287957772
# Number of clusters: 31, Calinski-Harabasz Index: 4.115127512114091
# Number of clusters: 32, Calinski-Harabasz Index: 3.9436828383429057
# Number of clusters: 33, Calinski-Harabasz Index: 3.8306067681412292
# Number of clusters: 34, Calinski-Harabasz Index: 3.700435921644438
# Number of clusters: 35, Calinski-Harabasz Index: 3.8628781352922874
# Number of clusters: 36, Calinski-Harabasz Index: 3.7187029726714202
# Number of clusters: 37, Calinski-Harabasz Index: 3.5818002516988168
# Number of clusters: 38, Calinski-Harabasz Index: 3.454492802759085
# Number of clusters: 39, Calinski-Harabasz Index: 3.3505532910855544
# Number of clusters: 40, Calinski-Harabasz Index: 3.2417803344522755
# Number of clusters: 41, Calinski-Harabasz Index: 3.124582543938616
# Number of clusters: 42, Calinski-Harabasz Index: 3.0133821933606346
# Number of clusters: 43, Calinski-Harabasz Index: 2.9087017432331046
# Number of clusters: 44, Calinski-Harabasz Index: 2.9379103989784836
# Number of clusters: 45, Calinski-Harabasz Index: 2.8367405866744537
# Number of clusters: 46, Calinski-Harabasz Index: 2.7571780259864793
# Number of clusters: 47, Calinski-Harabasz Index: 2.681388319261134
# Number of clusters: 48, Calinski-Harabasz Index: 2.5956590692238763
# Number of clusters: 49, Calinski-Harabasz Index: 2.517709362695255

# %%
# davies_bouldin_score
from sklearn.metrics import davies_bouldin_score

for i in range(2, 50):
    labels = fcluster(linked, i, criterion='maxclust')
    score = davies_bouldin_score(X, labels)
    print(f'Number of clusters: {i}, Davies-Bouldin Index: {score}')
# Out:
# Number of clusters: 2, Davies-Bouldin Index: 1.5897692490825703
# Number of clusters: 3, Davies-Bouldin Index: 1.8471337080110286
# Number of clusters: 4, Davies-Bouldin Index: 2.4183066438330365
# Number of clusters: 5, Davies-Bouldin Index: 2.6357119205698782
# Number of clusters: 6, Davies-Bouldin Index: 2.383159903639424
# Number of clusters: 7, Davies-Bouldin Index: 2.2882080240993616
# Number of clusters: 8, Davies-Bouldin Index: 3.5469860997685307
# Number of clusters: 9, Davies-Bouldin Index: 3.114580640350649
# Number of clusters: 10, Davies-Bouldin Index: 3.00158427746421
# Number of clusters: 11, Davies-Bouldin Index: 2.6246838457645167
# Number of clusters: 12, Davies-Bouldin Index: 2.535288561507215
# Number of clusters: 13, Davies-Bouldin Index: 2.524165307338471
# Number of clusters: 14, Davies-Bouldin Index: 2.624851177387132
# Number of clusters: 15, Davies-Bouldin Index: 2.535651328055619
# Number of clusters: 16, Davies-Bouldin Index: 2.3973141562418414
# Number of clusters: 17, Davies-Bouldin Index: 2.4449767675448673
# Number of clusters: 18, Davies-Bouldin Index: 2.3338129356259287
# Number of clusters: 19, Davies-Bouldin Index: 2.240143326731865
# Number of clusters: 20, Davies-Bouldin Index: 2.2911259910648916
# Number of clusters: 21, Davies-Bouldin Index: 2.228346834462507
# Number of clusters: 22, Davies-Bouldin Index: 2.2060863834022424
# Number of clusters: 23, Davies-Bouldin Index: 2.1614915746309125
# Number of clusters: 24, Davies-Bouldin Index: 2.1142233135416855
# Number of clusters: 25, Davies-Bouldin Index: 2.053089698999895
# Number of clusters: 26, Davies-Bouldin Index: 2.0610353574479165
# Number of clusters: 27, Davies-Bouldin Index: 2.042731805663046
# Number of clusters: 28, Davies-Bouldin Index: 2.0241930766630345
# Number of clusters: 29, Davies-Bouldin Index: 2.015979759898556
# Number of clusters: 30, Davies-Bouldin Index: 1.962431321919476
# Number of clusters: 31, Davies-Bouldin Index: 1.9326740948629157
# Number of clusters: 32, Davies-Bouldin Index: 1.9742838620911136
# Number of clusters: 33, Davies-Bouldin Index: 1.9498421733215527
# Number of clusters: 34, Davies-Bouldin Index: 1.9339468506248227
# Number of clusters: 35, Davies-Bouldin Index: 1.8800810048061303
# Number of clusters: 36, Davies-Bouldin Index: 1.8514942063209645
# Number of clusters: 37, Davies-Bouldin Index: 1.9260688645935755
# Number of clusters: 38, Davies-Bouldin Index: 1.8734132343562044
# Number of clusters: 39, Davies-Bouldin Index: 1.8639444513973273
# Number of clusters: 40, Davies-Bouldin Index: 1.915242392419047
# Number of clusters: 41, Davies-Bouldin Index: 1.9049926594056878
# Number of clusters: 42, Davies-Bouldin Index: 2.102762992815661
# Number of clusters: 43, Davies-Bouldin Index: 2.0756138764075795
# Number of clusters: 44, Davies-Bouldin Index: 2.02942481239146
# Number of clusters: 45, Davies-Bouldin Index: 2.0118979882542516
# Number of clusters: 46, Davies-Bouldin Index: 2.0390305826224595
# Number of clusters: 47, Davies-Bouldin Index: 2.0182483365531048
# Number of clusters: 48, Davies-Bouldin Index: 1.8680447234613684
# Number of clusters: 49, Davies-Bouldin Index: 1.8447532390592236

# %%
# see what there is in each cluster
labels = fcluster(linked, optimal_clusters, criterion='maxclust')
clusters = {i: [] for i in range(1, optimal_clusters + 1)}
for i, label in enumerate(labels):
    clusters[label].append(i)

for cluster, members in clusters.items():
    print(f'Cluster {cluster}:')
    for member in members:
        print(f'  {unique_adv[member]}')
# Out:
# Cluster 1:
#   ailleurs
#   outre
#   tant
# Cluster 2:
#   absolument
#   actuellement
#   afin
#   ainsi
#   alors
#   après
#   assez
#   au-delà
#   au-dessus
#   aujourd'hui
#   auparavant
#   auprès
#   aussi
#   autant
#   autour
#   autrement
#   avant
#   beaucoup
#   bien
#   bientôt
#   cependant
#   certes
#   clairement
#   comment
#   complètement
#   contrairement
#   davantage
#   depuis
#   directement
#   donc
#   définitivement
#   déjà
#   désormais
#   encore
#   enfin
#   ensemble
#   ensuite
#   entièrement
#   environ
#   essentiellement
#   extrêmement
#   facilement
#   finalement
#   fort
#   fortement
#   généralement
#   hier
#   hors
#   ici
#   immédiatement
#   initialement
#   jamais
#   juste
#   largement
#   loin
#   longtemps
#   lors
#   là
#   légèrement
#   maintenant
#   mal
#   malheureusement
#   mieux
#   moins
#   même
#   naturellement
#   ne
#   non
#   notamment
#   néanmoins
#   officiellement
#   parce
#   parfaitement
#   parfois
#   particulièrement
#   partiellement
#   partout
#   pas
#   peu
#   peut-être
#   plus
#   plutôt
#   pourquoi
#   pourtant
#   pratiquement
#   presque
#   principalement
#   probablement
#   progressivement
#   près
#   quant
#   que
#   rapidement
#   rarement
#   relativement
#   respectivement
#   récemment
#   réellement
#   régulièrement
#   seulement
#   si
#   simplement
#   soit
#   souvent
#   spécialement
#   surtout
#   tandis
#   tard
#   totalement
#   toujours
#   tout
#   toutefois
#   traditionnellement
#   trop
#   très
#   tôt
#   uniquement
#   vis-à-vis
#   vite
#   vivement
#   vraiment
#   véritablement
#   également
#   éventuellement

# %%
from jumpsmethod import JumpsMethod
jm = JumpsMethod(X)
jm.distortions()
jm.jumps()
number_clusters = jm.number_clusters()
print(number_clusters)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 10

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.decomposition import PCA
import plotly.express as px
import plotly.graph_objects as go

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Create a DataFrame for Plotly
df = pd.DataFrame({
    'PCA1': X_pca[:, 0],
    'PCA2': X_pca[:, 1],
    'Cluster': labels,
    'Word': unique_adv
})
# pca1_min, pca1_max = df['PCA1'].min(), df['PCA1'].max()
# pca2_min, pca2_max = df['PCA2'].min(), df['PCA2'].max()
# Create a scatter plot with Plotly
fig = go.Figure()

# Add traces for each cluster
for cluster in range(1, optimal_clusters + 1):
    cluster_data = df[df['Cluster'] == cluster]
    fig.add_trace(go.Scatter(
        x=cluster_data['PCA1'],
        y=cluster_data['PCA2'],
        mode='markers',
        marker=dict(size=10),
        name=f'Cluster {cluster}',
        text=cluster_data['Word'],
        hoverinfo='text'
    ))

# Update layout with dropdown menu
fig.update_layout(
    title='Word Clusters',
    xaxis_title='PCA1',
    yaxis_title='PCA2',
    # xaxis=dict(range=[pca1_min, pca1_max]),
    # yaxis=dict(range=[pca2_min, pca2_max]),
    updatemenus=[
        {
            'buttons': [
                {
                    'label': 'All Clusters',
                    'method': 'update',
                    'args': [{'visible': [True] * optimal_clusters},
                             {'title': 'All Clusters'}]
                }
            ] + [
                {
                    'label': f'Cluster {i}',
                    'method': 'update',
                    'args': [{'visible': [j == i - 1 for j in range(optimal_clusters)]},
                             {'title': f'Cluster {i}'}]
                } for i in range(1, optimal_clusters + 1)
            ],
            'direction': 'down',
            'showactive': True
        }
    ]
)

fig.show()

# %% [markdown]
# # If we also remove those that are part of an idiom

# %%
all_matches = corpus.search(grewpy.Request("pattern{X[upos=ADV]}").without("X[InIdiom=Yes]").without("X[Idiom=Yes]"), clustering_parameter=['X.lemma'])

# %%
matches = {}
for key, value in all_matches.items():
    # remove those that have less than 10 occurrences
    if len(value) > 10:
        matches[key] = value

# %%
with open("/Users/madalina/Documents/M2TAL/stage/check_coherent_labels/scripts/4. occurrences_as_features/patterns_adv_no_idioms.txt") as instream:
    config = yaml.load(instream, Loader=yaml.Loader)

templates = grex.utils.FeaturePredicate.from_config(config["templates"])
feature_predicate = grex.utils.FeaturePredicate.from_config(config["features"], templates=templates)

# %%
data = { k : list() for k in matches }
for adv, mts in matches.items():
    for match in mts:
        features = grex.data.extract_features(draft, match, feature_predicate)
        formatted_features = [
            f"{':'.join(k)}={v}" if not isinstance(v, set) else
            f"{':'.join(k)}={val}" for k, v in features.items() for val in (v if isinstance(v, set) else [v])
        ]
        data[adv].append(formatted_features)

# %%
unique_adv = sorted(set([k for k in data]))
unique_features = sorted(set([feat for _, matches in data.items() for m in matches for feat in m]))

idx2feature = {i : feat for i, feat in enumerate(unique_features) }
feature2idx = {feat : i for i, feat in idx2feature.items()}
idx2adv = {i : feat for i, feat in enumerate(unique_adv) }
adv2idx = {feat : i for i, feat in idx2adv.items()}

# %%
X = np.zeros((len(data.keys()), len(unique_features)))
for adv, samples in data.items():
    n_samples = len(matches)
    for m in samples:
        for feature in m:
            X[adv2idx[adv], feature2idx[feature]] += 1
    X[adv2idx[adv]] = X[adv2idx[adv]] / n_samples
print(f"{X.shape=}")
# Out:
# X.shape=(123, 185)

# %%
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, dendrogram, to_tree
import matplotlib.pyplot as plt

# Hamming or jacard for categorical data, cosine for sparse matrices (normally used in NLP)
# I compute the distance for each pair of lines, each POS
distance_matrix = pdist(X, 'mahalanobis', VI=None)
# Complete -> we cluster 
linked = linkage(distance_matrix, method="complete", optimal_ordering=True)

plt.figure(figsize=(30, 14))

dn = dendrogram(linked,
                orientation='top',
                labels=[name for name in unique_adv],
                distance_sort='descending',
                show_leaf_counts=True,
                get_leaves=True)

plt.title('Dendrogram', fontsize=12)  # Increase title font size
plt.xlabel('Sample index', fontsize=12)  # Increase x-axis label font size
plt.ylabel('Distance', fontsize=12)  # Increase y-axis label font size
plt.xticks(fontsize=12)  # Increase x-tick labels font size
plt.yticks(fontsize=12)  # Increase y-tick labels font size
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 7
#       3 import matplotlib.pyplot as plt
#       5 # Hamming or jacard for categorical data, cosine for sparse matrices (normally used in NLP)
#       6 # I compute the distance for each pair of lines, each POS
# ----> 7 distance_matrix = pdist(X, 'mahalanobis', VI=None)
#       8 # Complete -> we cluster
#       9 linked = linkage(distance_matrix, method="complete", optimal_ordering=True)
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/spatial/distance.py:2180, in pdist(X, metric, out, **kwargs)
#    2178 if metric_info is not None:
#    2179     pdist_fn = metric_info.pdist_func
# -> 2180     return pdist_fn(X, out=out, **kwargs)
#    2181 elif mstr.startswith("test_"):
#    2182     metric_info = _TEST_METRICS.get(mstr, None)
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/spatial/distance.py:1651, in PDistMetricWrapper.__call__(self, X, out, **kwargs)
#    1649 metric_name = self.metric_name
#    1650 metric_info = _METRICS[metric_name]
# -> 1651 X, typ, kwargs = _validate_pdist_input(
#    1652     X, m, n, metric_info, **kwargs)
#    1653 out_size = (m * (m - 1)) // 2
#    1654 w = kwargs.pop('w', None)
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/spatial/distance.py:274, in _validate_pdist_input(X, m, n, metric_info, **kwargs)
#     272 _validate_kwargs = metric_info.validator
#     273 if _validate_kwargs:
# --> 274     kwargs = _validate_kwargs(X, m, n, **kwargs)
#     275 return X, typ, kwargs
#
# File /opt/homebrew/lib/python3.11/site-packages/scipy/spatial/distance.py:239, in _validate_mahalanobis_kwargs(X, m, n, **kwargs)
#     235 if VI is None:
#     236     if m <= n:
#     237         # There are fewer observations than the dimension of
#     238         # the observations.
# --> 239         raise ValueError("The number of observations (%d) is too "
#     240                          "small; the covariance matrix is "
#     241                          "singular. For observations with %d "
#     242                          "dimensions, at least %d observations "
#     243                          "are required." % (m, n, n + 1))
#     244     if isinstance(X, tuple):
#     245         X = np.vstack(X)
#
# ValueError: The number of observations (123) is too small; the covariance matrix is singular. For observations with 185 dimensions, at least 186 observations are required.

# %%
import numpy as np
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics import silhouette_score

def find_optimal_clusters(X, max_clusters=20, metric='cosine', method='complete'):
    distance_matrix = pdist(X, metric=metric)
    linked = linkage(distance_matrix, method=method, optimal_ordering=True)
    
    silhouette_scores = []
    for num_clusters in range(2, max_clusters + 1):
        labels = fcluster(linked, num_clusters, criterion='maxclust')
        if len(np.unique(labels)) > 1:  # Ensure there is more than one cluster
            score = silhouette_score(X, labels, metric=metric)
            silhouette_scores.append(score)
            print(f'Number of clusters: {num_clusters}, Silhouette Score: {score}')
        else:
            silhouette_scores.append(-1)  # Append a low score if only one cluster
    
    optimal_clusters = np.argmax(silhouette_scores) + 2  # +2 because range starts from 2
    return optimal_clusters, silhouette_scores
optimal_clusters, silhouette_scores = find_optimal_clusters(X, max_clusters=50)
print(f'Optimal number of clusters: {optimal_clusters}')
print(X.shape)
# Out:
# Number of clusters: 2, Silhouette Score: 0.4686437693957695
# Number of clusters: 3, Silhouette Score: 0.40896904806432305
# Number of clusters: 4, Silhouette Score: 0.42172624581390367
# Number of clusters: 5, Silhouette Score: 0.4000010453288083
# Number of clusters: 6, Silhouette Score: 0.2679539143690957
# Number of clusters: 7, Silhouette Score: 0.28682023952351354
# Number of clusters: 8, Silhouette Score: 0.29887585458398885
# Number of clusters: 9, Silhouette Score: 0.3008290243341241
# Number of clusters: 10, Silhouette Score: 0.2997643515709149
# Number of clusters: 11, Silhouette Score: 0.31030825972482656
# Number of clusters: 12, Silhouette Score: 0.3111926414985038
# Number of clusters: 13, Silhouette Score: 0.2995359366313846
# Number of clusters: 14, Silhouette Score: 0.3105006893962711
# Number of clusters: 15, Silhouette Score: 0.3152655258931331
# Number of clusters: 16, Silhouette Score: 0.3065408813723807
# Number of clusters: 17, Silhouette Score: 0.3186533729756988
# Number of clusters: 18, Silhouette Score: 0.31006484597290684
# Number of clusters: 19, Silhouette Score: 0.2870099924452226
# Number of clusters: 20, Silhouette Score: 0.2926695812608468
# Number of clusters: 21, Silhouette Score: 0.30996920694416885
# Number of clusters: 22, Silhouette Score: 0.3118486894475592
# Number of clusters: 23, Silhouette Score: 0.3162715551665808
# Number of clusters: 24, Silhouette Score: 0.32415906910154185
# Number of clusters: 25, Silhouette Score: 0.3245983356205116
# Number of clusters: 26, Silhouette Score: 0.3168596698093477
# Number of clusters: 27, Silhouette Score: 0.3287095188258184
# Number of clusters: 28, Silhouette Score: 0.33160429987323237
# Number of clusters: 29, Silhouette Score: 0.32386114782634073
# Number of clusters: 30, Silhouette Score: 0.3337237933029233
# Number of clusters: 31, Silhouette Score: 0.34201380854398844
# Number of clusters: 32, Silhouette Score: 0.33819287566977974
# Number of clusters: 33, Silhouette Score: 0.3341909555853784
# Number of clusters: 34, Silhouette Score: 0.3222805285020923
# Number of clusters: 35, Silhouette Score: 0.3120257277371118
# Number of clusters: 36, Silhouette Score: 0.30120274755032816
# Number of clusters: 37, Silhouette Score: 0.2988038284313911
# Number of clusters: 38, Silhouette Score: 0.2952022589435774
# Number of clusters: 39, Silhouette Score: 0.2875316048075627
# Number of clusters: 40, Silhouette Score: 0.2879016404107719
# Number of clusters: 41, Silhouette Score: 0.2880150464632125
# Number of clusters: 42, Silhouette Score: 0.2441758528366925
# Number of clusters: 43, Silhouette Score: 0.24330125407481618
# Number of clusters: 44, Silhouette Score: 0.24737109571128296
# Number of clusters: 45, Silhouette Score: 0.24242263647280343
# Number of clusters: 46, Silhouette Score: 0.24289582536514542
# Number of clusters: 47, Silhouette Score: 0.23271008409784366
# Number of clusters: 48, Silhouette Score: 0.23011545912244752
# Number of clusters: 49, Silhouette Score: 0.22614435360700635
# Number of clusters: 50, Silhouette Score: 0.2410357600350743
# Optimal number of clusters: 2
# (123, 185)

# %%
# see what there is in each cluster
labels = fcluster(linked, optimal_clusters, criterion='maxclust')
clusters = {i: [] for i in range(1, optimal_clusters + 1)}
for i, label in enumerate(labels):
    clusters[label].append(i)

for cluster, members in clusters.items():
    print(f'Cluster {cluster}:')
    for member in members:
        print(f'  {unique_adv[member]}')
# Out:
# Cluster 1:
#   au-delà
#   au-dessus
#   auprès
#   autant
#   autour
#   beaucoup
#   contrairement
#   davantage
#   hors
#   loin
#   lors
#   moins
#   peu
#   près
#   tant
#   tard
#   tôt
#   vis-à-vis
# Cluster 2:
#   absolument
#   actuellement
#   afin
#   ailleurs
#   ainsi
#   alors
#   après
#   assez
#   aujourd'hui
#   auparavant
#   aussi
#   autrement
#   avant
#   bien
#   bientôt
#   cependant
#   certes
#   clairement
#   comment
#   complètement
#   depuis
#   directement
#   donc
#   définitivement
#   déjà
#   désormais
#   encore
#   enfin
#   ensemble
#   ensuite
#   entièrement
#   environ
#   essentiellement
#   extrêmement
#   facilement
#   finalement
#   fort
#   fortement
#   généralement
#   hier
#   ici
#   immédiatement
#   initialement
#   jamais
#   juste
#   largement
#   longtemps
#   là
#   légèrement
#   maintenant
#   mal
#   malheureusement
#   mieux
#   même
#   naturellement
#   ne
#   non
#   notamment
#   néanmoins
#   officiellement
#   parfaitement
#   parfois
#   particulièrement
#   partiellement
#   partout
#   pas
#   peut-être
#   plus
#   plutôt
#   pourquoi
#   pourtant
#   pratiquement
#   presque
#   principalement
#   probablement
#   progressivement
#   que
#   rapidement
#   rarement
#   relativement
#   respectivement
#   récemment
#   réellement
#   régulièrement
#   seulement
#   si
#   simplement
#   soit
#   souvent
#   spécialement
#   surtout
#   totalement
#   toujours
#   tout
#   toutefois
#   traditionnellement
#   trop
#   très
#   uniquement
#   vite
#   vivement
#   vraiment
#   véritablement
#   également
#   éventuellement

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.decomposition import PCA
import plotly.express as px
import plotly.graph_objects as go

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Create a DataFrame for Plotly
df = pd.DataFrame({
    'PCA1': X_pca[:, 0],
    'PCA2': X_pca[:, 1],
    'Cluster': labels,
    'Word': unique_adv
})
# pca1_min, pca1_max = df['PCA1'].min(), df['PCA1'].max()
# pca2_min, pca2_max = df['PCA2'].min(), df['PCA2'].max()
# Create a scatter plot with Plotly
fig = go.Figure()

# Add traces for each cluster
for cluster in range(1, optimal_clusters + 1):
    cluster_data = df[df['Cluster'] == cluster]
    fig.add_trace(go.Scatter(
        x=cluster_data['PCA1'],
        y=cluster_data['PCA2'],
        mode='markers',
        marker=dict(size=10),
        name=f'Cluster {cluster}',
        text=cluster_data['Word'],
        hoverinfo='text'
    ))

# Update layout with dropdown menu
fig.update_layout(
    title='Word Clusters',
    xaxis_title='PCA1',
    yaxis_title='PCA2',
    # xaxis=dict(range=[pca1_min, pca1_max]),
    # yaxis=dict(range=[pca2_min, pca2_max]),
    updatemenus=[
        {
            'buttons': [
                {
                    'label': 'All Clusters',
                    'method': 'update',
                    'args': [{'visible': [True] * optimal_clusters},
                             {'title': 'All Clusters'}]
                }
            ] + [
                {
                    'label': f'Cluster {i}',
                    'method': 'update',
                    'args': [{'visible': [j == i - 1 for j in range(optimal_clusters)]},
                             {'title': f'Cluster {i}'}]
                } for i in range(1, optimal_clusters + 1)
            ],
            'direction': 'down',
            'showactive': True
        }
    ]
)

fig.show()

# %%
# seeing as the optimal clusters is 2, if we want to have more than that, judging by silhouette scores it would make sense to choose 4
optimal_clusters = 4
labels = fcluster(linked, optimal_clusters, criterion='maxclust')
clusters = {i: [] for i in range(1, optimal_clusters + 1)}
for i, label in enumerate(labels):
    clusters[label].append(i)

for cluster, members in clusters.items():
    print(f'Cluster {cluster}:')
    for member in members:
        print(f'  {unique_adv[member]}')
# Out:
# Cluster 1:
#   au-delà
#   au-dessus
#   auprès
#   autant
#   autour
#   beaucoup
#   contrairement
#   davantage
#   hors
#   loin
#   lors
#   moins
#   peu
#   près
#   tant
#   tard
#   tôt
#   vis-à-vis
# Cluster 2:
#   absolument
#   actuellement
#   afin
#   ailleurs
#   ainsi
#   alors
#   après
#   aujourd'hui
#   auparavant
#   aussi
#   autrement
#   avant
#   bien
#   bientôt
#   cependant
#   certes
#   clairement
#   comment
#   complètement
#   depuis
#   directement
#   donc
#   définitivement
#   déjà
#   désormais
#   encore
#   enfin
#   ensemble
#   ensuite
#   entièrement
#   essentiellement
#   facilement
#   finalement
#   fortement
#   généralement
#   hier
#   ici
#   immédiatement
#   initialement
#   largement
#   longtemps
#   là
#   maintenant
#   mal
#   malheureusement
#   mieux
#   même
#   naturellement
#   notamment
#   néanmoins
#   officiellement
#   parfaitement
#   parfois
#   partiellement
#   partout
#   peut-être
#   plutôt
#   pourquoi
#   pourtant
#   pratiquement
#   principalement
#   probablement
#   progressivement
#   rapidement
#   rarement
#   respectivement
#   récemment
#   réellement
#   régulièrement
#   seulement
#   simplement
#   souvent
#   spécialement
#   surtout
#   totalement
#   toujours
#   toutefois
#   traditionnellement
#   uniquement
#   vite
#   vivement
#   vraiment
#   véritablement
#   également
#   éventuellement
# Cluster 3:
#   jamais
#   ne
#   non
#   pas
#   que
# Cluster 4:
#   assez
#   environ
#   extrêmement
#   fort
#   juste
#   légèrement
#   particulièrement
#   plus
#   presque
#   relativement
#   si
#   soit
#   tout
#   trop
#   très

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.decomposition import PCA
import plotly.express as px
import plotly.graph_objects as go

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Create a DataFrame for Plotly
df = pd.DataFrame({
    'PCA1': X_pca[:, 0],
    'PCA2': X_pca[:, 1],
    'Cluster': labels,
    'Word': unique_adv
})
# pca1_min, pca1_max = df['PCA1'].min(), df['PCA1'].max()
# pca2_min, pca2_max = df['PCA2'].min(), df['PCA2'].max()
# Create a scatter plot with Plotly
fig = go.Figure()

# Add traces for each cluster
for cluster in range(1, optimal_clusters + 1):
    cluster_data = df[df['Cluster'] == cluster]
    fig.add_trace(go.Scatter(
        x=cluster_data['PCA1'],
        y=cluster_data['PCA2'],
        mode='markers',
        marker=dict(size=10),
        name=f'Cluster {cluster}',
        text=cluster_data['Word'],
        hoverinfo='text'
    ))

# Update layout with dropdown menu
fig.update_layout(
    title='Word Clusters',
    xaxis_title='PCA1',
    yaxis_title='PCA2',
    # xaxis=dict(range=[pca1_min, pca1_max]),
    # yaxis=dict(range=[pca2_min, pca2_max]),
    updatemenus=[
        {
            'buttons': [
                {
                    'label': 'All Clusters',
                    'method': 'update',
                    'args': [{'visible': [True] * optimal_clusters},
                             {'title': 'All Clusters'}]
                }
            ] + [
                {
                    'label': f'Cluster {i}',
                    'method': 'update',
                    'args': [{'visible': [j == i - 1 for j in range(optimal_clusters)]},
                             {'title': f'Cluster {i}'}]
                } for i in range(1, optimal_clusters + 1)
            ],
            'direction': 'down',
            'showactive': True
        }
    ]
)

fig.show()
